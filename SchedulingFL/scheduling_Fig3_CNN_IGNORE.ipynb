# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Subset
from torchvision import datasets, transforms
import numpy as np
import matplotlib.pyplot as plt
import collections
import random

# %%
# --- 1. Wireless Environment Parameters ---
B_HZ = 1e6              # 1 MHz
N0_DBM_HZ = -174        # Noise density
P_TX_CLIENT_DBM = 24    # Uplink Power
P_TX_SERVER_DBM = 46    # Downlink Power (Server)
Q_BITS = 16             # 16-bit quantization
RADIUS_KM = 0.5         # 500m
DEVICE_GFLOPS = 2.0     # Average edge device speed (2 Billion operations/sec)

# %%
def plot_radar_map(r_km):
    """
    Plots 30 devices in a circular layout with index labels.
    Red triangle = Edge Server (Center)
    Blue dots = Edge Devices (Labeled 0-29)
    """
    # Generate random angles (theta) in radians
    theta = 2 * np.pi * np.random.rand(len(r_km)) 
    
    # Convert polar (r, theta) to Cartesian (x, y) for easier labeling
    x = r_km * np.cos(theta)
    y = r_km * np.sin(theta)
    
    plt.figure(figsize=(8, 8))
    
    # Plot the circular boundary (500m radius)
    circle = plt.Circle((0, 0), RADIUS_KM, color='gray', fill=False, linestyle='--', alpha=0.5)
    plt.gca().add_patch(circle)
    
    # Plot Edge Server at the center (0,0)
    plt.scatter(0, 0, c='red', marker='^', s=150, label='Edge Server', zorder=5)
    
    # Plot Edge Devices
    plt.scatter(x, y, c='skyblue', edgecolors='navy', s=80, alpha=0.8, label='Edge Devices')
    
    # Add Index Labels (0 to 29) for each device
    for i in range(len(r_km)):
        plt.annotate(f'{i}', (x[i], y[i]), xytext=(5, 5), 
                     textcoords='offset points', fontsize=9, fontweight='bold')

    plt.title(f"Device Distribution ({RADIUS_KM*1000}m Radius)")
    plt.xlabel("Distance (km)")
    plt.ylabel("Distance (km)")
    plt.legend(loc='upper right')
    plt.grid(True, alpha=0.2)
    plt.axis('equal') # Keep the circle from looking like an oval
    plt.xlim(-RADIUS_KM - 0.1, RADIUS_KM + 0.1)
    plt.ylim(-RADIUS_KM - 0.1, RADIUS_KM + 0.1)
    plt.show()

# %%
# --- 2. Model Architectures ---

class SVMModel(nn.Module):
    def __init__(self):
        super(SVMModel, self).__init__()
        self.fc = nn.Linear(3072, 1)
    def forward(self, x):
        return self.fc(x.view(x.size(0), -1))

class CNNModel(nn.Module):
    def __init__(self):
        super(CNNModel, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(1, 32, 5), nn.ReLU(), nn.MaxPool2d(2, 2),
            nn.Conv2d(32, 64, 5), nn.ReLU(), nn.MaxPool2d(2, 2)
        )
        self.fc = nn.Sequential(nn.Linear(64 * 4 * 4, 512), nn.ReLU(), nn.Linear(512, 10))
    def forward(self, x):
        x = self.conv(x)
        return self.fc(x.view(x.size(0), -1))

# %%
# --- 3. Data Preparation ---

def get_datasets(task='CNN'):
    # Define a shared seed for reproducibility if needed, 
    # or remove it for different random splits each time.
    random.seed(42) 
    np.random.seed(42)

    if task == 'SVM':
        transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])
        train_set = datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
        test_set = datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
        
        train_idx = [i for i, l in enumerate(train_set.targets) if l in [0, 1]]
        test_idx = [i for i, l in enumerate(test_set.targets) if l in [0, 1]]
        
        airplanes = [i for i in train_idx if train_set.targets[i] == 0][:15*330]
        autos = [i for i in train_idx if train_set.targets[i] == 1][:15*330]
        
        # Create the raw list of 30 Subsets
        all_subsets = [Subset(train_set, airplanes[i*330:(i+1)*330]) for i in range(15)] + \
                       [Subset(train_set, autos[i*330:(i+1)*330]) for i in range(15)]
        
        # RANDOMIZATION: Shuffle the list so 'Airplane devices' are spread 0-29
        random.shuffle(all_subsets)
        device_data = all_subsets
        
        return device_data, Subset(test_set, test_idx), SVMModel(), 0.0001

    else: # CNN Task (MNIST)
        transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))])
        train_set = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
        test_set = datasets.MNIST(root='./data', train=False, download=True, transform=transform)
        
        # Pathological Non-IID: Sort by label to create shards
        indices = np.argsort(train_set.targets.numpy())
        shards = [indices[i*1000 : (i+1)*1000] for i in range(60)]
        
        # RANDOMIZATION: Shuffle the shards so Device 0 doesn't 
        # automatically get the 'lowest' labels (0 and 1)
        random.shuffle(shards)
        
        # Each device gets 2 random shards (each shard is likely 1 digit)
        device_data = [Subset(train_set, np.concatenate((shards[i*2], shards[i*2+1]))) for i in range(30)]
        
        return device_data, test_set, CNNModel(), 0.005
    
def observe_distribution(device_data, task='CNN'):
    # Determine how many classes to show
    num_labels = 10 if task == 'CNN' else 2
    distribution_matrix = np.zeros((30, num_labels))

    for i in range(30):
        subset = device_data[i]
        # Robustly handle different dataset target formats
        targets = subset.dataset.targets
        subset_labels = [int(targets[idx]) for idx in subset.indices]
        
        counts = collections.Counter(subset_labels)
        for label, count in counts.items():
            # For SVM, only record if label is 0 or 1
            if label < num_labels:
                distribution_matrix[i, label] = count

    # Plotting
    plt.figure(figsize=(8, 8)) # Narrower figure for 2 columns
    im = plt.imshow(distribution_matrix, cmap='YlGnBu', aspect='auto')
    
    plt.colorbar(im, label='Number of Samples')
    plt.title(f'Non-IID Heatmap: {task} Task', fontsize=14)
    plt.xlabel('Class Label', fontsize=12)
    plt.ylabel('Device Index', fontsize=12)
    
    # Set x-ticks specifically to the number of labels
    plt.xticks(range(num_labels))
    # If SVM, label them appropriately
    if task == 'SVM':
        plt.gca().set_xticklabels(['0 (Airplane)', '1 (Auto)'])
    
    plt.yticks(range(0, 30, 2))
    plt.tight_layout()
    plt.show()

# %%
device_data_svm, _, _, _ = get_datasets(task='CNN')
observe_distribution(device_data_svm, task='CNN')

# %%
def get_optimal_probabilities(n_k_list, grad_norms, T_u_list, rho):
    """
    Implements Theorem 1 - Importance- and channel-aware scheduling policy.
    """
    n_total = sum(n_k_list)
    grad_norms = np.array(grad_norms) + 1e-12 
    T_u_list = np.array(T_u_list)
    num_devices = len(n_k_list)

    floor_value = 0.0001 # Each device gets at least 1% chance
    total_floor = num_devices * floor_value
    remaining_budget = 1.0 - total_floor

    def apply_gaussian_top3(values, reverse=False):
        # 1. Start everyone with the 1% floor
        p = np.full(num_devices, floor_value)
        
        # 2. Identify the Top 3
        sorted_indices = np.argsort(values)
        if not reverse:
            sorted_indices = sorted_indices[::-1]
            
        # 3. Distribute the remaining 40% budget using Gaussian weights
        # Weights: Rank1 (1.0), Rank2 (0.606), Rank3 (0.135) -> Sum = 1.741
        raw_weights = np.array([1.0, 0.606, 0.135])
        normalized_weights = raw_weights / np.sum(raw_weights) # Scale to sum to 1.0
        
        # Add the budgeted share to the floor
        p[sorted_indices[0]] += normalized_weights[0] * remaining_budget
        p[sorted_indices[1]] += normalized_weights[1] * remaining_budget
        p[sorted_indices[2]] += normalized_weights[2] * remaining_budget
        
        return p

    # 1. New Behavior for rho = 0 (Channel-aware: Top 3 Fastest)
    if rho == 0:
        return apply_gaussian_top3(T_u_list, reverse=True)

    # 2. New Behavior for rho = 1 (Importance-aware: Top 3 Most Informative)
    if rho == 1:
        # Importance includes data weight n_k/n
        importance = (np.array(n_k_list) / n_total) * grad_norms
        return apply_gaussian_top3(importance, reverse=False)

    # 3. Proposed Policy (Intermediate rho)
    def compute_p_star(lam):
        denom = (1 - rho) * T_u_list + lam
        p = (np.array(n_k_list) / n_total) * grad_norms * np.sqrt(rho / np.maximum(denom, 1e-15))
        return p

    low = -np.min((1 - rho) * T_u_list) + 1e-12
    high = 1e6 
    
    for _ in range(100):
        mid = (low + high) / 2
        if np.sum(compute_p_star(mid)) > 1: low = mid
        else: high = mid

    lambda_star  = high
    final_p_raw = compute_p_star(lambda_star)
    return final_p_raw / np.sum(final_p_raw)

# %%
def run_importance_aware_fl(task='SVM', training_time=10, rho=5e-6, r_km= RADIUS_KM * np.sqrt(np.random.rand(30))):
    device_data, test_set, global_model, lr = get_datasets(task)
    test_loader = DataLoader(test_set, batch_size=1000, shuffle=False)
    n_k_list = [len(d) for d in device_data]
    n_total = sum(n_k_list)
    lmbda = 0.01 
    selection_counts = np.zeros(30)
    history = {'acc': [], 'time': []}
    cumulative_time = 0

    print(f"\n--- Simulation: {task} | 30 Clients | Training Time: {training_time}s ---")

    while cumulative_time < training_time:
        # Communication Model
        path_loss_db = 128.1 + 37.6 * np.log10(np.maximum(r_km, 0.01))
        
        noise_up_w = 10**(((N0_DBM_HZ + 10 * np.log10(B_HZ)) - 30) / 10)
        p_rx_up_w = 10**(((P_TX_CLIENT_DBM - path_loss_db) - 30) / 10)
        gamma_up = p_rx_up_w / noise_up_w
        
        noise_down_w = 10**(((N0_DBM_HZ + 10 * np.log10(B_HZ)) - 30) / 10)
        p_rx_down_w = 10**(((P_TX_SERVER_DBM - path_loss_db) - 30) / 10)
        gamma_down_min = np.min(p_rx_down_w / noise_down_w) 
        
        num_params = sum(p.numel() for p in global_model.parameters())
        payload_bits = num_params * Q_BITS
        T_u_list = payload_bits / (B_HZ * np.log2(1 + gamma_up))

        # Importance Evaluation
        grad_norms = []
        client_gradients = []
        for i in range(30):
            # Step 1: Global Model Broadcast
            local_model = type(global_model)()
            local_model.load_state_dict(global_model.state_dict())
            loader = DataLoader(device_data[i], batch_size=len(device_data[i]))
            data, target = next(iter(loader))
            local_model.zero_grad()

            # Step 2: Local Gradient Calculation
            output = local_model(data).squeeze()
            if task == 'SVM':
                target_svm = (target.float() * 2) - 1 
                loss = 0.5 * torch.mean(torch.clamp(1 - target_svm * output, min=0)) + (lmbda / 2.0) * sum(p.pow(2).sum() for p in local_model.parameters())
            else:
                target_oh = torch.nn.functional.one_hot(target, num_classes=10).float()
                loss = 0.5 * torch.nn.functional.mse_loss(output, target_oh, reduction='mean')

            # Step 3: Importance Indicator Report
            loss.backward()
            grads = [p.grad.detach().clone() for p in local_model.parameters()]
            grad_norms.append(torch.norm(torch.cat([g.view(-1) for g in grads])).item())
            client_gradients.append(grads)

        # Step 4: Device Selection and Resource Allocation
        p_star = get_optimal_probabilities(n_k_list, grad_norms, T_u_list, rho)
        print(f"Probability Policy: [Max: {100 * np.max(p_star):.2f}% - (Device {np.argmax(p_star)}) | "
        f"Min: {100 * np.min(p_star):.2f}% | Std: {100 * np.std(p_star):.2f}% | Sum: {100 * np.sum(p_star):.2f}% ]")
        selected_idx = np.random.choice(range(30), p=p_star)
        selection_counts[selected_idx] += 1

        # Step 5: Local Gradient Upload (Simulate latency)
        t_broadcast = payload_bits / (B_HZ * np.log2(1 + gamma_down_min)) 
        t_comp_max = (max(n_k_list) * (6000 if task=='SVM' else 15e6)) / (DEVICE_GFLOPS * 1e9)
        cumulative_time += (t_broadcast + t_comp_max + T_u_list[selected_idx])

        # Step 6: Global Model Update
        with torch.no_grad():
            if rho == 0 or rho == 1:
                scale = 1.0 
            else:
                # Standard Theorem 1 Unbiased Estimator
                scale = n_k_list[selected_idx] / (n_total) # * p_star[selected_idx]) IGNORE
            for p_global, g_local in zip(global_model.parameters(), client_gradients[selected_idx]):
                p_global -= lr * (scale * g_local)

        # Evaluation
        global_model.eval()
        correct, total = 0, 0
        with torch.no_grad():
            for data, target in test_loader:
                output = global_model(data)
                pred = torch.sign(output.squeeze()) if task == 'SVM' else output.argmax(1)
                labels = (target.float()*2-1) if task == 'SVM' else target
                correct += (pred == labels).sum().item()
                total += target.size(0)
        
        acc = 100. * correct / total
        history['acc'].append(acc)
        history['time'].append(cumulative_time)
        print(f"Time: {cumulative_time:.3f}s / {training_time}s | Acc: {acc:.2f}%")

    return history, selection_counts

# %%
# Force 5 devices to be at the cell edge (450m - 500m) 
# and 25 devices to be distributed normally.
r_km = RADIUS_KM * np.sqrt(np.random.rand(30))
r_km[:5] = 0.45 + (np.random.rand(5) * 0.05)
plot_radar_map(r_km)

# %%
rho = 0
_, selection_counts = run_importance_aware_fl(task='CNN', training_time=60, rho = rho, r_km=r_km )

# --- Selection Counts ---
plt.figure(figsize=(10, 5))
plt.bar(range(30), selection_counts, color='teal', edgecolor='black', alpha=0.7)
plt.title(f"Device Selection Frequency (rho={rho})")
plt.xlabel("Device Index")
plt.ylabel("Number of Times Selected")
plt.xticks(range(30))
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.show()
# Out:
# --- Simulation: CNN | 30 Clients | Training Time: 60s ---
# Probability Policy: [Max: 57.28% - (Device 5) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 16.212s / 60s | Acc: 10.12%
# Probability Policy: [Max: 57.28% - (Device 5) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 32.572s / 60s | Acc: 9.97%
# Probability Policy: [Max: 57.28% - (Device 5) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 48.882s / 60s | Acc: 9.82%
# Probability Policy: [Max: 57.28% - (Device 5) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 65.192s / 60s | Acc: 9.72%

# %%
rho = 1
_, selection_counts = run_importance_aware_fl(task='CNN', training_time=60, rho = rho, r_km=r_km )

# --- Selection Counts ---
plt.figure(figsize=(10, 5))
plt.bar(range(30), selection_counts, color='teal', edgecolor='black', alpha=0.7)
plt.title(f"Device Selection Frequency (rho={rho})")
plt.xlabel("Device Index")
plt.ylabel("Number of Times Selected")
plt.xticks(range(30))
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.show()
# Out:
# --- Simulation: CNN | 30 Clients | Training Time: 60s ---
# Probability Policy: [Max: 57.28% - (Device 3) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 16.867s / 60s | Acc: 9.82%
# Probability Policy: [Max: 57.28% - (Device 3) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 33.429s / 60s | Acc: 9.81%
# Probability Policy: [Max: 57.28% - (Device 3) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 49.991s / 60s | Acc: 9.86%
# Probability Policy: [Max: 57.28% - (Device 3) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 66.759s / 60s | Acc: 9.87%

# %%
rho = 5e-3
_, selection_counts = run_importance_aware_fl(task='CNN', training_time=60, rho = rho, r_km=r_km )

# --- Selection Counts ---
plt.figure(figsize=(10, 5))
plt.bar(range(30), selection_counts, color='teal', edgecolor='black', alpha=0.7)
plt.title(f"Device Selection Frequency (rho={rho})")
plt.xlabel("Device Index")
plt.ylabel("Number of Times Selected")
plt.xticks(range(30))
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.show()
# Out:
# --- Simulation: CNN | 30 Clients | Training Time: 60s ---
# Probability Policy: [Max: 93.72% - (Device 5) | Min: 0.13% | Std: 16.78% | Sum: 100.00% ]
# Time: 16.212s / 60s | Acc: 10.58%
# Probability Policy: [Max: 93.72% - (Device 5) | Min: 0.13% | Std: 16.78% | Sum: 100.00% ]
# Time: 32.905s / 60s | Acc: 10.60%
# Probability Policy: [Max: 93.72% - (Device 5) | Min: 0.13% | Std: 16.78% | Sum: 100.00% ]
# Time: 49.117s / 60s | Acc: 10.63%
# Probability Policy: [Max: 93.72% - (Device 5) | Min: 0.13% | Std: 16.79% | Sum: 100.00% ]
# Time: 65.329s / 60s | Acc: 10.65%

# %%
rho = 5e-1
_, selection_counts = run_importance_aware_fl(task='CNN', training_time=60, rho = rho, r_km=r_km )

# --- Selection Counts ---
plt.figure(figsize=(10, 5))
plt.bar(range(30), selection_counts, color='teal', edgecolor='black', alpha=0.7)
plt.title(f"Device Selection Frequency (rho={rho})")
plt.xlabel("Device Index")
plt.ylabel("Number of Times Selected")
plt.xticks(range(30))
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.show()
# Out:
# --- Simulation: CNN | 30 Clients | Training Time: 60s ---
# Probability Policy: [Max: 16.77% - (Device 5) | Min: 1.54% | Std: 2.67% | Sum: 100.00% ]
# Time: 16.917s / 60s | Acc: 10.03%
# Probability Policy: [Max: 16.80% - (Device 5) | Min: 1.54% | Std: 2.67% | Sum: 100.00% ]
# Time: 33.277s / 60s | Acc: 10.03%
# Probability Policy: [Max: 16.84% - (Device 5) | Min: 1.54% | Std: 2.68% | Sum: 100.00% ]
# Time: 50.140s / 60s | Acc: 10.03%
# Probability Policy: [Max: 16.86% - (Device 5) | Min: 1.54% | Std: 2.68% | Sum: 100.00% ]
# Time: 66.679s / 60s | Acc: 10.02%

# %%
rho = 5e-2
_, selection_counts = run_importance_aware_fl(task='CNN', training_time=60, rho = rho, r_km=r_km )

# --- Selection Counts ---
plt.figure(figsize=(10, 5))
plt.bar(range(30), selection_counts, color='teal', edgecolor='black', alpha=0.7)
plt.title(f"Device Selection Frequency (rho={rho})")
plt.xlabel("Device Index")
plt.ylabel("Number of Times Selected")
plt.xticks(range(30))
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.show()
# Out:
# --- Simulation: CNN | 30 Clients | Training Time: 60s ---
# Probability Policy: [Max: 78.73% - (Device 5) | Min: 0.46% | Std: 14.00% | Sum: 100.00% ]
# Time: 16.212s / 60s | Acc: 7.67%
# Probability Policy: [Max: 78.73% - (Device 5) | Min: 0.46% | Std: 14.00% | Sum: 100.00% ]
# Time: 33.121s / 60s | Acc: 7.68%
# Probability Policy: [Max: 78.74% - (Device 5) | Min: 0.46% | Std: 14.01% | Sum: 100.00% ]
# Time: 49.333s / 60s | Acc: 7.68%
# Probability Policy: [Max: 78.75% - (Device 5) | Min: 0.46% | Std: 14.01% | Sum: 100.00% ]
# Time: 65.545s / 60s | Acc: 7.67%

# %%
def run_full_comparison(task='SVM', max_sim_time=0.1):
    """Modified comparison loop to use max_sim_time instead of rounds."""
    if task == 'SVM':
        rhos = {0: 'Channel-aware', 1: 'Importance-aware', 5e-4: 'Proposed (5e-4)', 5e-5: 'Proposed (5e-5)', 5e-6: 'Proposed (5e-6)'}
        time_scale = 1
    else:
        rhos = {0: 'Channel-aware', 1: 'Importance-aware', 5e-1: 'Proposed (5e-1)', 5e-2: 'Proposed (5e-2)', 5e-3: 'Proposed (5e-3)'}
        time_scale = 60

    training_results = {}
    selection_results = {}
    # Force 5 devices to be at the cell edge (450m - 500m) 
    # and 25 devices to be distributed normally.
    r_km = RADIUS_KM * np.sqrt(np.random.rand(30))
    r_km[:5] = 0.45 + (np.random.rand(5) * 0.05)
    plot_radar_map(r_km)

    for rho, label in rhos.items():
        print(f"\n>>> Running {label} Policy, rho={rho} <<<")
        history, sel_counts = run_importance_aware_fl(task=task, training_time=max_sim_time, rho=rho, r_km=r_km)
        training_results[label] = history
        selection_results[label] = sel_counts

    # --- Plot Comparison ---
    plt.figure(figsize=(10, 6))
    for label, hist in training_results.items():
        plt.plot(np.array(hist['time']) / time_scale, hist['acc'], label=label)
    plt.xlabel(f"Training Time ({'Seconds' if time_scale==1 else 'Minutes'})")
    plt.ylabel("Accuracy")
    plt.title(f"Performance Comparison: {task}")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()

    # --- Selection Counts ---
    fig, axes = plt.subplots(len(rhos), 1, figsize=(12, 3 * len(rhos)))
    if len(rhos) == 1: axes = [axes] 

    for ax, (label, sel) in zip(axes, selection_results.items()):
        # Plotting the bars
        ax.bar(range(30), sel, color='teal', edgecolor='black', alpha=0.7)
    
        # 2. Set the Title and Labels
        ax.set_title(f"Selection Frequency: {label}", fontsize=12, fontweight='bold')
        ax.set_ylabel("Count")
    
        # 3. Force the ticks and labels on EVERY subplot
        ax.set_xticks(range(30))
        ax.tick_params(labelbottom=True) # Forces labels to appear even if sharing axes
    
        # 4. Styling the grid
        ax.grid(axis='y', linestyle='--', alpha=0.4)
    
        # 5. Optional: Set Y-axis to integers only (since counts are whole numbers)
        ax.yaxis.get_major_locator().set_params(integer=True)

    plt.xlabel("Device Index")
    plt.tight_layout()
    plt.show()

# %%
run_full_comparison(task='CNN', max_sim_time=12000)
# Out:
# >>> Running Channel-aware Policy, rho=0 <<<
#
# --- Simulation: CNN | 30 Clients | Training Time: 12000s ---
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 16.177s / 12000s | Acc: 12.08%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 32.469s / 12000s | Acc: 12.17%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 48.723s / 12000s | Acc: 12.30%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 64.976s / 12000s | Acc: 12.24%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 81.154s / 12000s | Acc: 12.52%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 97.331s / 12000s | Acc: 12.65%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 113.509s / 12000s | Acc: 12.65%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 129.762s / 12000s | Acc: 12.82%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 146.016s / 12000s | Acc: 13.03%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 162.269s / 12000s | Acc: 12.99%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 178.447s / 12000s | Acc: 13.24%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 194.739s / 12000s | Acc: 13.26%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 210.992s / 12000s | Acc: 13.51%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 227.170s / 12000s | Acc: 13.51%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 243.347s / 12000s | Acc: 13.64%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 259.525s / 12000s | Acc: 13.61%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 275.702s / 12000s | Acc: 13.40%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 291.879s / 12000s | Acc: 13.19%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 308.057s / 12000s | Acc: 13.32%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 324.234s / 12000s | Acc: 12.95%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 340.488s / 12000s | Acc: 13.46%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 356.665s / 12000s | Acc: 13.23%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 372.843s / 12000s | Acc: 13.06%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 389.020s / 12000s | Acc: 12.85%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 405.198s / 12000s | Acc: 12.69%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 421.451s / 12000s | Acc: 13.06%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 437.629s / 12000s | Acc: 12.94%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 453.806s / 12000s | Acc: 12.65%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 470.060s / 12000s | Acc: 13.17%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 486.237s / 12000s | Acc: 12.99%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 502.491s / 12000s | Acc: 13.43%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 518.668s / 12000s | Acc: 13.30%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 534.846s / 12000s | Acc: 13.14%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 551.138s / 12000s | Acc: 12.75%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 567.429s / 12000s | Acc: 12.45%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 583.683s / 12000s | Acc: 12.75%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 599.860s / 12000s | Acc: 12.68%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 616.038s / 12000s | Acc: 12.61%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 632.291s / 12000s | Acc: 12.93%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 648.469s / 12000s | Acc: 12.88%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 664.646s / 12000s | Acc: 12.80%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 680.824s / 12000s | Acc: 12.78%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 697.001s / 12000s | Acc: 12.66%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 713.255s / 12000s | Acc: 13.09%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 729.432s / 12000s | Acc: 12.98%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 745.686s / 12000s | Acc: 13.34%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 761.863s / 12000s | Acc: 13.34%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 778.041s / 12000s | Acc: 13.24%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 794.218s / 12000s | Acc: 13.21%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 810.396s / 12000s | Acc: 13.25%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 826.687s / 12000s | Acc: 12.95%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 842.941s / 12000s | Acc: 13.12%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 859.233s / 12000s | Acc: 12.67%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 875.486s / 12000s | Acc: 12.96%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 891.740s / 12000s | Acc: 13.38%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 907.993s / 12000s | Acc: 13.77%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 924.171s / 12000s | Acc: 13.69%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 940.348s / 12000s | Acc: 13.69%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 956.526s / 12000s | Acc: 13.57%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 972.703s / 12000s | Acc: 13.51%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 988.881s / 12000s | Acc: 13.62%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1005.058s / 12000s | Acc: 13.60%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1021.312s / 12000s | Acc: 13.86%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1037.489s / 12000s | Acc: 13.84%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1053.667s / 12000s | Acc: 13.88%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1069.844s / 12000s | Acc: 13.97%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1086.022s / 12000s | Acc: 14.05%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1102.275s / 12000s | Acc: 14.15%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1118.453s / 12000s | Acc: 14.22%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1134.744s / 12000s | Acc: 13.93%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1150.998s / 12000s | Acc: 14.06%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1167.175s / 12000s | Acc: 14.09%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1183.353s / 12000s | Acc: 14.16%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1199.606s / 12000s | Acc: 14.27%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1215.860s / 12000s | Acc: 14.55%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1232.113s / 12000s | Acc: 14.99%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1248.367s / 12000s | Acc: 15.19%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1264.544s / 12000s | Acc: 15.20%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1280.722s / 12000s | Acc: 15.08%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1296.899s / 12000s | Acc: 14.96%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1313.153s / 12000s | Acc: 15.34%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1329.407s / 12000s | Acc: 15.65%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1345.584s / 12000s | Acc: 15.60%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1361.761s / 12000s | Acc: 15.48%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1377.939s / 12000s | Acc: 15.33%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1394.116s / 12000s | Acc: 15.24%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1410.370s / 12000s | Acc: 15.54%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1426.623s / 12000s | Acc: 16.01%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1442.877s / 12000s | Acc: 16.33%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1459.054s / 12000s | Acc: 16.27%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1475.232s / 12000s | Acc: 16.04%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1491.485s / 12000s | Acc: 16.50%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1507.739s / 12000s | Acc: 16.93%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1523.916s / 12000s | Acc: 16.77%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1540.170s / 12000s | Acc: 17.24%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1556.347s / 12000s | Acc: 17.10%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1572.525s / 12000s | Acc: 16.94%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1588.702s / 12000s | Acc: 16.71%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1604.880s / 12000s | Acc: 16.58%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1621.057s / 12000s | Acc: 16.38%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1637.235s / 12000s | Acc: 16.27%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1653.488s / 12000s | Acc: 16.65%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1669.666s / 12000s | Acc: 16.49%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1685.843s / 12000s | Acc: 16.40%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1702.097s / 12000s | Acc: 16.75%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1718.274s / 12000s | Acc: 16.56%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1734.452s / 12000s | Acc: 16.46%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1750.705s / 12000s | Acc: 16.86%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1766.883s / 12000s | Acc: 16.67%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1783.060s / 12000s | Acc: 16.52%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1799.238s / 12000s | Acc: 16.42%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1815.415s / 12000s | Acc: 16.32%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1831.707s / 12000s | Acc: 16.17%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1847.961s / 12000s | Acc: 16.42%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1864.214s / 12000s | Acc: 16.68%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1880.468s / 12000s | Acc: 17.11%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1896.721s / 12000s | Acc: 17.54%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1912.899s / 12000s | Acc: 17.31%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1929.152s / 12000s | Acc: 17.82%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1945.330s / 12000s | Acc: 17.54%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1961.583s / 12000s | Acc: 18.15%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1977.837s / 12000s | Acc: 18.52%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 1994.014s / 12000s | Acc: 18.32%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2010.192s / 12000s | Acc: 17.95%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2026.369s / 12000s | Acc: 17.72%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2042.547s / 12000s | Acc: 17.47%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2058.800s / 12000s | Acc: 17.90%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2075.054s / 12000s | Acc: 18.52%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2091.231s / 12000s | Acc: 18.23%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2107.409s / 12000s | Acc: 17.94%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2123.586s / 12000s | Acc: 17.74%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2139.763s / 12000s | Acc: 17.45%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2155.941s / 12000s | Acc: 17.34%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2172.118s / 12000s | Acc: 17.24%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2188.410s / 12000s | Acc: 16.93%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2204.588s / 12000s | Acc: 16.87%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2220.765s / 12000s | Acc: 16.77%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2237.019s / 12000s | Acc: 17.05%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2253.196s / 12000s | Acc: 16.96%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2269.488s / 12000s | Acc: 16.65%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2285.780s / 12000s | Acc: 16.53%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2301.957s / 12000s | Acc: 16.44%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2318.135s / 12000s | Acc: 16.37%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2334.312s / 12000s | Acc: 16.35%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2350.490s / 12000s | Acc: 16.41%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2366.667s / 12000s | Acc: 16.50%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2382.921s / 12000s | Acc: 16.55%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2399.098s / 12000s | Acc: 16.56%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2415.276s / 12000s | Acc: 16.61%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2431.453s / 12000s | Acc: 16.66%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2447.707s / 12000s | Acc: 16.68%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2463.884s / 12000s | Acc: 16.72%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2480.062s / 12000s | Acc: 16.75%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2496.239s / 12000s | Acc: 16.83%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2512.531s / 12000s | Acc: 16.63%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2528.708s / 12000s | Acc: 16.68%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2544.962s / 12000s | Acc: 16.70%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2561.215s / 12000s | Acc: 16.76%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2577.393s / 12000s | Acc: 16.73%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2593.646s / 12000s | Acc: 16.83%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2609.824s / 12000s | Acc: 16.83%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2626.077s / 12000s | Acc: 16.97%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2642.331s / 12000s | Acc: 17.19%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2658.508s / 12000s | Acc: 17.13%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2674.686s / 12000s | Acc: 17.12%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2690.939s / 12000s | Acc: 17.28%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2707.117s / 12000s | Acc: 17.24%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2723.294s / 12000s | Acc: 17.29%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2739.472s / 12000s | Acc: 17.25%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2755.725s / 12000s | Acc: 17.44%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2771.979s / 12000s | Acc: 17.75%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2788.156s / 12000s | Acc: 17.66%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2804.334s / 12000s | Acc: 17.53%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2820.511s / 12000s | Acc: 17.48%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2836.765s / 12000s | Acc: 17.76%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2852.942s / 12000s | Acc: 17.61%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2869.196s / 12000s | Acc: 17.87%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2885.373s / 12000s | Acc: 17.86%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2901.665s / 12000s | Acc: 17.57%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2917.842s / 12000s | Acc: 17.48%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2934.020s / 12000s | Acc: 17.47%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2950.197s / 12000s | Acc: 17.42%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2966.489s / 12000s | Acc: 17.23%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2982.743s / 12000s | Acc: 17.38%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 2998.920s / 12000s | Acc: 17.37%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3015.174s / 12000s | Acc: 17.50%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3031.427s / 12000s | Acc: 17.82%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3047.605s / 12000s | Acc: 17.76%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3063.782s / 12000s | Acc: 17.64%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3079.960s / 12000s | Acc: 17.57%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3096.137s / 12000s | Acc: 17.60%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3112.391s / 12000s | Acc: 17.77%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3128.644s / 12000s | Acc: 18.05%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3144.898s / 12000s | Acc: 18.38%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3161.075s / 12000s | Acc: 18.22%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3177.253s / 12000s | Acc: 18.17%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3193.506s / 12000s | Acc: 18.49%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3209.760s / 12000s | Acc: 18.89%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3226.013s / 12000s | Acc: 19.47%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3242.267s / 12000s | Acc: 20.08%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3258.520s / 12000s | Acc: 20.82%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3274.698s / 12000s | Acc: 20.44%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3290.875s / 12000s | Acc: 20.07%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3307.129s / 12000s | Acc: 20.78%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3323.382s / 12000s | Acc: 21.62%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3339.560s / 12000s | Acc: 21.23%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3355.737s / 12000s | Acc: 20.71%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3371.991s / 12000s | Acc: 21.57%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3388.168s / 12000s | Acc: 21.04%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3404.346s / 12000s | Acc: 20.60%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3420.523s / 12000s | Acc: 20.16%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3436.777s / 12000s | Acc: 20.92%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3453.030s / 12000s | Acc: 21.84%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3469.208s / 12000s | Acc: 21.35%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3485.461s / 12000s | Acc: 22.27%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3501.639s / 12000s | Acc: 21.70%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3517.816s / 12000s | Acc: 21.13%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3534.070s / 12000s | Acc: 22.10%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3550.323s / 12000s | Acc: 23.15%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3566.577s / 12000s | Acc: 24.45%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3582.830s / 12000s | Acc: 25.40%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3599.008s / 12000s | Acc: 24.84%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3615.185s / 12000s | Acc: 24.14%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3631.363s / 12000s | Acc: 23.38%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3647.540s / 12000s | Acc: 22.66%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3663.718s / 12000s | Acc: 22.05%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3680.009s / 12000s | Acc: 21.65%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3696.187s / 12000s | Acc: 21.08%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3712.440s / 12000s | Acc: 22.06%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3728.694s / 12000s | Acc: 23.29%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3744.948s / 12000s | Acc: 24.70%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3761.125s / 12000s | Acc: 23.84%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3777.379s / 12000s | Acc: 25.08%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3793.556s / 12000s | Acc: 24.32%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3809.733s / 12000s | Acc: 23.48%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3825.987s / 12000s | Acc: 24.80%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3842.164s / 12000s | Acc: 24.09%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3858.342s / 12000s | Acc: 23.34%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3874.595s / 12000s | Acc: 24.64%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3890.773s / 12000s | Acc: 23.86%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3907.065s / 12000s | Acc: 23.44%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3923.357s / 12000s | Acc: 22.80%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3939.610s / 12000s | Acc: 24.16%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3955.788s / 12000s | Acc: 23.41%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3971.965s / 12000s | Acc: 22.65%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 3988.257s / 12000s | Acc: 22.09%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4004.434s / 12000s | Acc: 21.39%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4020.726s / 12000s | Acc: 21.04%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4037.018s / 12000s | Acc: 20.43%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4053.271s / 12000s | Acc: 21.51%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4069.449s / 12000s | Acc: 21.03%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4085.626s / 12000s | Acc: 20.51%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4101.880s / 12000s | Acc: 21.54%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4118.057s / 12000s | Acc: 21.07%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4134.235s / 12000s | Acc: 20.66%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4150.412s / 12000s | Acc: 20.11%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4166.704s / 12000s | Acc: 19.71%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4182.958s / 12000s | Acc: 20.59%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4199.135s / 12000s | Acc: 20.17%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4215.313s / 12000s | Acc: 19.84%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4231.566s / 12000s | Acc: 20.80%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4247.858s / 12000s | Acc: 20.18%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4264.035s / 12000s | Acc: 19.76%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4280.213s / 12000s | Acc: 19.53%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4296.466s / 12000s | Acc: 20.37%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4312.720s / 12000s | Acc: 21.45%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4328.973s / 12000s | Acc: 22.62%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4345.227s / 12000s | Acc: 24.22%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4361.404s / 12000s | Acc: 23.44%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4377.582s / 12000s | Acc: 22.59%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4393.835s / 12000s | Acc: 24.26%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4410.089s / 12000s | Acc: 25.57%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4426.342s / 12000s | Acc: 27.01%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4442.596s / 12000s | Acc: 28.40%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4458.773s / 12000s | Acc: 27.57%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4474.951s / 12000s | Acc: 26.71%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4491.204s / 12000s | Acc: 28.13%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4507.458s / 12000s | Acc: 29.46%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4523.712s / 12000s | Acc: 30.52%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4539.965s / 12000s | Acc: 31.50%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4556.219s / 12000s | Acc: 32.25%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4572.396s / 12000s | Acc: 31.81%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4588.574s / 12000s | Acc: 31.26%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4604.751s / 12000s | Acc: 30.51%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4621.005s / 12000s | Acc: 31.55%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4637.182s / 12000s | Acc: 30.91%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4653.359s / 12000s | Acc: 30.15%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4669.537s / 12000s | Acc: 29.51%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4685.714s / 12000s | Acc: 28.71%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4701.968s / 12000s | Acc: 29.94%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4718.145s / 12000s | Acc: 29.28%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4734.323s / 12000s | Acc: 28.48%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4750.576s / 12000s | Acc: 29.81%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4766.754s / 12000s | Acc: 28.99%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4782.931s / 12000s | Acc: 28.15%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4799.109s / 12000s | Acc: 27.27%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4815.362s / 12000s | Acc: 28.80%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4831.540s / 12000s | Acc: 27.94%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4847.793s / 12000s | Acc: 29.34%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4863.971s / 12000s | Acc: 28.59%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4880.148s / 12000s | Acc: 27.62%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4896.326s / 12000s | Acc: 26.76%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4912.503s / 12000s | Acc: 25.91%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4928.757s / 12000s | Acc: 27.43%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4945.010s / 12000s | Acc: 28.86%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4961.302s / 12000s | Acc: 28.59%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4977.480s / 12000s | Acc: 27.68%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 4993.657s / 12000s | Acc: 26.88%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5009.911s / 12000s | Acc: 28.29%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5026.088s / 12000s | Acc: 27.52%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5042.266s / 12000s | Acc: 26.60%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5058.443s / 12000s | Acc: 25.79%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5074.620s / 12000s | Acc: 24.95%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5090.912s / 12000s | Acc: 24.67%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5107.166s / 12000s | Acc: 26.16%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5123.419s / 12000s | Acc: 27.70%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5139.597s / 12000s | Acc: 26.84%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5155.774s / 12000s | Acc: 26.03%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5171.952s / 12000s | Acc: 25.21%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5188.129s / 12000s | Acc: 24.55%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5204.307s / 12000s | Acc: 23.81%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5220.560s / 12000s | Acc: 25.27%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5236.814s / 12000s | Acc: 26.64%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5252.991s / 12000s | Acc: 25.92%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5269.283s / 12000s | Acc: 25.65%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5285.537s / 12000s | Acc: 27.07%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5301.714s / 12000s | Acc: 26.28%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5317.968s / 12000s | Acc: 27.88%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5334.145s / 12000s | Acc: 26.86%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5350.322s / 12000s | Acc: 26.11%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5366.500s / 12000s | Acc: 25.42%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5382.753s / 12000s | Acc: 26.86%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5398.931s / 12000s | Acc: 26.08%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5415.108s / 12000s | Acc: 25.35%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5431.286s / 12000s | Acc: 24.70%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5447.463s / 12000s | Acc: 24.04%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5463.717s / 12000s | Acc: 25.43%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5479.970s / 12000s | Acc: 26.86%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5496.148s / 12000s | Acc: 26.09%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5512.325s / 12000s | Acc: 25.37%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5528.503s / 12000s | Acc: 24.74%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5544.680s / 12000s | Acc: 24.05%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5560.858s / 12000s | Acc: 23.35%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5577.035s / 12000s | Acc: 22.74%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5593.213s / 12000s | Acc: 22.25%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5609.466s / 12000s | Acc: 23.47%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5625.720s / 12000s | Acc: 24.87%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5641.897s / 12000s | Acc: 24.21%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5658.075s / 12000s | Acc: 23.55%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5674.328s / 12000s | Acc: 24.97%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5690.506s / 12000s | Acc: 24.32%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5706.759s / 12000s | Acc: 25.64%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5723.013s / 12000s | Acc: 27.30%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5739.190s / 12000s | Acc: 26.36%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5755.368s / 12000s | Acc: 25.64%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5771.621s / 12000s | Acc: 27.31%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5787.799s / 12000s | Acc: 26.37%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5804.052s / 12000s | Acc: 28.02%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5820.344s / 12000s | Acc: 27.79%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5836.598s / 12000s | Acc: 29.23%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5852.775s / 12000s | Acc: 28.36%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5869.029s / 12000s | Acc: 29.91%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5885.206s / 12000s | Acc: 29.05%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5901.384s / 12000s | Acc: 28.26%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5917.675s / 12000s | Acc: 28.01%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5933.853s / 12000s | Acc: 27.23%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5950.145s / 12000s | Acc: 26.93%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5966.398s / 12000s | Acc: 28.39%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5982.576s / 12000s | Acc: 27.76%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 5998.753s / 12000s | Acc: 26.96%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 6014.931s / 12000s | Acc: 26.29%
# Probability Policy: [Max: 57.28% - (Device 6) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# ...
# Time: 10011.731s / 12000s | Acc: 9.68%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10027.909s / 12000s | Acc: 9.68%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10044.086s / 12000s | Acc: 9.70%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10060.264s / 12000s | Acc: 9.70%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10076.441s / 12000s | Acc: 9.71%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10092.619s / 12000s | Acc: 9.71%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10108.796s / 12000s | Acc: 9.70%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10124.974s / 12000s | Acc: 9.70%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10141.151s / 12000s | Acc: 9.70%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10157.328s / 12000s | Acc: 9.71%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10173.506s / 12000s | Acc: 9.72%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10189.683s / 12000s | Acc: 9.72%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10205.861s / 12000s | Acc: 9.72%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10222.038s / 12000s | Acc: 9.74%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10238.216s / 12000s | Acc: 9.76%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10254.393s / 12000s | Acc: 9.76%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10270.571s / 12000s | Acc: 9.76%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10286.748s / 12000s | Acc: 9.76%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10302.926s / 12000s | Acc: 9.77%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10319.103s / 12000s | Acc: 9.78%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10335.281s / 12000s | Acc: 9.78%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10351.458s / 12000s | Acc: 9.79%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10367.636s / 12000s | Acc: 9.80%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10383.813s / 12000s | Acc: 9.80%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10399.991s / 12000s | Acc: 9.80%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10416.168s / 12000s | Acc: 9.81%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10432.346s / 12000s | Acc: 9.81%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10448.523s / 12000s | Acc: 9.81%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10464.700s / 12000s | Acc: 9.81%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10480.878s / 12000s | Acc: 9.81%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10497.055s / 12000s | Acc: 9.81%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10513.233s / 12000s | Acc: 9.82%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10529.410s / 12000s | Acc: 9.82%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10545.588s / 12000s | Acc: 9.82%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10561.765s / 12000s | Acc: 9.83%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10577.943s / 12000s | Acc: 9.83%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10594.120s / 12000s | Acc: 9.83%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10610.298s / 12000s | Acc: 9.83%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10626.475s / 12000s | Acc: 9.83%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10642.653s / 12000s | Acc: 9.84%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10658.830s / 12000s | Acc: 9.85%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10675.008s / 12000s | Acc: 9.86%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10691.185s / 12000s | Acc: 9.86%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10707.363s / 12000s | Acc: 9.88%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10724.062s / 12000s | Acc: 9.85%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10740.239s / 12000s | Acc: 9.87%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10756.417s / 12000s | Acc: 9.88%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10772.594s / 12000s | Acc: 9.88%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10788.772s / 12000s | Acc: 9.89%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10804.949s / 12000s | Acc: 9.92%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10821.127s / 12000s | Acc: 9.92%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10837.304s / 12000s | Acc: 9.93%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10853.482s / 12000s | Acc: 9.93%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10869.659s / 12000s | Acc: 9.93%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10885.837s / 12000s | Acc: 9.94%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10902.014s / 12000s | Acc: 9.94%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10918.192s / 12000s | Acc: 9.94%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10934.369s / 12000s | Acc: 9.94%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10951.225s / 12000s | Acc: 9.94%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10967.402s / 12000s | Acc: 9.94%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 10983.579s / 12000s | Acc: 9.94%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 11000.133s / 12000s | Acc: 9.94%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 11016.311s / 12000s | Acc: 9.95%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 11032.488s / 12000s | Acc: 9.97%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 11048.666s / 12000s | Acc: 9.97%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 11064.843s / 12000s | Acc: 9.97%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 11081.021s / 12000s | Acc: 9.98%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 11097.198s / 12000s | Acc: 9.99%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 11113.376s / 12000s | Acc: 10.01%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 11129.553s / 12000s | Acc: 10.03%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.11% | Std: 17.06% | Sum: 100.00% ]
# Time: 11145.731s / 12000s | Acc: 10.03%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11161.908s / 12000s | Acc: 10.06%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11178.086s / 12000s | Acc: 10.07%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11194.263s / 12000s | Acc: 10.07%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11210.441s / 12000s | Acc: 10.08%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11226.618s / 12000s | Acc: 10.09%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11242.795s / 12000s | Acc: 10.09%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11258.973s / 12000s | Acc: 10.09%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11275.150s / 12000s | Acc: 10.10%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11291.328s / 12000s | Acc: 10.13%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11307.505s / 12000s | Acc: 10.14%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11323.683s / 12000s | Acc: 10.14%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11339.860s / 12000s | Acc: 10.14%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11356.038s / 12000s | Acc: 10.14%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11372.215s / 12000s | Acc: 10.14%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11388.393s / 12000s | Acc: 10.14%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11404.570s / 12000s | Acc: 10.14%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11420.748s / 12000s | Acc: 10.14%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11437.001s / 12000s | Acc: 10.14%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11453.179s / 12000s | Acc: 10.14%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11469.356s / 12000s | Acc: 10.14%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11485.534s / 12000s | Acc: 10.14%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11501.711s / 12000s | Acc: 10.14%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11517.889s / 12000s | Acc: 10.14%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11534.066s / 12000s | Acc: 10.14%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11550.244s / 12000s | Acc: 10.15%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11566.421s / 12000s | Acc: 10.15%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11582.598s / 12000s | Acc: 10.16%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11598.776s / 12000s | Acc: 10.16%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11614.953s / 12000s | Acc: 10.16%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11631.399s / 12000s | Acc: 10.16%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11647.576s / 12000s | Acc: 10.16%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11663.754s / 12000s | Acc: 10.17%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11679.931s / 12000s | Acc: 10.18%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11696.109s / 12000s | Acc: 10.18%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11712.286s / 12000s | Acc: 10.19%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11728.464s / 12000s | Acc: 10.20%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11744.641s / 12000s | Acc: 10.21%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11760.819s / 12000s | Acc: 10.23%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11776.996s / 12000s | Acc: 10.23%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11793.174s / 12000s | Acc: 10.24%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11809.351s / 12000s | Acc: 10.26%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11825.529s / 12000s | Acc: 10.26%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11841.706s / 12000s | Acc: 10.26%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11857.884s / 12000s | Acc: 10.27%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11874.061s / 12000s | Acc: 10.27%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11890.239s / 12000s | Acc: 10.27%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11906.416s / 12000s | Acc: 10.27%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11922.594s / 12000s | Acc: 10.27%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11938.771s / 12000s | Acc: 10.28%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11954.948s / 12000s | Acc: 10.28%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11971.126s / 12000s | Acc: 10.28%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 11987.303s / 12000s | Acc: 10.28%
# Probability Policy: [Max: 95.19% - (Device 6) | Min: 0.10% | Std: 17.06% | Sum: 100.00% ]
# Time: 12003.481s / 12000s | Acc: 10.32%

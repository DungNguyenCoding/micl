# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Subset
from torchvision import datasets, transforms
import numpy as np
import matplotlib.pyplot as plt
import collections
import random

# %%
# --- 1. Wireless Environment Parameters ---
B_HZ = 1e6              # 1 MHz
N0_DBM_HZ = -174        # Noise density
P_TX_CLIENT_DBM = 24    # Uplink Power
P_TX_SERVER_DBM = 46    # Downlink Power (Server)
Q_BITS = 16             # 16-bit quantization
RADIUS_KM = 0.5         # 500m
DEVICE_GFLOPS = 2.0     # Average edge device speed (2 Billion operations/sec)

# %%
def plot_radar_map(r_km):
    """
    Plots 30 devices in a circular layout with index labels.
    Red triangle = Edge Server (Center)
    Blue dots = Edge Devices (Labeled 0-29)
    """
    # Generate random angles (theta) in radians
    theta = 2 * np.pi * np.random.rand(len(r_km)) 
    
    # Convert polar (r, theta) to Cartesian (x, y) for easier labeling
    x = r_km * np.cos(theta)
    y = r_km * np.sin(theta)
    
    plt.figure(figsize=(8, 8))
    
    # Plot the circular boundary (500m radius)
    circle = plt.Circle((0, 0), RADIUS_KM, color='gray', fill=False, linestyle='--', alpha=0.5)
    plt.gca().add_patch(circle)
    
    # Plot Edge Server at the center (0,0)
    plt.scatter(0, 0, c='red', marker='^', s=150, label='Edge Server', zorder=5)
    
    # Plot Edge Devices
    plt.scatter(x, y, c='skyblue', edgecolors='navy', s=80, alpha=0.8, label='Edge Devices')
    
    # Add Index Labels (0 to 29) for each device
    for i in range(len(r_km)):
        plt.annotate(f'{i}', (x[i], y[i]), xytext=(5, 5), 
                     textcoords='offset points', fontsize=9, fontweight='bold')

    plt.title(f"Device Distribution ({RADIUS_KM*1000}m Radius)")
    plt.xlabel("Distance (km)")
    plt.ylabel("Distance (km)")
    plt.legend(loc='upper right')
    plt.grid(True, alpha=0.2)
    plt.axis('equal') # Keep the circle from looking like an oval
    plt.xlim(-RADIUS_KM - 0.1, RADIUS_KM + 0.1)
    plt.ylim(-RADIUS_KM - 0.1, RADIUS_KM + 0.1)
    plt.show()

# %%
# --- 2. Model Architectures ---

class SVMModel(nn.Module):
    def __init__(self):
        super(SVMModel, self).__init__()
        self.fc = nn.Linear(3072, 1)
    def forward(self, x):
        return self.fc(x.view(x.size(0), -1))

class CNNModel(nn.Module):
    def __init__(self):
        super(CNNModel, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(1, 32, 5), nn.ReLU(), nn.MaxPool2d(2, 2),
            nn.Conv2d(32, 64, 5), nn.ReLU(), nn.MaxPool2d(2, 2)
        )
        self.fc = nn.Sequential(nn.Linear(64 * 4 * 4, 512), nn.ReLU(), nn.Linear(512, 10))
    def forward(self, x):
        x = self.conv(x)
        return self.fc(x.view(x.size(0), -1))

# %%
# --- 3. Data Preparation ---

def get_datasets(task='CNN'):
    # Define a shared seed for reproducibility if needed, 
    # or remove it for different random splits each time.
    random.seed(42) 
    np.random.seed(42)

    if task == 'SVM':
        transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])
        train_set = datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
        test_set = datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
        
        train_idx = [i for i, l in enumerate(train_set.targets) if l in [0, 1]]
        test_idx = [i for i, l in enumerate(test_set.targets) if l in [0, 1]]
        
        airplanes = [i for i in train_idx if train_set.targets[i] == 0][:15*330]
        autos = [i for i in train_idx if train_set.targets[i] == 1][:15*330]
        
        # Create the raw list of 30 Subsets
        all_subsets = [Subset(train_set, airplanes[i*330:(i+1)*330]) for i in range(15)] + \
                       [Subset(train_set, autos[i*330:(i+1)*330]) for i in range(15)]
        
        # RANDOMIZATION: Shuffle the list so 'Airplane devices' are spread 0-29
        random.shuffle(all_subsets)
        device_data = all_subsets
        
        return device_data, Subset(test_set, test_idx), SVMModel(), 0.0001

    else: # CNN Task (MNIST)
        transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))])
        train_set = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
        test_set = datasets.MNIST(root='./data', train=False, download=True, transform=transform)
        
        # Pathological Non-IID: Sort by label to create shards
        indices = np.argsort(train_set.targets.numpy())
        shards = [indices[i*1000 : (i+1)*1000] for i in range(60)]
        
        # RANDOMIZATION: Shuffle the shards so Device 0 doesn't 
        # automatically get the 'lowest' labels (0 and 1)
        random.shuffle(shards)
        
        # Each device gets 2 random shards (each shard is likely 1 digit)
        device_data = [Subset(train_set, np.concatenate((shards[i*2], shards[i*2+1]))) for i in range(30)]
        
        return device_data, test_set, CNNModel(), 0.005
    
def observe_distribution(device_data, task='CNN'):
    # Determine how many classes to show
    num_labels = 10 if task == 'CNN' else 2
    distribution_matrix = np.zeros((30, num_labels))

    for i in range(30):
        subset = device_data[i]
        # Robustly handle different dataset target formats
        targets = subset.dataset.targets
        subset_labels = [int(targets[idx]) for idx in subset.indices]
        
        counts = collections.Counter(subset_labels)
        for label, count in counts.items():
            # For SVM, only record if label is 0 or 1
            if label < num_labels:
                distribution_matrix[i, label] = count

    # Plotting
    plt.figure(figsize=(8, 8)) # Narrower figure for 2 columns
    im = plt.imshow(distribution_matrix, cmap='YlGnBu', aspect='auto')
    
    plt.colorbar(im, label='Number of Samples')
    plt.title(f'Non-IID Heatmap: {task} Task', fontsize=14)
    plt.xlabel('Class Label', fontsize=12)
    plt.ylabel('Device Index', fontsize=12)
    
    # Set x-ticks specifically to the number of labels
    plt.xticks(range(num_labels))
    # If SVM, label them appropriately
    if task == 'SVM':
        plt.gca().set_xticklabels(['0 (Airplane)', '1 (Auto)'])
    
    plt.yticks(range(0, 30, 2))
    plt.tight_layout()
    plt.show()

# %%
def get_optimal_probabilities(n_k_list, grad_norms, T_u_list, rho):
    """
    Implements Theorem 1 - Importance- and channel-aware scheduling policy.
    """
    n_total = sum(n_k_list)
    grad_norms = np.array(grad_norms) + 1e-12 
    T_u_list = np.array(T_u_list)
    num_devices = len(n_k_list)

    floor_value = 0.0001 # Each device gets at least 1% chance
    total_floor = num_devices * floor_value
    remaining_budget = 1.0 - total_floor

    def apply_gaussian_top3(values, reverse=False):
        # 1. Start everyone with the 1% floor
        p = np.full(num_devices, floor_value)
        
        # 2. Identify the Top 3
        sorted_indices = np.argsort(values)
        if not reverse:
            sorted_indices = sorted_indices[::-1]
            
        # 3. Distribute the remaining 40% budget using Gaussian weights
        # Weights: Rank1 (1.0), Rank2 (0.606), Rank3 (0.135) -> Sum = 1.741
        raw_weights = np.array([1.0, 0.606, 0.135])
        normalized_weights = raw_weights / np.sum(raw_weights) # Scale to sum to 1.0
        
        # Add the budgeted share to the floor
        p[sorted_indices[0]] += normalized_weights[0] * remaining_budget
        p[sorted_indices[1]] += normalized_weights[1] * remaining_budget
        p[sorted_indices[2]] += normalized_weights[2] * remaining_budget
        
        return p

    # 1. New Behavior for rho = 0 (Channel-aware: Top 3 Fastest)
    if rho == 0:
        return apply_gaussian_top3(T_u_list, reverse=True)

    # 2. New Behavior for rho = 1 (Importance-aware: Top 3 Most Informative)
    if rho == 1:
        # Importance includes data weight n_k/n
        importance = (np.array(n_k_list) / n_total) * grad_norms
        return apply_gaussian_top3(importance, reverse=False)

    # 3. Proposed Policy (Intermediate rho)
    def compute_p_star(lam):
        denom = (1 - rho) * T_u_list + lam
        p = (np.array(n_k_list) / n_total) * grad_norms * np.sqrt(rho / np.maximum(denom, 1e-15))
        return p

    low = -np.min((1 - rho) * T_u_list) + 1e-12
    high = 1e6 
    
    for _ in range(100):
        mid = (low + high) / 2
        if np.sum(compute_p_star(mid)) > 1: low = mid
        else: high = mid

    lambda_star  = high
    final_p_raw = compute_p_star(lambda_star)
    return final_p_raw / np.sum(final_p_raw)

# %%
def get_multi_device_selection(n_k_list, grad_norms, T_u_list_full_B, rho, M):
    """
    Implements Algorithm 1: Importance- and Channel-Aware Scheduling 
    without replacement for M devices.
    """

    num_devices = len(n_k_list)

    # --- Pure Channel-Aware (Fastest M) ---
    if rho == 0:
        # Get indices of the M smallest latency values
        selected_indices = np.argsort(T_u_list_full_B)[:M].tolist()
        # Create a uniform p_star just for logging purposes
        p_star = np.zeros(num_devices)
        p_star[selected_indices] = 1.0 / M
        return selected_indices, p_star
    
    # --- Pure Importance-Aware ---
    if rho == 1:
        # Importance calculation consistent with Equation 14
        importance = (np.array(n_k_list) / sum(n_k_list)) * np.array(grad_norms)
        # Get indices of the M largest importance values
        selected_indices = np.argsort(importance)[-M:][::-1].tolist()
        # Create a uniform p_star for logging
        p_star = np.zeros(num_devices)
        p_star[selected_indices] = 1.0 / M
        return selected_indices, p_star
    
    # 1. Compute optimal scheduling distribution P* (Equation 25)
    p_star = get_optimal_probabilities(n_k_list, grad_norms, T_u_list_full_B, rho)
    
    selected_indices = []
    current_p = p_star.copy()
    
    for m in range(M):
        # Normalize current distribution to ensure sum = 1
        current_p = current_p / np.sum(current_p)
        
        # 2. Randomly select device based on conditional distribution
        idx = np.random.choice(range(len(p_star)), p=current_p)
        selected_indices.append(idx)
        
        # 3. The probability for this selected device becomes 0 in the next step
        current_p[idx] = 0
        
    return selected_indices, p_star

# %%
# --- 5. Main Training Logic ---

def run_multi_device_fl(task='SVM', training_time=10, rho=5e-6, M=10, r_km= RADIUS_KM * np.sqrt(np.random.rand(30))):
    device_data, test_set, global_model, lr = get_datasets(task)
    test_loader = DataLoader(test_set, batch_size=1000, shuffle=False)
    n_k_list = [len(d) for d in device_data]
    n_total = sum(n_k_list)
    lmbda = 0.01 
    # Force 5 devices to be at the cell edge (450m - 500m) 
    # and 25 devices to be distributed normally.
    r_km = RADIUS_KM * np.sqrt(np.random.rand(30))
    r_km[:5] = 0.45 + (np.random.rand(5) * 0.05)
    
    history = {'acc': [], 'time': []}
    cumulative_time = 0

    print(f"\n--- Multi-Device Simulation: {task} | M={M} | Training Time: {training_time}s ---")

    while cumulative_time < training_time:
        # Communication Model 
        path_loss_db = 128.1 + 37.6 * np.log10(np.maximum(r_km, 0.01))
        
        noise_up_w = 10**(((N0_DBM_HZ + 10 * np.log10(B_HZ)) - 30) / 10)
        p_rx_up_w = 10**(((P_TX_CLIENT_DBM - path_loss_db) - 30) / 10)
        gamma_up = p_rx_up_w / noise_up_w
        
        p_rx_down_w = 10**(((P_TX_SERVER_DBM - path_loss_db) - 30) / 10)
        gamma_down_min = np.min(p_rx_down_w / noise_up_w) 
        
        num_params = sum(p.numel() for p in global_model.parameters())
        payload_bits = num_params * Q_BITS
        T_u_full_B = payload_bits / (B_HZ * np.log2(1 + gamma_up))

        # Importance Evaluation
        grad_norms = []
        client_gradients = []
        for i in range(30):
            # Step 1: Global Model Broadcast
            local_model = type(global_model)()
            local_model.load_state_dict(global_model.state_dict())
            loader = DataLoader(device_data[i], batch_size=len(device_data[i]))
            data, target = next(iter(loader))
            local_model.zero_grad()

            # Step 2: Local Gradient Calculation
            output = local_model(data).squeeze()
            if task == 'SVM':
                target_svm = (target.float() * 2) - 1 
                loss = 0.5 * torch.mean(torch.clamp(1 - target_svm * output, min=0)) + (lmbda / 2.0) * sum(p.pow(2).sum() for p in local_model.parameters())
            else:
                target_oh = torch.nn.functional.one_hot(target, num_classes=10).float()
                loss = 0.5 * torch.nn.functional.mse_loss(output, target_oh, reduction='mean')
            
            # Step 3: Importance Indicator Report
            loss.backward()
            grads = [p.grad.detach().clone() for p in local_model.parameters()]
            grad_norms.append(torch.norm(torch.cat([g.view(-1) for g in grads])).item())
            client_gradients.append(grads)

        # Step 4: Device Selection and Resource Allocation
        selected_indices, p_star = get_multi_device_selection(n_k_list, grad_norms, T_u_full_B, rho, M)
        print(f"Probability Policy: [Max: {100 * np.max(p_star):.2f}% - (Device {np.argmax(p_star)}) | "
        f"Min: {100 * np.min(p_star):.2f}% | Std: {100 * np.std(p_star):.2f}% | Sum: {100 * np.sum(p_star):.2f}% ]"
        f"\nSelected Devices: {selected_indices}" )

        # Step 5: Local Gradient Upload (Simulate Latency with Bandwidth Allocation - Theorem 3)
        # 1. Calculate the rate per unit bandwidth for selected devices
        R_k = np.log2(1 + gamma_up[selected_indices])
        
        # 2. Apply Theorem 3: Optimal Parallel Upload Time
        # This allows multiple devices to share the 'B' bandwidth efficiently
        sum_sqrt_inv_R = np.sum(np.sqrt(1.0 / R_k))
        t_upload_parallel = (payload_bits / B_HZ) * (sum_sqrt_inv_R**2)
        
        # 3. Standard overheads
        t_broadcast = payload_bits / (B_HZ * np.log2(1 + gamma_down_min))
        t_comp_max = (max(n_k_list) * 6000) / (DEVICE_GFLOPS * 1e9)
        
        # Total time for this specific round
        round_time = t_broadcast + t_comp_max + t_upload_parallel
        cumulative_time += round_time

        # Step 6: Global Model Update (Equation 29)
        with torch.no_grad():
            global_grad_sum = [torch.zeros_like(p) for p in global_model.parameters()]
            
            for m, idx in enumerate(selected_indices):
                # --- Proposed Policy Style (Unbiased Estimator) ---
                # Calculate conditional probability q_Y_m for Theorem 1 correctness
                sum_prev_p = sum(p_star[selected_indices[j]] for j in range(m))
                q_Y_m = p_star[idx] / np.maximum(1.0 - sum_prev_p, 1e-10)
                # Apply importance scale based on Equation 29
                scale = n_k_list[idx] / (n_total * q_Y_m)

                if rho == 0 or rho == 1:
                    # --- FedAvg Style (Simple Average) ---
                    # We ignore the selection probability scaling entirely.
                    # Each of the M selected devices contributes 1/M to the update.
                    for g_sum, g_local in zip(global_grad_sum, client_gradients[idx]):
                        g_sum += (1.0 / M) * scale * g_local
                else:
                    
                    
                    for g_sum, g_local in zip(global_grad_sum, client_gradients[idx]):
                        # Clip only the proposed update to handle potential variance
                        update_val = (1.0 / M) * scale * g_local
                        g_sum += torch.clamp(update_val, min=-10.0, max=10.0)
            
            # Update global weights
            for p_global, g_agg in zip(global_model.parameters(), global_grad_sum):
                p_global -= lr * g_agg

        # Evaluation
        global_model.eval()
        correct, total = 0, 0
        with torch.no_grad():
            for data, target in test_loader:
                output = global_model(data)
                pred = torch.sign(output.squeeze()) if task == 'SVM' else output.argmax(1)
                labels = (target.float()*2-1) if task == 'SVM' else target
                correct += (pred == labels).sum().item()
                total += target.size(0)
        
        acc = 100. * correct / total
        history['acc'].append(acc)
        history['time'].append(cumulative_time)
        
        print(f"Time: {cumulative_time:.3f}s / {training_time}s | Acc: {acc:.2f}%")

    return history

# %%
def run_multi_comparison(task='SVM', training_time=10):
    """
    Executes all multi-device scheduling policies for a specific task and plots the results.
    """
    # Define task-specific parameters based on Section VI.C 
    if task == 'SVM':
        M_devices = 10
        rhos = {0: 'Channel-aware', 
                1: 'Importance-aware',
                5e-4: 'Proposed (5e-4)',
                5e-6: 'Proposed (5e-6)'}
        time_scale = 1 # Seconds
        x_label = "Training Time (seconds)"
    else: # CNN
        M_devices = 3
        rhos = {0: 'Channel-aware', 
                1: 'Importance-aware', 
                1e-2: 'Proposed (1e-2)',
                1e-3: 'Proposed (1e-3)'}
        time_scale = 60 # Minutes
        x_label = "Training Time (minutes)"
    
    results = {}
    # Force 5 devices to be at the cell edge (450m - 500m) 
    # and 25 devices to be distributed normally.
    r_km = RADIUS_KM * np.sqrt(np.random.rand(30))
    r_km[:5] = 0.45 + (np.random.rand(5) * 0.05)
    plot_radar_map(r_km)

    print(f"--- Starting {task} Multi-Device Comparison (M={M_devices}) ---")
    for rho, label in rhos.items():
        print(f"Running {label} (rho={rho})...")
        # Ensure fresh model for each policy run
        results[label] = run_multi_device_fl(task=task, training_time=training_time, rho=rho, M=M_devices, r_km=r_km)

    # --- Plotting Results (Replicating Figure 4) ---
    plt.figure(figsize=(10, 6))
    for label, hist in results.items():
        # Convert time to appropriate scale (seconds or minutes)
        plt.plot(np.array(hist['time']) / time_scale, hist['acc'], label=label)
    
    plt.title(f"Multi-Device Performance Comparison: {task} Model (M={M_devices})")
    plt.xlabel(x_label)
    plt.ylabel("Test Accuracy (%)")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()

# To execute the multi-device simulation:
# run_multi_comparison(task='SVM', training_time=10)
# run_multi_comparison(task='CNN', training_time=50)

# %%
# Force 5 devices to be at the cell edge (450m - 500m) 
# and 25 devices to be distributed normally.
r_km = RADIUS_KM * np.sqrt(np.random.rand(30))
r_km[:5] = 0.45 + (np.random.rand(5) * 0.05)
plot_radar_map(r_km)

# %%
run_multi_device_fl(task='SVM', training_time=0.5, rho=0, M=10, r_km=r_km)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
#
# --- Multi-Device Simulation: SVM | M=10 | Training Time: 0.5s ---
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 0.394s / 0.5s | Acc: 58.35%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 0.788s / 0.5s | Acc: 58.75%
# {'acc': [58.35, 58.75], 'time': [0.39412047627578745, 0.7882409525515749]}

# %%
run_multi_device_fl(task='SVM', training_time=0.5, rho=1, M=10, r_km=r_km)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
#
# --- Multi-Device Simulation: SVM | M=10 | Training Time: 0.5s ---
# Probability Policy: [Max: 10.00% - (Device 1) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [17, 5, 19, 16, 22, 27, 1, 7, 13, 6]
# Time: 0.502s / 0.5s | Acc: 55.55%
# {'acc': [55.55], 'time': [0.5023682074910394]}

# %%
run_multi_device_fl(task='SVM', training_time=0.5, rho=5e-6, M=10, r_km=r_km)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
#
# --- Multi-Device Simulation: SVM | M=10 | Training Time: 0.5s ---
# Probability Policy: [Max: 80.89% - (Device 10) | Min: 0.43% | Std: 14.40% | Sum: 100.00% ]
# Selected Devices: [10, 9, 3, 22, 15, 5, 17, 1, 29, 8]
# Time: 0.495s / 0.5s | Acc: 64.30%
# Probability Policy: [Max: 80.94% - (Device 10) | Min: 0.43% | Std: 14.41% | Sum: 100.00% ]
# Selected Devices: [10, 9, 17, 18, 5, 29, 23, 27, 25, 16]
# Time: 0.981s / 0.5s | Acc: 64.30%
# {'acc': [64.3, 64.3], 'time': [0.4953064547768853, 0.9805993444789352]}

# %%
run_multi_comparison(task='SVM', training_time=700)
# Out:
# --- Starting SVM Multi-Device Comparison (M=10) ---
# Running Channel-aware (rho=0)...
# Files already downloaded and verified
# Files already downloaded and verified
#
# --- Multi-Device Simulation: SVM | M=10 | Training Time: 700s ---
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 0.394s / 700s | Acc: 33.30%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 0.788s / 700s | Acc: 33.35%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 1.182s / 700s | Acc: 33.35%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 1.576s / 700s | Acc: 33.25%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 1.971s / 700s | Acc: 33.25%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 2.365s / 700s | Acc: 33.25%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 2.759s / 700s | Acc: 33.25%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 3.153s / 700s | Acc: 33.25%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 3.547s / 700s | Acc: 33.35%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 3.941s / 700s | Acc: 33.35%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 4.335s / 700s | Acc: 33.35%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 4.729s / 700s | Acc: 33.40%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 5.124s / 700s | Acc: 33.40%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 5.518s / 700s | Acc: 33.40%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 5.912s / 700s | Acc: 33.45%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 6.306s / 700s | Acc: 33.50%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 6.700s / 700s | Acc: 33.45%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 7.094s / 700s | Acc: 33.45%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 7.488s / 700s | Acc: 33.45%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 7.882s / 700s | Acc: 33.50%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 8.277s / 700s | Acc: 33.50%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 8.671s / 700s | Acc: 33.50%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 9.065s / 700s | Acc: 33.50%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 9.459s / 700s | Acc: 33.55%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 9.853s / 700s | Acc: 33.55%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 10.247s / 700s | Acc: 33.55%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 10.641s / 700s | Acc: 33.55%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 11.035s / 700s | Acc: 33.55%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 11.429s / 700s | Acc: 33.55%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 11.824s / 700s | Acc: 33.70%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 12.218s / 700s | Acc: 33.70%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 12.612s / 700s | Acc: 33.65%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 13.006s / 700s | Acc: 33.65%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 13.400s / 700s | Acc: 33.65%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 13.794s / 700s | Acc: 33.70%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 14.188s / 700s | Acc: 33.70%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 14.582s / 700s | Acc: 33.70%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 14.977s / 700s | Acc: 33.75%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 15.371s / 700s | Acc: 33.80%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 15.765s / 700s | Acc: 33.80%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 16.159s / 700s | Acc: 33.85%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 16.553s / 700s | Acc: 33.85%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 16.947s / 700s | Acc: 33.90%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 17.341s / 700s | Acc: 33.95%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 17.735s / 700s | Acc: 34.00%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 18.130s / 700s | Acc: 34.05%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 18.524s / 700s | Acc: 34.05%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 18.918s / 700s | Acc: 34.10%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 19.312s / 700s | Acc: 34.10%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 19.706s / 700s | Acc: 34.10%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 20.100s / 700s | Acc: 34.10%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 20.494s / 700s | Acc: 34.10%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 20.888s / 700s | Acc: 34.10%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 21.283s / 700s | Acc: 34.10%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 21.677s / 700s | Acc: 34.15%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 22.071s / 700s | Acc: 34.10%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 22.465s / 700s | Acc: 34.10%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 22.859s / 700s | Acc: 34.15%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 23.253s / 700s | Acc: 34.20%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 23.647s / 700s | Acc: 34.30%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 24.041s / 700s | Acc: 34.30%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 24.435s / 700s | Acc: 34.30%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 24.830s / 700s | Acc: 34.35%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 25.224s / 700s | Acc: 34.35%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 25.618s / 700s | Acc: 34.35%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 26.012s / 700s | Acc: 34.35%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 26.406s / 700s | Acc: 34.40%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 26.800s / 700s | Acc: 34.40%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 27.194s / 700s | Acc: 34.40%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 27.588s / 700s | Acc: 34.45%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 27.983s / 700s | Acc: 34.50%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 28.377s / 700s | Acc: 34.55%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 28.771s / 700s | Acc: 34.55%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 29.165s / 700s | Acc: 34.55%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 29.559s / 700s | Acc: 34.60%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 29.953s / 700s | Acc: 34.60%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 30.347s / 700s | Acc: 34.60%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 30.741s / 700s | Acc: 34.70%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 31.136s / 700s | Acc: 34.75%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 31.530s / 700s | Acc: 34.85%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 31.924s / 700s | Acc: 34.80%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 32.318s / 700s | Acc: 34.85%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 32.712s / 700s | Acc: 34.90%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 33.106s / 700s | Acc: 34.90%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 33.500s / 700s | Acc: 34.95%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 33.894s / 700s | Acc: 35.00%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 34.288s / 700s | Acc: 35.00%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 34.683s / 700s | Acc: 35.00%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 35.077s / 700s | Acc: 35.05%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 35.471s / 700s | Acc: 35.15%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 35.865s / 700s | Acc: 35.20%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 36.259s / 700s | Acc: 35.15%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 36.653s / 700s | Acc: 35.15%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 37.047s / 700s | Acc: 35.10%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 37.441s / 700s | Acc: 35.10%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 37.836s / 700s | Acc: 35.20%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 38.230s / 700s | Acc: 35.20%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 38.624s / 700s | Acc: 35.20%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 39.018s / 700s | Acc: 35.20%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 39.412s / 700s | Acc: 35.20%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 39.806s / 700s | Acc: 35.25%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 40.200s / 700s | Acc: 35.35%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 40.594s / 700s | Acc: 35.35%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 40.989s / 700s | Acc: 35.35%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 41.383s / 700s | Acc: 35.35%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 41.777s / 700s | Acc: 35.40%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 42.171s / 700s | Acc: 35.40%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 42.565s / 700s | Acc: 35.40%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 42.959s / 700s | Acc: 35.35%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 43.353s / 700s | Acc: 35.40%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 43.747s / 700s | Acc: 35.45%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 44.141s / 700s | Acc: 35.45%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 44.536s / 700s | Acc: 35.45%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 44.930s / 700s | Acc: 35.50%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 45.324s / 700s | Acc: 35.45%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 45.718s / 700s | Acc: 35.45%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 46.112s / 700s | Acc: 35.45%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 46.506s / 700s | Acc: 35.45%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 46.900s / 700s | Acc: 35.40%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 47.294s / 700s | Acc: 35.55%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 47.689s / 700s | Acc: 35.55%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 48.083s / 700s | Acc: 35.55%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 48.477s / 700s | Acc: 35.55%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 48.871s / 700s | Acc: 35.60%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 49.265s / 700s | Acc: 35.60%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 49.659s / 700s | Acc: 35.60%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 50.053s / 700s | Acc: 35.60%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 50.447s / 700s | Acc: 35.65%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 50.842s / 700s | Acc: 35.65%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 51.236s / 700s | Acc: 35.70%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 51.630s / 700s | Acc: 35.70%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 52.024s / 700s | Acc: 35.75%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 52.418s / 700s | Acc: 35.70%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 52.812s / 700s | Acc: 35.70%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 53.206s / 700s | Acc: 35.70%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 53.600s / 700s | Acc: 35.70%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 53.995s / 700s | Acc: 35.80%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 54.389s / 700s | Acc: 35.80%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 54.783s / 700s | Acc: 35.75%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 55.177s / 700s | Acc: 35.75%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 55.571s / 700s | Acc: 35.75%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 55.965s / 700s | Acc: 35.75%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 56.359s / 700s | Acc: 35.75%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 56.753s / 700s | Acc: 35.75%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 57.147s / 700s | Acc: 35.75%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 57.542s / 700s | Acc: 35.85%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 57.936s / 700s | Acc: 35.90%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 58.330s / 700s | Acc: 35.90%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 58.724s / 700s | Acc: 35.95%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 59.118s / 700s | Acc: 35.95%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 59.512s / 700s | Acc: 36.00%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 59.906s / 700s | Acc: 36.00%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 60.300s / 700s | Acc: 36.00%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 60.695s / 700s | Acc: 36.00%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 61.089s / 700s | Acc: 36.00%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 61.483s / 700s | Acc: 36.05%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 61.877s / 700s | Acc: 36.10%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 62.271s / 700s | Acc: 36.15%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 62.665s / 700s | Acc: 36.15%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 63.059s / 700s | Acc: 36.20%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 63.453s / 700s | Acc: 36.25%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 63.848s / 700s | Acc: 36.25%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 64.242s / 700s | Acc: 36.20%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 64.636s / 700s | Acc: 36.30%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 65.030s / 700s | Acc: 36.25%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 65.424s / 700s | Acc: 36.30%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 65.818s / 700s | Acc: 36.35%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 66.212s / 700s | Acc: 36.35%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 66.606s / 700s | Acc: 36.35%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 67.000s / 700s | Acc: 36.55%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 67.395s / 700s | Acc: 36.55%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 67.789s / 700s | Acc: 36.60%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 68.183s / 700s | Acc: 36.55%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 68.577s / 700s | Acc: 36.55%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 68.971s / 700s | Acc: 36.60%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 69.365s / 700s | Acc: 36.70%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 69.759s / 700s | Acc: 36.75%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 70.153s / 700s | Acc: 36.85%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 70.548s / 700s | Acc: 36.85%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 70.942s / 700s | Acc: 36.95%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 71.336s / 700s | Acc: 37.00%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 71.730s / 700s | Acc: 36.95%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 72.124s / 700s | Acc: 36.95%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 72.518s / 700s | Acc: 36.95%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 72.912s / 700s | Acc: 37.05%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 73.306s / 700s | Acc: 37.05%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 73.701s / 700s | Acc: 37.15%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 74.095s / 700s | Acc: 37.30%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 74.489s / 700s | Acc: 37.30%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 74.883s / 700s | Acc: 37.30%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 75.277s / 700s | Acc: 37.30%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 75.671s / 700s | Acc: 37.30%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 76.065s / 700s | Acc: 37.30%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 76.459s / 700s | Acc: 37.35%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 76.853s / 700s | Acc: 37.40%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 77.248s / 700s | Acc: 37.45%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 77.642s / 700s | Acc: 37.55%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 78.036s / 700s | Acc: 37.55%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 78.430s / 700s | Acc: 37.55%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 78.824s / 700s | Acc: 37.55%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 79.218s / 700s | Acc: 37.60%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 79.612s / 700s | Acc: 37.65%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 80.006s / 700s | Acc: 37.80%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 80.401s / 700s | Acc: 37.80%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 80.795s / 700s | Acc: 37.85%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 81.189s / 700s | Acc: 37.85%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 81.583s / 700s | Acc: 37.85%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 81.977s / 700s | Acc: 37.90%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 82.371s / 700s | Acc: 37.90%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 82.765s / 700s | Acc: 37.95%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 83.159s / 700s | Acc: 38.05%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 83.554s / 700s | Acc: 38.15%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 83.948s / 700s | Acc: 38.20%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 84.342s / 700s | Acc: 38.15%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 84.736s / 700s | Acc: 38.15%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 85.130s / 700s | Acc: 38.10%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 85.524s / 700s | Acc: 38.30%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 85.918s / 700s | Acc: 38.30%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 86.312s / 700s | Acc: 38.35%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 86.707s / 700s | Acc: 38.35%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 87.101s / 700s | Acc: 38.30%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 87.495s / 700s | Acc: 38.35%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 87.889s / 700s | Acc: 38.40%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 88.283s / 700s | Acc: 38.45%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 88.677s / 700s | Acc: 38.45%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 89.071s / 700s | Acc: 38.65%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 89.465s / 700s | Acc: 38.65%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 89.859s / 700s | Acc: 38.70%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 90.254s / 700s | Acc: 38.85%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 90.648s / 700s | Acc: 38.85%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 91.042s / 700s | Acc: 38.90%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 91.436s / 700s | Acc: 38.95%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 91.830s / 700s | Acc: 38.95%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 92.224s / 700s | Acc: 38.95%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 92.618s / 700s | Acc: 38.95%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 93.012s / 700s | Acc: 38.95%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 93.407s / 700s | Acc: 38.95%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 93.801s / 700s | Acc: 39.00%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 94.195s / 700s | Acc: 39.00%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 94.589s / 700s | Acc: 39.00%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 94.983s / 700s | Acc: 39.00%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 95.377s / 700s | Acc: 39.15%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 95.771s / 700s | Acc: 39.15%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 96.165s / 700s | Acc: 39.15%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 96.560s / 700s | Acc: 39.15%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 96.954s / 700s | Acc: 39.20%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 97.348s / 700s | Acc: 39.30%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 97.742s / 700s | Acc: 39.35%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 98.136s / 700s | Acc: 39.25%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 98.530s / 700s | Acc: 39.30%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 98.924s / 700s | Acc: 39.30%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 99.318s / 700s | Acc: 39.35%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 99.712s / 700s | Acc: 39.40%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 100.107s / 700s | Acc: 39.45%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 100.501s / 700s | Acc: 39.50%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 100.895s / 700s | Acc: 39.55%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 101.289s / 700s | Acc: 39.65%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 101.683s / 700s | Acc: 39.65%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 102.077s / 700s | Acc: 39.60%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 102.471s / 700s | Acc: 39.70%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 102.865s / 700s | Acc: 39.70%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 103.260s / 700s | Acc: 39.85%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 103.654s / 700s | Acc: 39.85%
# Probability Policy: [Max: 10.00% - (Device 5) | Min: 0.00% | Std: 4.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 6, 21, 5, 14, 15, 26, 13, 19]
# Time: 104.048s / 700s | Acc: 39.95%
# ...
# Time: 658.127s / 700s | Acc: 78.15%
# Probability Policy: [Max: 87.80% - (Device 10) | Min: 0.27% | Std: 15.69% | Sum: 100.00% ]
# Selected Devices: [10, 17, 6, 1, 29, 7, 8, 16, 18, 0]
# Time: 658.628s / 700s | Acc: 78.15%
# Probability Policy: [Max: 87.80% - (Device 10) | Min: 0.27% | Std: 15.69% | Sum: 100.00% ]
# Selected Devices: [10, 13, 21, 6, 15, 19, 28, 9, 3, 17]
# Time: 659.103s / 700s | Acc: 78.15%
# Probability Policy: [Max: 87.80% - (Device 10) | Min: 0.27% | Std: 15.69% | Sum: 100.00% ]
# Selected Devices: [10, 4, 14, 0, 2, 17, 11, 26, 20, 15]
# Time: 659.638s / 700s | Acc: 78.15%
# Probability Policy: [Max: 87.81% - (Device 10) | Min: 0.27% | Std: 15.69% | Sum: 100.00% ]
# Selected Devices: [10, 16, 1, 27, 29, 6, 4, 5, 21, 20]
# Time: 660.103s / 700s | Acc: 78.15%
# Probability Policy: [Max: 87.81% - (Device 10) | Min: 0.27% | Std: 15.69% | Sum: 100.00% ]
# Selected Devices: [10, 23, 14, 19, 21, 15, 13, 20, 17, 22]
# Time: 660.558s / 700s | Acc: 78.20%
# Probability Policy: [Max: 87.82% - (Device 10) | Min: 0.27% | Std: 15.69% | Sum: 100.00% ]
# Selected Devices: [10, 22, 19, 15, 21, 13, 6, 0, 18, 20]
# Time: 661.016s / 700s | Acc: 78.20%
# Probability Policy: [Max: 87.82% - (Device 10) | Min: 0.27% | Std: 15.69% | Sum: 100.00% ]
# Selected Devices: [23, 10, 13, 6, 2, 25, 9, 20, 21, 16]
# Time: 661.504s / 700s | Acc: 78.30%
# Probability Policy: [Max: 87.84% - (Device 10) | Min: 0.27% | Std: 15.69% | Sum: 100.00% ]
# Selected Devices: [10, 14, 8, 27, 26, 5, 0, 3, 12, 29]
# Time: 661.999s / 700s | Acc: 78.25%
# Probability Policy: [Max: 87.84% - (Device 10) | Min: 0.27% | Std: 15.69% | Sum: 100.00% ]
# Selected Devices: [10, 13, 27, 15, 8, 29, 24, 23, 14, 21]
# Time: 662.444s / 700s | Acc: 78.25%
# Probability Policy: [Max: 87.84% - (Device 10) | Min: 0.27% | Std: 15.69% | Sum: 100.00% ]
# Selected Devices: [10, 18, 29, 8, 23, 14, 1, 22, 5, 19]
# Time: 662.906s / 700s | Acc: 78.30%
# Probability Policy: [Max: 87.84% - (Device 10) | Min: 0.27% | Std: 15.69% | Sum: 100.00% ]
# Selected Devices: [10, 29, 8, 6, 4, 27, 21, 22, 15, 14]
# Time: 663.350s / 700s | Acc: 78.30%
# Probability Policy: [Max: 87.84% - (Device 10) | Min: 0.27% | Std: 15.69% | Sum: 100.00% ]
# Selected Devices: [10, 18, 7, 29, 23, 13, 4, 22, 3, 6]
# Time: 663.835s / 700s | Acc: 78.30%
# Probability Policy: [Max: 87.84% - (Device 10) | Min: 0.27% | Std: 15.69% | Sum: 100.00% ]
# Selected Devices: [10, 17, 24, 9, 2, 15, 23, 6, 7, 29]
# Time: 664.317s / 700s | Acc: 78.30%
# Probability Policy: [Max: 87.84% - (Device 10) | Min: 0.27% | Std: 15.69% | Sum: 100.00% ]
# Selected Devices: [19, 28, 10, 6, 7, 13, 12, 29, 23, 21]
# Time: 664.776s / 700s | Acc: 78.25%
# Probability Policy: [Max: 87.85% - (Device 10) | Min: 0.27% | Std: 15.69% | Sum: 100.00% ]
# Selected Devices: [10, 28, 24, 5, 26, 8, 2, 20, 19, 3]
# Time: 665.295s / 700s | Acc: 78.25%
# Probability Policy: [Max: 87.83% - (Device 10) | Min: 0.27% | Std: 15.69% | Sum: 100.00% ]
# Selected Devices: [10, 29, 20, 21, 6, 2, 9, 8, 7, 5]
# Time: 665.771s / 700s | Acc: 78.25%
# Probability Policy: [Max: 87.82% - (Device 10) | Min: 0.27% | Std: 15.69% | Sum: 100.00% ]
# Selected Devices: [10, 11, 25, 6, 16, 0, 17, 2, 29, 23]
# Time: 666.276s / 700s | Acc: 78.30%
# Probability Policy: [Max: 87.82% - (Device 10) | Min: 0.27% | Std: 15.69% | Sum: 100.00% ]
# Selected Devices: [10, 3, 19, 23, 6, 18, 26, 24, 25, 28]
# Time: 666.772s / 700s | Acc: 78.35%
# Probability Policy: [Max: 87.82% - (Device 10) | Min: 0.27% | Std: 15.69% | Sum: 100.00% ]
# Selected Devices: [15, 10, 18, 25, 21, 29, 0, 9, 6, 8]
# Time: 667.245s / 700s | Acc: 78.30%
# Probability Policy: [Max: 87.86% - (Device 10) | Min: 0.27% | Std: 15.70% | Sum: 100.00% ]
# Selected Devices: [10, 21, 3, 23, 20, 7, 8, 18, 25, 28]
# Time: 667.786s / 700s | Acc: 78.30%
# Probability Policy: [Max: 87.86% - (Device 10) | Min: 0.27% | Std: 15.70% | Sum: 100.00% ]
# Selected Devices: [10, 29, 17, 26, 22, 24, 0, 28, 13, 20]
# Time: 668.271s / 700s | Acc: 78.30%
# Probability Policy: [Max: 87.87% - (Device 10) | Min: 0.27% | Std: 15.70% | Sum: 100.00% ]
# Selected Devices: [10, 13, 7, 9, 4, 25, 0, 12, 6, 21]
# Time: 668.802s / 700s | Acc: 78.35%
# Probability Policy: [Max: 87.86% - (Device 10) | Min: 0.27% | Std: 15.70% | Sum: 100.00% ]
# Selected Devices: [10, 7, 16, 21, 4, 6, 9, 29, 14, 19]
# Time: 669.263s / 700s | Acc: 78.35%
# Probability Policy: [Max: 87.86% - (Device 10) | Min: 0.27% | Std: 15.70% | Sum: 100.00% ]
# Selected Devices: [10, 15, 2, 1, 16, 13, 5, 23, 29, 12]
# Time: 669.739s / 700s | Acc: 78.30%
# Probability Policy: [Max: 87.86% - (Device 10) | Min: 0.27% | Std: 15.70% | Sum: 100.00% ]
# Selected Devices: [10, 29, 23, 14, 21, 3, 15, 6, 5, 13]
# Time: 670.158s / 700s | Acc: 78.35%
# Probability Policy: [Max: 87.86% - (Device 10) | Min: 0.27% | Std: 15.70% | Sum: 100.00% ]
# Selected Devices: [10, 21, 14, 16, 5, 4, 19, 29, 2, 8]
# Time: 670.624s / 700s | Acc: 78.35%
# Probability Policy: [Max: 87.86% - (Device 10) | Min: 0.27% | Std: 15.70% | Sum: 100.00% ]
# Selected Devices: [10, 2, 27, 16, 13, 9, 8, 11, 28, 22]
# Time: 671.155s / 700s | Acc: 78.30%
# Probability Policy: [Max: 87.86% - (Device 10) | Min: 0.27% | Std: 15.70% | Sum: 100.00% ]
# Selected Devices: [10, 24, 7, 19, 14, 25, 8, 20, 28, 12]
# Time: 671.693s / 700s | Acc: 78.35%
# Probability Policy: [Max: 87.86% - (Device 10) | Min: 0.27% | Std: 15.70% | Sum: 100.00% ]
# Selected Devices: [10, 16, 11, 21, 29, 14, 13, 19, 2, 6]
# Time: 672.137s / 700s | Acc: 78.35%
# Probability Policy: [Max: 87.86% - (Device 10) | Min: 0.27% | Std: 15.70% | Sum: 100.00% ]
# Selected Devices: [11, 10, 0, 6, 22, 24, 26, 9, 29, 16]
# Time: 672.614s / 700s | Acc: 78.40%
# Probability Policy: [Max: 87.87% - (Device 10) | Min: 0.27% | Std: 15.70% | Sum: 100.00% ]
# Selected Devices: [10, 19, 4, 29, 5, 8, 24, 18, 25, 15]
# Time: 673.097s / 700s | Acc: 78.40%
# Probability Policy: [Max: 87.87% - (Device 10) | Min: 0.27% | Std: 15.70% | Sum: 100.00% ]
# Selected Devices: [10, 28, 1, 26, 6, 24, 5, 18, 27, 15]
# Time: 673.567s / 700s | Acc: 78.40%
# Probability Policy: [Max: 87.88% - (Device 10) | Min: 0.27% | Std: 15.70% | Sum: 100.00% ]
# Selected Devices: [10, 24, 22, 28, 13, 5, 1, 8, 6, 19]
# Time: 674.040s / 700s | Acc: 78.35%
# Probability Policy: [Max: 87.88% - (Device 10) | Min: 0.27% | Std: 15.70% | Sum: 100.00% ]
# Selected Devices: [10, 1, 2, 26, 18, 12, 28, 4, 29, 17]
# Time: 674.569s / 700s | Acc: 78.35%
# Probability Policy: [Max: 87.88% - (Device 10) | Min: 0.27% | Std: 15.70% | Sum: 100.00% ]
# Selected Devices: [10, 21, 23, 13, 27, 4, 7, 2, 6, 9]
# Time: 675.075s / 700s | Acc: 78.35%
# Probability Policy: [Max: 87.88% - (Device 10) | Min: 0.27% | Std: 15.70% | Sum: 100.00% ]
# Selected Devices: [11, 10, 14, 18, 28, 29, 21, 27, 22, 26]
# Time: 675.539s / 700s | Acc: 78.40%
# Probability Policy: [Max: 87.88% - (Device 10) | Min: 0.27% | Std: 15.70% | Sum: 100.00% ]
# Selected Devices: [10, 3, 14, 21, 11, 8, 19, 29, 1, 23]
# Time: 676.035s / 700s | Acc: 78.40%
# Probability Policy: [Max: 87.88% - (Device 10) | Min: 0.27% | Std: 15.70% | Sum: 100.00% ]
# Selected Devices: [10, 29, 26, 21, 14, 5, 16, 22, 25, 20]
# Time: 676.476s / 700s | Acc: 78.40%
# Probability Policy: [Max: 87.88% - (Device 10) | Min: 0.27% | Std: 15.70% | Sum: 100.00% ]
# Selected Devices: [10, 19, 11, 0, 6, 4, 26, 9, 13, 29]
# Time: 676.963s / 700s | Acc: 78.40%
# Probability Policy: [Max: 87.88% - (Device 10) | Min: 0.27% | Std: 15.70% | Sum: 100.00% ]
# Selected Devices: [10, 0, 9, 5, 4, 3, 20, 8, 15, 27]
# Time: 677.510s / 700s | Acc: 78.40%
# Probability Policy: [Max: 87.88% - (Device 10) | Min: 0.27% | Std: 15.70% | Sum: 100.00% ]
# Selected Devices: [10, 28, 15, 13, 23, 2, 3, 20, 16, 25]
# Time: 678.033s / 700s | Acc: 78.40%
# Probability Policy: [Max: 87.88% - (Device 10) | Min: 0.27% | Std: 15.70% | Sum: 100.00% ]
# Selected Devices: [10, 13, 19, 16, 29, 24, 26, 6, 21, 5]
# Time: 678.443s / 700s | Acc: 78.40%
# Probability Policy: [Max: 87.89% - (Device 10) | Min: 0.27% | Std: 15.70% | Sum: 100.00% ]
# Selected Devices: [10, 29, 0, 27, 5, 23, 8, 13, 6, 19]
# Time: 678.896s / 700s | Acc: 78.40%
# Probability Policy: [Max: 87.89% - (Device 10) | Min: 0.27% | Std: 15.70% | Sum: 100.00% ]
# Selected Devices: [10, 20, 0, 3, 5, 15, 26, 28, 8, 18]
# Time: 679.411s / 700s | Acc: 78.45%
# Probability Policy: [Max: 87.89% - (Device 10) | Min: 0.27% | Std: 15.70% | Sum: 100.00% ]
# Selected Devices: [10, 8, 14, 17, 4, 0, 6, 21, 3, 9]
# Time: 679.929s / 700s | Acc: 78.55%
# Probability Policy: [Max: 87.88% - (Device 10) | Min: 0.27% | Std: 15.70% | Sum: 100.00% ]
# Selected Devices: [10, 2, 6, 28, 0, 21, 14, 22, 18, 8]
# Time: 680.417s / 700s | Acc: 78.55%
# Probability Policy: [Max: 87.89% - (Device 10) | Min: 0.27% | Std: 15.70% | Sum: 100.00% ]
# Selected Devices: [10, 16, 25, 13, 29, 22, 28, 14, 12, 21]
# Time: 680.881s / 700s | Acc: 78.50%
# Probability Policy: [Max: 87.89% - (Device 10) | Min: 0.27% | Std: 15.70% | Sum: 100.00% ]
# Selected Devices: [10, 29, 9, 23, 6, 17, 5, 13, 27, 3]
# Time: 681.346s / 700s | Acc: 78.50%
# Probability Policy: [Max: 87.88% - (Device 10) | Min: 0.27% | Std: 15.70% | Sum: 100.00% ]
# Selected Devices: [10, 18, 4, 11, 19, 6, 26, 29, 7, 5]
# Time: 681.821s / 700s | Acc: 78.55%
# Probability Policy: [Max: 87.89% - (Device 10) | Min: 0.27% | Std: 15.70% | Sum: 100.00% ]
# Selected Devices: [10, 23, 8, 0, 17, 29, 13, 14, 28, 20]
# Time: 682.311s / 700s | Acc: 78.65%
# Probability Policy: [Max: 87.89% - (Device 10) | Min: 0.27% | Std: 15.70% | Sum: 100.00% ]
# Selected Devices: [10, 18, 29, 20, 26, 19, 21, 6, 8, 23]
# Time: 682.753s / 700s | Acc: 78.65%
# Probability Policy: [Max: 87.89% - (Device 10) | Min: 0.27% | Std: 15.70% | Sum: 100.00% ]
# Selected Devices: [10, 18, 7, 25, 3, 26, 19, 6, 16, 9]
# Time: 683.261s / 700s | Acc: 78.65%
# Probability Policy: [Max: 87.89% - (Device 10) | Min: 0.27% | Std: 15.70% | Sum: 100.00% ]
# Selected Devices: [10, 12, 2, 29, 1, 20, 13, 19, 9, 21]
# Time: 683.761s / 700s | Acc: 78.65%
# Probability Policy: [Max: 87.89% - (Device 10) | Min: 0.27% | Std: 15.70% | Sum: 100.00% ]
# Selected Devices: [10, 21, 4, 20, 8, 1, 14, 15, 16, 24]
# Time: 684.263s / 700s | Acc: 78.65%
# Probability Policy: [Max: 87.89% - (Device 10) | Min: 0.27% | Std: 15.70% | Sum: 100.00% ]
# Selected Devices: [10, 9, 2, 21, 18, 12, 23, 16, 14, 15]
# Time: 684.754s / 700s | Acc: 78.70%
# Probability Policy: [Max: 87.89% - (Device 10) | Min: 0.27% | Std: 15.70% | Sum: 100.00% ]
# Selected Devices: [10, 20, 8, 5, 6, 21, 27, 14, 4, 24]
# Time: 685.230s / 700s | Acc: 78.70%
# Probability Policy: [Max: 87.89% - (Device 10) | Min: 0.27% | Std: 15.70% | Sum: 100.00% ]
# Selected Devices: [10, 27, 18, 26, 0, 4, 3, 21, 2, 15]
# Time: 685.757s / 700s | Acc: 78.70%
# Probability Policy: [Max: 87.91% - (Device 10) | Min: 0.27% | Std: 15.71% | Sum: 100.00% ]
# Selected Devices: [10, 9, 26, 5, 13, 23, 1, 21, 25, 29]
# Time: 686.221s / 700s | Acc: 78.70%
# Probability Policy: [Max: 87.90% - (Device 10) | Min: 0.27% | Std: 15.70% | Sum: 100.00% ]
# Selected Devices: [10, 9, 19, 2, 7, 4, 13, 27, 14, 20]
# Time: 686.754s / 700s | Acc: 78.70%
# Probability Policy: [Max: 87.90% - (Device 10) | Min: 0.27% | Std: 15.70% | Sum: 100.00% ]
# Selected Devices: [10, 15, 29, 8, 19, 13, 1, 16, 24, 3]
# Time: 687.238s / 700s | Acc: 78.70%
# Probability Policy: [Max: 87.91% - (Device 10) | Min: 0.27% | Std: 15.71% | Sum: 100.00% ]
# Selected Devices: [10, 5, 23, 22, 17, 14, 28, 24, 25, 26]
# Time: 687.719s / 700s | Acc: 78.70%
# Probability Policy: [Max: 87.91% - (Device 10) | Min: 0.27% | Std: 15.71% | Sum: 100.00% ]
# Selected Devices: [10, 15, 26, 29, 0, 2, 27, 8, 23, 12]
# Time: 688.221s / 700s | Acc: 78.70%
# Probability Policy: [Max: 87.90% - (Device 10) | Min: 0.27% | Std: 15.70% | Sum: 100.00% ]
# Selected Devices: [10, 3, 6, 9, 17, 23, 29, 14, 16, 18]
# Time: 688.689s / 700s | Acc: 78.70%
# Probability Policy: [Max: 87.91% - (Device 10) | Min: 0.27% | Std: 15.71% | Sum: 100.00% ]
# Selected Devices: [10, 16, 0, 1, 5, 6, 23, 9, 28, 29]
# Time: 689.168s / 700s | Acc: 78.70%
# Probability Policy: [Max: 87.92% - (Device 10) | Min: 0.27% | Std: 15.71% | Sum: 100.00% ]
# Selected Devices: [24, 15, 10, 16, 5, 26, 28, 25, 13, 21]
# Time: 689.628s / 700s | Acc: 78.75%
# Probability Policy: [Max: 87.92% - (Device 10) | Min: 0.27% | Std: 15.71% | Sum: 100.00% ]
# Selected Devices: [10, 1, 23, 14, 29, 4, 25, 15, 22, 21]
# Time: 690.103s / 700s | Acc: 78.80%
# Probability Policy: [Max: 87.91% - (Device 10) | Min: 0.27% | Std: 15.71% | Sum: 100.00% ]
# Selected Devices: [10, 9, 29, 5, 2, 15, 24, 16, 25, 21]
# Time: 690.573s / 700s | Acc: 78.80%
# Probability Policy: [Max: 87.92% - (Device 10) | Min: 0.27% | Std: 15.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 2, 26, 8, 15, 13, 5, 12, 6]
# Time: 691.020s / 700s | Acc: 78.80%
# Probability Policy: [Max: 87.92% - (Device 10) | Min: 0.27% | Std: 15.71% | Sum: 100.00% ]
# Selected Devices: [10, 6, 16, 25, 19, 28, 20, 21, 18, 13]
# Time: 691.490s / 700s | Acc: 78.80%
# Probability Policy: [Max: 87.92% - (Device 10) | Min: 0.27% | Std: 15.71% | Sum: 100.00% ]
# Selected Devices: [10, 2, 26, 23, 7, 22, 0, 6, 3, 24]
# Time: 692.008s / 700s | Acc: 78.80%
# Probability Policy: [Max: 87.92% - (Device 10) | Min: 0.27% | Std: 15.71% | Sum: 100.00% ]
# Selected Devices: [10, 25, 0, 16, 21, 5, 20, 3, 6, 17]
# Time: 692.507s / 700s | Acc: 78.85%
# Probability Policy: [Max: 87.92% - (Device 10) | Min: 0.27% | Std: 15.71% | Sum: 100.00% ]
# Selected Devices: [10, 5, 6, 9, 12, 11, 16, 22, 17, 26]
# Time: 692.994s / 700s | Acc: 78.85%
# Probability Policy: [Max: 87.92% - (Device 10) | Min: 0.27% | Std: 15.71% | Sum: 100.00% ]
# Selected Devices: [10, 4, 1, 27, 3, 6, 0, 21, 19, 29]
# Time: 693.493s / 700s | Acc: 78.80%
# Probability Policy: [Max: 87.92% - (Device 10) | Min: 0.27% | Std: 15.71% | Sum: 100.00% ]
# Selected Devices: [10, 13, 12, 8, 5, 4, 6, 3, 14, 16]
# Time: 693.984s / 700s | Acc: 78.85%
# Probability Policy: [Max: 87.92% - (Device 10) | Min: 0.27% | Std: 15.71% | Sum: 100.00% ]
# Selected Devices: [21, 10, 29, 11, 14, 8, 5, 4, 27, 28]
# Time: 694.471s / 700s | Acc: 78.80%
# Probability Policy: [Max: 87.94% - (Device 10) | Min: 0.27% | Std: 15.71% | Sum: 100.00% ]
# Selected Devices: [10, 5, 14, 6, 15, 3, 18, 11, 16, 2]
# Time: 694.956s / 700s | Acc: 78.85%
# Probability Policy: [Max: 87.94% - (Device 10) | Min: 0.27% | Std: 15.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 9, 25, 23, 27, 21, 17, 22, 2]
# Time: 695.450s / 700s | Acc: 78.85%
# Probability Policy: [Max: 87.95% - (Device 10) | Min: 0.27% | Std: 15.71% | Sum: 100.00% ]
# Selected Devices: [10, 29, 22, 27, 21, 24, 18, 19, 13, 26]
# Time: 695.893s / 700s | Acc: 78.85%
# Probability Policy: [Max: 87.95% - (Device 10) | Min: 0.27% | Std: 15.71% | Sum: 100.00% ]
# Selected Devices: [10, 26, 20, 8, 1, 29, 16, 7, 5, 23]
# Time: 696.379s / 700s | Acc: 78.85%
# Probability Policy: [Max: 87.95% - (Device 10) | Min: 0.27% | Std: 15.71% | Sum: 100.00% ]
# Selected Devices: [10, 25, 19, 11, 8, 0, 26, 3, 20, 15]
# Time: 696.921s / 700s | Acc: 78.85%
# Probability Policy: [Max: 87.95% - (Device 10) | Min: 0.27% | Std: 15.71% | Sum: 100.00% ]
# Selected Devices: [10, 28, 1, 23, 2, 3, 14, 5, 25, 18]
# Time: 697.452s / 700s | Acc: 78.85%
# Probability Policy: [Max: 87.95% - (Device 10) | Min: 0.27% | Std: 15.71% | Sum: 100.00% ]
# Selected Devices: [7, 10, 19, 25, 14, 17, 24, 18, 6, 21]
# Time: 697.931s / 700s | Acc: 78.70%
# Probability Policy: [Max: 87.93% - (Device 10) | Min: 0.27% | Std: 15.71% | Sum: 100.00% ]
# Selected Devices: [10, 22, 19, 29, 5, 27, 15, 18, 2, 11]
# Time: 698.407s / 700s | Acc: 78.70%
# Probability Policy: [Max: 87.94% - (Device 10) | Min: 0.27% | Std: 15.71% | Sum: 100.00% ]
# Selected Devices: [10, 21, 1, 17, 4, 29, 26, 0, 24, 27]
# Time: 698.911s / 700s | Acc: 78.70%
# Probability Policy: [Max: 87.94% - (Device 10) | Min: 0.27% | Std: 15.71% | Sum: 100.00% ]
# Selected Devices: [10, 22, 14, 20, 9, 8, 15, 4, 26, 11]
# Time: 699.426s / 700s | Acc: 78.70%
# Probability Policy: [Max: 87.93% - (Device 10) | Min: 0.27% | Std: 15.71% | Sum: 100.00% ]
# Selected Devices: [10, 27, 15, 17, 29, 25, 5, 13, 28, 9]
# Time: 699.904s / 700s | Acc: 78.70%
# Probability Policy: [Max: 87.94% - (Device 10) | Min: 0.27% | Std: 15.71% | Sum: 100.00% ]
# Selected Devices: [10, 6, 4, 23, 24, 29, 21, 8, 1, 28]
# Time: 700.386s / 700s | Acc: 78.70%

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Subset
from torchvision import datasets, transforms
import numpy as np
import matplotlib.pyplot as plt
import collections
import random

# %%
# --- 1. Wireless Environment Parameters ---
B_HZ = 1e6              # 1 MHz
N0_DBM_HZ = -174        # Noise density
P_TX_CLIENT_DBM = 24    # Uplink Power
P_TX_SERVER_DBM = 46    # Downlink Power (Server)
Q_BITS = 16             # 16-bit quantization
RADIUS_KM = 0.5         # 500m
DEVICE_GFLOPS = 2.0     # Average edge device speed (2 Billion operations/sec)

# %%
def plot_radar_map(r_km):
    """
    Plots 30 devices in a circular layout with index labels.
    Red triangle = Edge Server (Center)
    Blue dots = Edge Devices (Labeled 0-29)
    """
    # Generate random angles (theta) in radians
    theta = 2 * np.pi * np.random.rand(len(r_km)) 
    
    # Convert polar (r, theta) to Cartesian (x, y) for easier labeling
    x = r_km * np.cos(theta)
    y = r_km * np.sin(theta)
    
    plt.figure(figsize=(8, 8))
    
    # Plot the circular boundary (500m radius)
    circle = plt.Circle((0, 0), RADIUS_KM, color='gray', fill=False, linestyle='--', alpha=0.5)
    plt.gca().add_patch(circle)
    
    # Plot Edge Server at the center (0,0)
    plt.scatter(0, 0, c='red', marker='^', s=150, label='Edge Server', zorder=5)
    
    # Plot Edge Devices
    plt.scatter(x, y, c='skyblue', edgecolors='navy', s=80, alpha=0.8, label='Edge Devices')
    
    # Add Index Labels (0 to 29) for each device
    for i in range(len(r_km)):
        plt.annotate(f'{i}', (x[i], y[i]), xytext=(5, 5), 
                     textcoords='offset points', fontsize=9, fontweight='bold')

    plt.title(f"Device Distribution ({RADIUS_KM*1000}m Radius)")
    plt.xlabel("Distance (km)")
    plt.ylabel("Distance (km)")
    plt.legend(loc='upper right')
    plt.grid(True, alpha=0.2)
    plt.axis('equal') # Keep the circle from looking like an oval
    plt.xlim(-RADIUS_KM - 0.1, RADIUS_KM + 0.1)
    plt.ylim(-RADIUS_KM - 0.1, RADIUS_KM + 0.1)
    plt.show()

# %%
# --- 2. Model Architectures ---

class SVMModel(nn.Module):
    def __init__(self):
        super(SVMModel, self).__init__()
        self.fc = nn.Linear(3072, 1)
    def forward(self, x):
        return self.fc(x.view(x.size(0), -1))

class CNNModel(nn.Module):
    def __init__(self):
        super(CNNModel, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(1, 32, 5), nn.ReLU(), nn.MaxPool2d(2, 2),
            nn.Conv2d(32, 64, 5), nn.ReLU(), nn.MaxPool2d(2, 2)
        )
        self.fc = nn.Sequential(nn.Linear(64 * 4 * 4, 512), nn.ReLU(), nn.Linear(512, 10))
    def forward(self, x):
        x = self.conv(x)
        return self.fc(x.view(x.size(0), -1))

# %%
# --- 3. Data Preparation ---

def get_datasets(task='CNN'):
    # Define a shared seed for reproducibility if needed, 
    # or remove it for different random splits each time.
    random.seed(42) 
    np.random.seed(42)

    if task == 'SVM':
        transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])
        train_set = datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
        test_set = datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
        
        train_idx = [i for i, l in enumerate(train_set.targets) if l in [0, 1]]
        test_idx = [i for i, l in enumerate(test_set.targets) if l in [0, 1]]
        
        airplanes = [i for i in train_idx if train_set.targets[i] == 0][:15*330]
        autos = [i for i in train_idx if train_set.targets[i] == 1][:15*330]
        
        # Create the raw list of 30 Subsets
        all_subsets = [Subset(train_set, airplanes[i*330:(i+1)*330]) for i in range(15)] + \
                       [Subset(train_set, autos[i*330:(i+1)*330]) for i in range(15)]
        
        # RANDOMIZATION: Shuffle the list so 'Airplane devices' are spread 0-29
        random.shuffle(all_subsets)
        device_data = all_subsets
        
        return device_data, Subset(test_set, test_idx), SVMModel(), 0.0001

    else: # CNN Task (MNIST)
        transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))])
        train_set = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
        test_set = datasets.MNIST(root='./data', train=False, download=True, transform=transform)
        
        # Pathological Non-IID: Sort by label to create shards
        indices = np.argsort(train_set.targets.numpy())
        shards = [indices[i*1000 : (i+1)*1000] for i in range(60)]
        
        # RANDOMIZATION: Shuffle the shards so Device 0 doesn't 
        # automatically get the 'lowest' labels (0 and 1)
        random.shuffle(shards)
        
        # Each device gets 2 random shards (each shard is likely 1 digit)
        device_data = [Subset(train_set, np.concatenate((shards[i*2], shards[i*2+1]))) for i in range(30)]
        
        return device_data, test_set, CNNModel(), 0.1
    
def observe_distribution(device_data, task='CNN'):
    # Determine how many classes to show
    num_labels = 10 if task == 'CNN' else 2
    distribution_matrix = np.zeros((30, num_labels))

    for i in range(30):
        subset = device_data[i]
        # Robustly handle different dataset target formats
        targets = subset.dataset.targets
        subset_labels = [int(targets[idx]) for idx in subset.indices]
        
        counts = collections.Counter(subset_labels)
        for label, count in counts.items():
            # For SVM, only record if label is 0 or 1
            if label < num_labels:
                distribution_matrix[i, label] = count

    # Plotting
    plt.figure(figsize=(8, 8)) # Narrower figure for 2 columns
    im = plt.imshow(distribution_matrix, cmap='YlGnBu', aspect='auto')
    
    plt.colorbar(im, label='Number of Samples')
    plt.title(f'Non-IID Heatmap: {task} Task', fontsize=14)
    plt.xlabel('Class Label', fontsize=12)
    plt.ylabel('Device Index', fontsize=12)
    
    # Set x-ticks specifically to the number of labels
    plt.xticks(range(num_labels))
    # If SVM, label them appropriately
    if task == 'SVM':
        plt.gca().set_xticklabels(['0 (Airplane)', '1 (Auto)'])
    
    plt.yticks(range(0, 30, 2))
    plt.tight_layout()
    plt.show()

# %%
device_data_svm, _, _, _ = get_datasets(task='CNN')
observe_distribution(device_data_svm, task='CNN')

# %%
def get_optimal_probabilities(n_k_list, grad_norms, T_u_list, rho):
    """
    Implements Theorem 1 - Importance- and channel-aware scheduling policy.
    """
    n_total = sum(n_k_list)
    grad_norms = np.array(grad_norms) + 1e-12 
    T_u_list = np.array(T_u_list)
    num_devices = len(n_k_list)

    floor_value = 0.0001 # Each device gets at least 1% chance
    total_floor = num_devices * floor_value
    remaining_budget = 1.0 - total_floor

    def apply_gaussian_top3(values, reverse=False):
        # 1. Start everyone with the 1% floor
        p = np.full(num_devices, floor_value)
        
        # 2. Identify the Top 3
        sorted_indices = np.argsort(values)
        if not reverse:
            sorted_indices = sorted_indices[::-1]
            
        # 3. Distribute the remaining 40% budget using Gaussian weights
        # Weights: Rank1 (1.0), Rank2 (0.606), Rank3 (0.135) -> Sum = 1.741
        raw_weights = np.array([1.0, 0.606, 0.135])
        normalized_weights = raw_weights / np.sum(raw_weights) # Scale to sum to 1.0
        
        # Add the budgeted share to the floor
        p[sorted_indices[0]] += normalized_weights[0] * remaining_budget
        p[sorted_indices[1]] += normalized_weights[1] * remaining_budget
        p[sorted_indices[2]] += normalized_weights[2] * remaining_budget
        
        return p

    # 1. New Behavior for rho = 0 (Channel-aware: Top 3 Fastest)
    if rho == 0:
        return apply_gaussian_top3(T_u_list, reverse=True)

    # 2. New Behavior for rho = 1 (Importance-aware: Top 3 Most Informative)
    if rho == 1:
        # Importance includes data weight n_k/n
        importance = (np.array(n_k_list) / n_total) * grad_norms
        return apply_gaussian_top3(importance, reverse=False)

    # 3. Proposed Policy (Intermediate rho)
    def compute_p_star(lam):
        denom = (1 - rho) * T_u_list + lam
        p = (np.array(n_k_list) / n_total) * grad_norms * np.sqrt(rho / np.maximum(denom, 1e-15))
        return p

    low = -np.min((1 - rho) * T_u_list) + 1e-12
    high = 1e6 
    
    for _ in range(100):
        mid = (low + high) / 2
        if np.sum(compute_p_star(mid)) > 1: low = mid
        else: high = mid

    lambda_star  = high
    final_p_raw = compute_p_star(lambda_star)
    return final_p_raw / np.sum(final_p_raw)

# %%
def run_importance_aware_fl(task='SVM', training_time=10, rho=5e-6, r_km= RADIUS_KM * np.sqrt(np.random.rand(30))):
    device_data, test_set, global_model, lr = get_datasets(task)
    test_loader = DataLoader(test_set, batch_size=1000, shuffle=False)
    n_k_list = [len(d) for d in device_data]
    n_total = sum(n_k_list)
    lmbda = 0.01 
    selection_counts = np.zeros(30)
    history = {'acc': [], 'time': []}
    cumulative_time = 0

    print(f"\n--- Simulation: {task} | 30 Clients | Training Time: {training_time}s ---")

    while cumulative_time < training_time:
        # Communication Model
        path_loss_db = 128.1 + 37.6 * np.log10(np.maximum(r_km, 0.01))
        
        noise_up_w = 10**(((N0_DBM_HZ + 10 * np.log10(B_HZ)) - 30) / 10)
        p_rx_up_w = 10**(((P_TX_CLIENT_DBM - path_loss_db) - 30) / 10)
        gamma_up = p_rx_up_w / noise_up_w
        
        noise_down_w = 10**(((N0_DBM_HZ + 10 * np.log10(B_HZ)) - 30) / 10)
        p_rx_down_w = 10**(((P_TX_SERVER_DBM - path_loss_db) - 30) / 10)
        gamma_down_min = np.min(p_rx_down_w / noise_down_w) 
        
        num_params = sum(p.numel() for p in global_model.parameters())
        payload_bits = num_params * Q_BITS
        T_u_list = payload_bits / (B_HZ * np.log2(1 + gamma_up))

        # Importance Evaluation
        grad_norms = []
        client_gradients = []
        for i in range(30):
            # Step 1: Global Model Broadcast
            local_model = type(global_model)()
            local_model.load_state_dict(global_model.state_dict())
            loader = DataLoader(device_data[i], batch_size=len(device_data[i]))
            data, target = next(iter(loader))
            local_model.zero_grad()

            # Step 2: Local Gradient Calculation
            output = local_model(data).squeeze()
            if task == 'SVM':
                target_svm = (target.float() * 2) - 1 
                loss = 0.5 * torch.mean(torch.clamp(1 - target_svm * output, min=0)) + (lmbda / 2.0) * sum(p.pow(2).sum() for p in local_model.parameters())
            else:
                target_oh = torch.nn.functional.one_hot(target, num_classes=10).float()
                loss = 0.5 * torch.nn.functional.mse_loss(output, target_oh, reduction='mean')

            # Step 3: Importance Indicator Report
            loss.backward()
            grads = [p.grad.detach().clone() for p in local_model.parameters()]
            grad_norms.append(torch.norm(torch.cat([g.view(-1) for g in grads])).item())
            client_gradients.append(grads)

        # Step 4: Device Selection and Resource Allocation
        p_star = get_optimal_probabilities(n_k_list, grad_norms, T_u_list, rho)
        print(f"Probability Policy: [Max: {100 * np.max(p_star):.2f}% - (Device {np.argmax(p_star)}) | "
        f"Min: {100 * np.min(p_star):.2f}% | Std: {100 * np.std(p_star):.2f}% | Sum: {100 * np.sum(p_star):.2f}% ]")
        selected_idx = np.random.choice(range(30), p=p_star)
        selection_counts[selected_idx] += 1

        # Step 5: Local Gradient Upload (Simulate latency)
        t_broadcast = payload_bits / (B_HZ * np.log2(1 + gamma_down_min)) 
        t_comp_max = (max(n_k_list) * (6000 if task=='SVM' else 15e6)) / (DEVICE_GFLOPS * 1e9)
        cumulative_time += (t_broadcast + t_comp_max + T_u_list[selected_idx])

        # Step 6: Global Model Update
        with torch.no_grad():
            if rho == 0 or rho == 1:
                scale = n_k_list[selected_idx] / n_total
            else:
                # Standard Theorem 1 Unbiased Estimator
                scale = n_k_list[selected_idx] / (n_total * p_star[selected_idx])
            for p_global, g_local in zip(global_model.parameters(), client_gradients[selected_idx]):
                p_global -= lr * (scale * g_local)

        # Evaluation
        global_model.eval()
        correct, total = 0, 0
        with torch.no_grad():
            for data, target in test_loader:
                output = global_model(data)
                pred = torch.sign(output.squeeze()) if task == 'SVM' else output.argmax(1)
                labels = (target.float()*2-1) if task == 'SVM' else target
                correct += (pred == labels).sum().item()
                total += target.size(0)
        
        acc = 100. * correct / total
        history['acc'].append(acc)
        history['time'].append(cumulative_time)
        print(f"Time: {cumulative_time:.3f}s / {training_time}s | Acc: {acc:.2f}%")

    return history, selection_counts

# %%
# Force 5 devices to be at the cell edge (450m - 500m) 
# and 25 devices to be distributed normally.
r_km = RADIUS_KM * np.sqrt(np.random.rand(30))
r_km[:5] = 0.45 + (np.random.rand(5) * 0.05)
plot_radar_map(r_km)
# Out:
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.

# %%
def run_full_comparison(task='SVM', max_sim_time=0.1):
    """Modified comparison loop to use max_sim_time instead of rounds."""
    if task == 'SVM':
        rhos = {0: 'Channel-aware', 1: 'Importance-aware', 5e-4: 'Proposed (5e-4)', 5e-5: 'Proposed (5e-5)', 5e-6: 'Proposed (5e-6)'}
        time_scale = 1
    else:
        rhos = {0: 'Channel-aware', 1: 'Importance-aware', 5e-3: 'Proposed (5e-3)', 5e-1: 'Proposed (5e-1)', 9e-1: 'Proposed (9e-1)'}
        time_scale = 60

    training_results = {}
    selection_results = {}
    # Force 5 devices to be at the cell edge (450m - 500m) 
    # and 25 devices to be distributed normally.
    r_km = RADIUS_KM * np.sqrt(np.random.rand(30))
    r_km[:5] = 0.45 + (np.random.rand(5) * 0.05)
    plot_radar_map(r_km)

    for rho, label in rhos.items():
        print(f"\n>>> Running {label} Policy, rho={rho} <<<")
        history, sel_counts = run_importance_aware_fl(task=task, training_time=max_sim_time, rho=rho, r_km=r_km)
        training_results[label] = history
        selection_results[label] = sel_counts

    # --- Plot Comparison ---
    plt.figure(figsize=(10, 6))
    for label, hist in training_results.items():
        plt.plot(np.array(hist['time']) / time_scale, hist['acc'], label=label)
    plt.xlabel(f"Training Time ({'Seconds' if time_scale==1 else 'Minutes'})")
    plt.ylabel("Accuracy")
    plt.title(f"Performance Comparison: {task}")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()

    # --- Selection Counts ---
    fig, axes = plt.subplots(len(rhos), 1, figsize=(12, 3 * len(rhos)))
    if len(rhos) == 1: axes = [axes] 

    for ax, (label, sel) in zip(axes, selection_results.items()):
        # Plotting the bars
        ax.bar(range(30), sel, color='teal', edgecolor='black', alpha=0.7)
    
        # 2. Set the Title and Labels
        ax.set_title(f"Selection Frequency: {label}", fontsize=12, fontweight='bold')
        ax.set_ylabel("Count")
    
        # 3. Force the ticks and labels on EVERY subplot
        ax.set_xticks(range(30))
        ax.tick_params(labelbottom=True) # Forces labels to appear even if sharing axes
    
        # 4. Styling the grid
        ax.grid(axis='y', linestyle='--', alpha=0.4)
    
        # 5. Optional: Set Y-axis to integers only (since counts are whole numbers)
        ax.yaxis.get_major_locator().set_params(integer=True)

    plt.xlabel("Device Index")
    plt.tight_layout()
    plt.show()

# %%
run_full_comparison(task='CNN', max_sim_time=12000)
# Out:
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# >>> Running Channel-aware Policy, rho=0 <<<
#
# --- Simulation: CNN | 30 Clients | Training Time: 12000s ---
# Probability Policy: [Max: 57.28% - (Device 5) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 16.212s / 12000s | Acc: 8.89%
# Probability Policy: [Max: 57.28% - (Device 5) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 32.572s / 12000s | Acc: 9.36%
# Probability Policy: [Max: 57.28% - (Device 5) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 48.882s / 12000s | Acc: 9.13%
# Probability Policy: [Max: 57.28% - (Device 5) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 65.192s / 12000s | Acc: 8.98%
# Probability Policy: [Max: 57.28% - (Device 5) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 81.404s / 12000s | Acc: 9.08%
# Probability Policy: [Max: 57.28% - (Device 5) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 97.616s / 12000s | Acc: 9.11%
# Probability Policy: [Max: 57.28% - (Device 5) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 113.828s / 12000s | Acc: 9.16%
# Probability Policy: [Max: 57.28% - (Device 5) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 130.138s / 12000s | Acc: 9.12%
# Probability Policy: [Max: 57.28% - (Device 5) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 146.448s / 12000s | Acc: 9.04%
# Probability Policy: [Max: 57.28% - (Device 5) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 162.758s / 12000s | Acc: 9.01%
# Probability Policy: [Max: 57.28% - (Device 5) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 178.970s / 12000s | Acc: 9.02%
# Probability Policy: [Max: 57.28% - (Device 5) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 195.330s / 12000s | Acc: 9.36%
# Probability Policy: [Max: 57.28% - (Device 5) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 211.640s / 12000s | Acc: 9.40%
# Probability Policy: [Max: 57.28% - (Device 5) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 227.852s / 12000s | Acc: 9.34%
# Probability Policy: [Max: 57.28% - (Device 5) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 244.064s / 12000s | Acc: 9.37%
# Probability Policy: [Max: 57.28% - (Device 5) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 260.276s / 12000s | Acc: 9.39%
# Probability Policy: [Max: 57.28% - (Device 5) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 276.488s / 12000s | Acc: 9.41%
# Probability Policy: [Max: 57.28% - (Device 5) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 292.700s / 12000s | Acc: 9.52%
# Probability Policy: [Max: 57.28% - (Device 5) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 308.911s / 12000s | Acc: 9.51%
# Probability Policy: [Max: 57.28% - (Device 5) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 325.123s / 12000s | Acc: 9.57%
# Probability Policy: [Max: 57.28% - (Device 5) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 341.434s / 12000s | Acc: 9.40%
# Probability Policy: [Max: 57.28% - (Device 5) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 357.645s / 12000s | Acc: 9.49%
# Probability Policy: [Max: 57.28% - (Device 5) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 373.857s / 12000s | Acc: 9.45%
# Probability Policy: [Max: 57.28% - (Device 5) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 390.069s / 12000s | Acc: 9.55%
# Probability Policy: [Max: 57.28% - (Device 5) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 406.281s / 12000s | Acc: 9.64%
# Probability Policy: [Max: 57.28% - (Device 5) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 422.591s / 12000s | Acc: 9.47%
# Probability Policy: [Max: 57.28% - (Device 5) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 438.803s / 12000s | Acc: 9.59%
# Probability Policy: [Max: 57.28% - (Device 5) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 455.015s / 12000s | Acc: 9.63%
# Probability Policy: [Max: 57.28% - (Device 5) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 471.325s / 12000s | Acc: 9.54%
# Probability Policy: [Max: 57.28% - (Device 5) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 487.537s / 12000s | Acc: 9.58%
# Probability Policy: [Max: 57.28% - (Device 5) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 503.847s / 12000s | Acc: 9.55%
# Probability Policy: [Max: 57.28% - (Device 5) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 520.059s / 12000s | Acc: 9.68%
# Probability Policy: [Max: 57.28% - (Device 5) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 536.271s / 12000s | Acc: 10.03%
# Probability Policy: [Max: 57.28% - (Device 5) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 552.631s / 12000s | Acc: 10.32%
# Probability Policy: [Max: 57.28% - (Device 5) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 568.991s / 12000s | Acc: 10.66%
# Probability Policy: [Max: 57.28% - (Device 5) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 585.301s / 12000s | Acc: 10.44%
# Probability Policy: [Max: 57.28% - (Device 5) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 601.513s / 12000s | Acc: 10.74%
# Probability Policy: [Max: 57.28% - (Device 5) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 617.725s / 12000s | Acc: 10.97%
# Probability Policy: [Max: 57.28% - (Device 5) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 634.035s / 12000s | Acc: 10.65%
# Probability Policy: [Max: 57.28% - (Device 5) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 650.247s / 12000s | Acc: 11.01%
# Probability Policy: [Max: 57.28% - (Device 5) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time: 666.459s / 12000s | Acc: 11.61%
# Probability Policy: [Max: 57.28% - (Device 5) | Min: 0.01% | Std: 11.85% | Sum: 100.00% ]
# Time:
# Probability Policy: [Max: 17.57% - (Device 5) | Min: 1.39% | Std: 2.97% | Sum: 100.00% ]
# Time: 10138.989s / 12000s | Acc: 93.50%
# Probability Policy: [Max: 22.14% - (Device 5) | Min: 1.28% | Std: 3.71% | Sum: 100.00% ]
# Time: 10155.410s / 12000s | Acc: 93.13%
# Probability Policy: [Max: 24.78% - (Device 5) | Min: 1.48% | Std: 4.15% | Sum: 100.00% ]
# Time: 10172.356s / 12000s | Acc: 93.20%
# Probability Policy: [Max: 20.48% - (Device 5) | Min: 1.47% | Std: 3.44% | Sum: 100.00% ]
# Time: 10188.804s / 12000s | Acc: 93.41%
# Probability Policy: [Max: 25.40% - (Device 5) | Min: 1.41% | Std: 4.25% | Sum: 100.00% ]
# Time: 10205.114s / 12000s | Acc: 93.59%
# Probability Policy: [Max: 25.24% - (Device 5) | Min: 1.31% | Std: 4.17% | Sum: 100.00% ]
# Time: 10221.981s / 12000s | Acc: 92.56%
# Probability Policy: [Max: 13.10% - (Device 5) | Min: 1.34% | Std: 2.24% | Sum: 100.00% ]
# Time: 10238.892s / 12000s | Acc: 92.83%
# Probability Policy: [Max: 15.50% - (Device 5) | Min: 0.66% | Std: 2.64% | Sum: 100.00% ]
# Time: 10255.454s / 12000s | Acc: 92.51%
# Probability Policy: [Max: 8.01% - (Device 14) | Min: 0.95% | Std: 1.56% | Sum: 100.00% ]
# Time: 10272.405s / 12000s | Acc: 92.25%
# Probability Policy: [Max: 12.72% - (Device 5) | Min: 0.71% | Std: 2.25% | Sum: 100.00% ]
# Time: 10288.964s / 12000s | Acc: 93.67%
# Probability Policy: [Max: 20.70% - (Device 5) | Min: 1.27% | Std: 3.39% | Sum: 100.00% ]
# Time: 10305.873s / 12000s | Acc: 93.84%
# Probability Policy: [Max: 16.45% - (Device 5) | Min: 1.18% | Std: 2.73% | Sum: 100.00% ]
# Time: 10322.772s / 12000s | Acc: 93.77%
# Probability Policy: [Max: 16.03% - (Device 5) | Min: 0.75% | Std: 2.71% | Sum: 100.00% ]
# Time: 10338.984s / 12000s | Acc: 93.73%
# Probability Policy: [Max: 17.24% - (Device 5) | Min: 0.76% | Std: 2.90% | Sum: 100.00% ]
# Time: 10355.196s / 12000s | Acc: 93.72%
# Probability Policy: [Max: 18.13% - (Device 5) | Min: 0.80% | Std: 3.05% | Sum: 100.00% ]
# Time: 10371.889s / 12000s | Acc: 93.56%
# Probability Policy: [Max: 23.93% - (Device 5) | Min: 1.23% | Std: 4.02% | Sum: 100.00% ]
# Time: 10388.518s / 12000s | Acc: 92.45%
# Probability Policy: [Max: 14.99% - (Device 5) | Min: 1.39% | Std: 2.61% | Sum: 100.00% ]
# Time: 10404.939s / 12000s | Acc: 93.12%
# Probability Policy: [Max: 22.78% - (Device 5) | Min: 1.12% | Std: 3.82% | Sum: 100.00% ]
# Time: 10421.498s / 12000s | Acc: 94.03%
# Probability Policy: [Max: 23.10% - (Device 5) | Min: 1.22% | Std: 3.78% | Sum: 100.00% ]
# Time: 10438.004s / 12000s | Acc: 92.94%
# Probability Policy: [Max: 18.75% - (Device 5) | Min: 1.46% | Std: 3.03% | Sum: 100.00% ]
# Time: 10454.867s / 12000s | Acc: 93.47%
# Probability Policy: [Max: 22.30% - (Device 5) | Min: 1.50% | Std: 3.69% | Sum: 100.00% ]
# Time: 10471.817s / 12000s | Acc: 92.62%
# Probability Policy: [Max: 11.98% - (Device 5) | Min: 0.72% | Std: 2.14% | Sum: 100.00% ]
# Time: 10488.588s / 12000s | Acc: 93.85%
# Probability Policy: [Max: 17.01% - (Device 5) | Min: 1.11% | Std: 2.90% | Sum: 100.00% ]
# Time: 10505.356s / 12000s | Acc: 94.37%
# Probability Policy: [Max: 16.33% - (Device 5) | Min: 1.38% | Std: 2.66% | Sum: 100.00% ]
# Time: 10521.918s / 12000s | Acc: 94.09%
# Probability Policy: [Max: 13.30% - (Device 5) | Min: 1.06% | Std: 2.24% | Sum: 100.00% ]
# Time: 10538.406s / 12000s | Acc: 94.19%
# Probability Policy: [Max: 22.56% - (Device 5) | Min: 0.98% | Std: 3.76% | Sum: 100.00% ]
# Time: 10555.243s / 12000s | Acc: 93.93%
# Probability Policy: [Max: 25.65% - (Device 5) | Min: 1.03% | Std: 4.31% | Sum: 100.00% ]
# Time: 10572.158s / 12000s | Acc: 93.60%
# Probability Policy: [Max: 10.54% - (Device 5) | Min: 0.81% | Std: 1.94% | Sum: 100.00% ]
# Time: 10588.646s / 12000s | Acc: 94.06%
# Probability Policy: [Max: 22.19% - (Device 5) | Min: 1.22% | Std: 3.74% | Sum: 100.00% ]
# Time: 10605.134s / 12000s | Acc: 93.68%
# Probability Policy: [Max: 21.24% - (Device 5) | Min: 0.96% | Std: 3.56% | Sum: 100.00% ]
# Time: 10621.346s / 12000s | Acc: 93.73%
# Probability Policy: [Max: 21.84% - (Device 5) | Min: 0.98% | Std: 3.67% | Sum: 100.00% ]
# Time: 10637.558s / 12000s | Acc: 93.76%
# Probability Policy: [Max: 22.26% - (Device 5) | Min: 1.01% | Std: 3.74% | Sum: 100.00% ]
# Time: 10654.117s / 12000s | Acc: 94.22%
# Probability Policy: [Max: 23.13% - (Device 5) | Min: 1.20% | Std: 3.79% | Sum: 100.00% ]
# Time: 10671.025s / 12000s | Acc: 93.58%
# Probability Policy: [Max: 19.82% - (Device 5) | Min: 0.80% | Std: 3.31% | Sum: 100.00% ]
# Time: 10687.795s / 12000s | Acc: 94.03%
# Probability Policy: [Max: 19.66% - (Device 5) | Min: 1.22% | Std: 3.33% | Sum: 100.00% ]
# Time: 10704.007s / 12000s | Acc: 94.04%
# Probability Policy: [Max: 20.19% - (Device 5) | Min: 1.26% | Std: 3.42% | Sum: 100.00% ]
# Time: 10720.777s / 12000s | Acc: 92.53%
# Probability Policy: [Max: 8.26% - (Device 14) | Min: 0.74% | Std: 1.63% | Sum: 100.00% ]
# Time: 10737.643s / 12000s | Acc: 93.54%
# Probability Policy: [Max: 11.18% - (Device 5) | Min: 1.62% | Std: 2.05% | Sum: 100.00% ]
# Time: 10754.205s / 12000s | Acc: 93.65%
# Probability Policy: [Max: 11.68% - (Device 5) | Min: 1.21% | Std: 2.13% | Sum: 100.00% ]
# Time: 10770.745s / 12000s | Acc: 94.28%
# Probability Policy: [Max: 20.63% - (Device 5) | Min: 1.17% | Std: 3.43% | Sum: 100.00% ]
# Time: 10787.167s / 12000s | Acc: 94.00%
# Probability Policy: [Max: 23.66% - (Device 5) | Min: 1.43% | Std: 3.93% | Sum: 100.00% ]
# Time: 10804.029s / 12000s | Acc: 93.77%
# Probability Policy: [Max: 19.70% - (Device 5) | Min: 1.43% | Std: 3.27% | Sum: 100.00% ]
# Time: 10820.517s / 12000s | Acc: 94.11%
# Probability Policy: [Max: 24.97% - (Device 5) | Min: 1.47% | Std: 4.20% | Sum: 100.00% ]
# Time: 10837.384s / 12000s | Acc: 92.63%
# Probability Policy: [Max: 11.96% - (Device 5) | Min: 1.09% | Std: 2.19% | Sum: 100.00% ]
# Time: 10853.694s / 12000s | Acc: 93.58%
# Probability Policy: [Max: 17.18% - (Device 5) | Min: 1.29% | Std: 2.86% | Sum: 100.00% ]
# Time: 10870.234s / 12000s | Acc: 94.27%
# Probability Policy: [Max: 24.87% - (Device 5) | Min: 1.50% | Std: 4.13% | Sum: 100.00% ]
# Time: 10887.002s / 12000s | Acc: 94.47%
# Probability Policy: [Max: 19.33% - (Device 5) | Min: 1.24% | Std: 3.12% | Sum: 100.00% ]
# Time: 10903.509s / 12000s | Acc: 94.21%
# Probability Policy: [Max: 22.66% - (Device 5) | Min: 1.47% | Std: 3.71% | Sum: 100.00% ]
# Time: 10920.424s / 12000s | Acc: 93.97%
# Probability Policy: [Max: 15.19% - (Device 5) | Min: 0.80% | Std: 2.58% | Sum: 100.00% ]
# Time: 10937.194s / 12000s | Acc: 93.19%
# Probability Policy: [Max: 11.22% - (Device 5) | Min: 0.74% | Std: 2.03% | Sum: 100.00% ]
# Time: 10954.112s / 12000s | Acc: 94.50%
# Probability Policy: [Max: 22.57% - (Device 5) | Min: 1.19% | Std: 3.70% | Sum: 100.00% ]
# Time: 10970.651s / 12000s | Acc: 94.02%
# Probability Policy: [Max: 25.78% - (Device 5) | Min: 1.55% | Std: 4.28% | Sum: 100.00% ]
# Time: 10987.139s / 12000s | Acc: 93.76%
# Probability Policy: [Max: 24.72% - (Device 5) | Min: 0.95% | Std: 4.15% | Sum: 100.00% ]
# Time: 11003.351s / 12000s | Acc: 93.87%
# Probability Policy: [Max: 25.46% - (Device 5) | Min: 0.96% | Std: 4.28% | Sum: 100.00% ]
# Time: 11019.838s / 12000s | Acc: 94.13%
# Probability Policy: [Max: 25.15% - (Device 5) | Min: 1.44% | Std: 4.23% | Sum: 100.00% ]
# Time: 11036.149s / 12000s | Acc: 94.12%
# Probability Policy: [Max: 28.16% - (Device 5) | Min: 1.33% | Std: 4.72% | Sum: 100.00% ]
# Time: 11052.361s / 12000s | Acc: 94.09%
# Probability Policy: [Max: 28.01% - (Device 5) | Min: 1.34% | Std: 4.69% | Sum: 100.00% ]
# Time: 11069.227s / 12000s | Acc: 94.10%
# Probability Policy: [Max: 19.95% - (Device 5) | Min: 1.53% | Std: 3.31% | Sum: 100.00% ]
# Time: 11085.439s / 12000s | Acc: 94.08%
# Probability Policy: [Max: 20.34% - (Device 5) | Min: 1.53% | Std: 3.38% | Sum: 100.00% ]
# Time: 11101.651s / 12000s | Acc: 94.04%
# Probability Policy: [Max: 20.55% - (Device 5) | Min: 1.53% | Std: 3.42% | Sum: 100.00% ]
# Time: 11117.863s / 12000s | Acc: 94.07%
# Probability Policy: [Max: 20.62% - (Device 5) | Min: 1.54% | Std: 3.44% | Sum: 100.00% ]
# Time: 11134.075s / 12000s | Acc: 94.09%
# Probability Policy: [Max: 20.59% - (Device 5) | Min: 1.55% | Std: 3.43% | Sum: 100.00% ]
# Time: 11150.287s / 12000s | Acc: 94.07%
# Probability Policy: [Max: 20.46% - (Device 5) | Min: 1.46% | Std: 3.42% | Sum: 100.00% ]
# Time: 11166.499s / 12000s | Acc: 94.03%
# Probability Policy: [Max: 20.28% - (Device 5) | Min: 1.38% | Std: 3.39% | Sum: 100.00% ]
# Time: 11183.410s / 12000s | Acc: 93.89%
# Probability Policy: [Max: 16.91% - (Device 5) | Min: 0.61% | Std: 2.86% | Sum: 100.00% ]
# Time: 11200.277s / 12000s | Acc: 92.18%
# Probability Policy: [Max: 8.80% - (Device 14) | Min: 1.04% | Std: 1.73% | Sum: 100.00% ]
# Time: 11216.587s / 12000s | Acc: 93.36%
# Probability Policy: [Max: 13.39% - (Device 5) | Min: 1.16% | Std: 2.31% | Sum: 100.00% ]
# Time: 11233.216s / 12000s | Acc: 92.26%
# Probability Policy: [Max: 9.09% - (Device 5) | Min: 1.17% | Std: 1.92% | Sum: 100.00% ]
# Time: 11249.703s / 12000s | Acc: 92.77%
# Probability Policy: [Max: 12.26% - (Device 5) | Min: 0.97% | Std: 2.32% | Sum: 100.00% ]
# Time: 11265.915s / 12000s | Acc: 92.74%
# Probability Policy: [Max: 12.14% - (Device 5) | Min: 0.90% | Std: 2.31% | Sum: 100.00% ]
# Time: 11282.544s / 12000s | Acc: 91.05%
# Probability Policy: [Max: 8.82% - (Device 14) | Min: 0.90% | Std: 1.70% | Sum: 100.00% ]
# Time: 11298.904s / 12000s | Acc: 92.45%
# Probability Policy: [Max: 14.76% - (Device 5) | Min: 1.25% | Std: 2.67% | Sum: 100.00% ]
# Time: 11315.768s / 12000s | Acc: 89.78%
# Probability Policy: [Max: 9.02% - (Device 14) | Min: 0.50% | Std: 1.76% | Sum: 100.00% ]
# Time: 11332.678s / 12000s | Acc: 92.21%
# Probability Policy: [Max: 12.53% - (Device 5) | Min: 1.34% | Std: 2.37% | Sum: 100.00% ]
# Time: 11349.237s / 12000s | Acc: 93.83%
# Probability Policy: [Max: 21.52% - (Device 5) | Min: 1.43% | Std: 3.58% | Sum: 100.00% ]
# Time: 11365.449s / 12000s | Acc: 93.84%
# Probability Policy: [Max: 22.17% - (Device 5) | Min: 1.41% | Std: 3.70% | Sum: 100.00% ]
# Time: 11381.870s / 12000s | Acc: 94.42%
# Probability Policy: [Max: 27.19% - (Device 5) | Min: 1.48% | Std: 4.54% | Sum: 100.00% ]
# Time: 11398.432s / 12000s | Acc: 94.14%
# Probability Policy: [Max: 21.49% - (Device 5) | Min: 0.86% | Std: 3.58% | Sum: 100.00% ]
# Time: 11414.920s / 12000s | Acc: 94.25%
# Probability Policy: [Max: 27.72% - (Device 5) | Min: 1.14% | Std: 4.67% | Sum: 100.00% ]
# Time: 11431.757s / 12000s | Acc: 93.83%
# Probability Policy: [Max: 23.98% - (Device 5) | Min: 0.69% | Std: 4.04% | Sum: 100.00% ]
# Time: 11447.969s / 12000s | Acc: 93.84%
# Probability Policy: [Max: 24.03% - (Device 5) | Min: 0.69% | Std: 4.05% | Sum: 100.00% ]
# Time: 11464.832s / 12000s | Acc: 92.77%
# Probability Policy: [Max: 18.78% - (Device 5) | Min: 1.04% | Std: 3.24% | Sum: 100.00% ]
# Time: 11481.044s / 12000s | Acc: 92.81%
# Probability Policy: [Max: 19.23% - (Device 5) | Min: 1.06% | Std: 3.32% | Sum: 100.00% ]
# Time: 11497.603s / 12000s | Acc: 94.00%
# Probability Policy: [Max: 23.11% - (Device 5) | Min: 1.18% | Std: 3.82% | Sum: 100.00% ]
# Time: 11514.520s / 12000s | Acc: 92.38%
# Probability Policy: [Max: 6.84% - (Device 5) | Min: 0.84% | Std: 1.16% | Sum: 100.00% ]
# Time: 11530.830s / 12000s | Acc: 92.66%
# Probability Policy: [Max: 8.38% - (Device 5) | Min: 1.00% | Std: 1.35% | Sum: 100.00% ]
# Time: 11547.042s / 12000s | Acc: 93.27%
# Probability Policy: [Max: 13.80% - (Device 5) | Min: 0.94% | Std: 2.16% | Sum: 100.00% ]
# Time: 11563.909s / 12000s | Acc: 93.29%
# Probability Policy: [Max: 16.95% - (Device 5) | Min: 1.07% | Std: 2.78% | Sum: 100.00% ]
# Time: 11580.330s / 12000s | Acc: 94.04%
# Probability Policy: [Max: 26.54% - (Device 5) | Min: 1.14% | Std: 4.41% | Sum: 100.00% ]
# Time: 11596.542s / 12000s | Acc: 94.04%
# Probability Policy: [Max: 26.78% - (Device 5) | Min: 1.15% | Std: 4.46% | Sum: 100.00% ]
# Time: 11612.852s / 12000s | Acc: 94.04%
# Probability Policy: [Max: 23.44% - (Device 5) | Min: 0.99% | Std: 3.83% | Sum: 100.00% ]
# Time: 11629.064s / 12000s | Acc: 94.08%
# Probability Policy: [Max: 24.36% - (Device 5) | Min: 0.98% | Std: 4.00% | Sum: 100.00% ]
# Time: 11645.570s / 12000s | Acc: 93.56%
# Probability Policy: [Max: 18.52% - (Device 5) | Min: 1.27% | Std: 2.98% | Sum: 100.00% ]
# Time: 11662.058s / 12000s | Acc: 93.95%
# Probability Policy: [Max: 28.89% - (Device 5) | Min: 1.31% | Std: 4.86% | Sum: 100.00% ]
# Time: 11679.009s / 12000s | Acc: 94.18%
# Probability Policy: [Max: 19.21% - (Device 5) | Min: 0.82% | Std: 3.21% | Sum: 100.00% ]
# Time: 11695.568s / 12000s | Acc: 94.52%
# Probability Policy: [Max: 27.43% - (Device 5) | Min: 1.12% | Std: 4.56% | Sum: 100.00% ]
# Time: 11711.780s / 12000s | Acc: 94.59%
# Probability Policy: [Max: 28.26% - (Device 5) | Min: 1.11% | Std: 4.71% | Sum: 100.00% ]
# Time: 11728.647s / 12000s | Acc: 93.69%
# Probability Policy: [Max: 16.91% - (Device 5) | Min: 1.40% | Std: 2.83% | Sum: 100.00% ]
# Time: 11745.134s / 12000s | Acc: 93.76%
# Probability Policy: [Max: 21.09% - (Device 5) | Min: 0.91% | Std: 3.57% | Sum: 100.00% ]
# Time: 11761.904s / 12000s | Acc: 94.32%
# Probability Policy: [Max: 21.35% - (Device 5) | Min: 1.40% | Std: 3.61% | Sum: 100.00% ]
# Time: 11778.352s / 12000s | Acc: 94.43%
# Probability Policy: [Max: 29.61% - (Device 5) | Min: 1.44% | Std: 5.00% | Sum: 100.00% ]
# Time: 11794.564s / 12000s | Acc: 94.42%
# Probability Policy: [Max: 29.67% - (Device 5) | Min: 1.43% | Std: 5.01% | Sum: 100.00% ]
# Time: 11811.103s / 12000s | Acc: 93.98%
# Probability Policy: [Max: 28.12% - (Device 5) | Min: 1.18% | Std: 4.73% | Sum: 100.00% ]
# Time: 11827.872s / 12000s | Acc: 94.50%
# Probability Policy: [Max: 21.75% - (Device 5) | Min: 1.12% | Std: 3.54% | Sum: 100.00% ]
# Time: 11844.182s / 12000s | Acc: 93.96%
# Probability Policy: [Max: 19.47% - (Device 5) | Min: 0.95% | Std: 3.14% | Sum: 100.00% ]
# Time: 11860.811s / 12000s | Acc: 94.75%
# Probability Policy: [Max: 27.08% - (Device 5) | Min: 1.08% | Std: 4.50% | Sum: 100.00% ]
# Time: 11877.581s / 12000s | Acc: 94.68%
# Probability Policy: [Max: 21.97% - (Device 5) | Min: 1.10% | Std: 3.66% | Sum: 100.00% ]
# Time: 11894.351s / 12000s | Acc: 92.87%
# Probability Policy: [Max: 7.18% - (Device 14) | Min: 0.76% | Std: 1.43% | Sum: 100.00% ]
# Time: 11910.710s / 12000s | Acc: 94.01%
# Probability Policy: [Max: 16.48% - (Device 5) | Min: 0.99% | Std: 2.76% | Sum: 100.00% ]
# Time: 11927.423s / 12000s | Acc: 94.32%
# Probability Policy: [Max: 17.90% - (Device 5) | Min: 1.14% | Std: 2.89% | Sum: 100.00% ]
# Time: 11943.782s / 12000s | Acc: 94.47%
# Probability Policy: [Max: 23.86% - (Device 5) | Min: 1.27% | Std: 3.95% | Sum: 100.00% ]
# Time: 11960.649s / 12000s | Acc: 94.28%
# Probability Policy: [Max: 20.04% - (Device 5) | Min: 1.40% | Std: 3.30% | Sum: 100.00% ]
# Time: 11977.418s / 12000s | Acc: 93.97%
# Probability Policy: [Max: 14.05% - (Device 5) | Min: 0.96% | Std: 2.27% | Sum: 100.00% ]
# Time: 11993.777s / 12000s | Acc: 94.50%
# Probability Policy: [Max: 23.63% - (Device 5) | Min: 1.14% | Std: 3.91% | Sum: 100.00% ]
# Time: 12009.989s / 12000s | Acc: 94.56%

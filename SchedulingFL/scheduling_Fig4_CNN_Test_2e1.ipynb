# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Subset
from torchvision import datasets, transforms
import numpy as np
import matplotlib.pyplot as plt
import collections
import random

# %%
# --- 1. Wireless Environment Parameters ---
B_HZ = 1e6              # 1 MHz
N0_DBM_HZ = -174        # Noise density
P_TX_CLIENT_DBM = 24    # Uplink Power
P_TX_SERVER_DBM = 46    # Downlink Power (Server)
Q_BITS = 16             # 16-bit quantization
RADIUS_KM = 0.5         # 500m
DEVICE_GFLOPS = 2.0     # Average edge device speed (2 Billion operations/sec)

# %%
def plot_radar_map(r_km):
    """
    Plots 30 devices in a circular layout with index labels.
    Red triangle = Edge Server (Center)
    Blue dots = Edge Devices (Labeled 0-29)
    """
    # Generate random angles (theta) in radians
    theta = 2 * np.pi * np.random.rand(len(r_km)) 
    
    # Convert polar (r, theta) to Cartesian (x, y) for easier labeling
    x = r_km * np.cos(theta)
    y = r_km * np.sin(theta)
    
    plt.figure(figsize=(8, 8))
    
    # Plot the circular boundary (500m radius)
    circle = plt.Circle((0, 0), RADIUS_KM, color='gray', fill=False, linestyle='--', alpha=0.5)
    plt.gca().add_patch(circle)
    
    # Plot Edge Server at the center (0,0)
    plt.scatter(0, 0, c='red', marker='^', s=150, label='Edge Server', zorder=5)
    
    # Plot Edge Devices
    plt.scatter(x, y, c='skyblue', edgecolors='navy', s=80, alpha=0.8, label='Edge Devices')
    
    # Add Index Labels (0 to 29) for each device
    for i in range(len(r_km)):
        plt.annotate(f'{i}', (x[i], y[i]), xytext=(5, 5), 
                     textcoords='offset points', fontsize=9, fontweight='bold')

    plt.title(f"Device Distribution ({RADIUS_KM*1000}m Radius)")
    plt.xlabel("Distance (km)")
    plt.ylabel("Distance (km)")
    plt.legend(loc='upper right')
    plt.grid(True, alpha=0.2)
    plt.axis('equal') # Keep the circle from looking like an oval
    plt.xlim(-RADIUS_KM - 0.1, RADIUS_KM + 0.1)
    plt.ylim(-RADIUS_KM - 0.1, RADIUS_KM + 0.1)
    plt.show()

# %%
# --- 2. Model Architectures ---

class SVMModel(nn.Module):
    def __init__(self):
        super(SVMModel, self).__init__()
        self.fc = nn.Linear(3072, 1)
    def forward(self, x):
        return self.fc(x.view(x.size(0), -1))

class CNNModel(nn.Module):
    def __init__(self):
        super(CNNModel, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(1, 32, 5), nn.ReLU(), nn.MaxPool2d(2, 2),
            nn.Conv2d(32, 64, 5), nn.ReLU(), nn.MaxPool2d(2, 2)
        )
        self.fc = nn.Sequential(nn.Linear(64 * 4 * 4, 512), nn.ReLU(), nn.Linear(512, 10))
    def forward(self, x):
        x = self.conv(x)
        return self.fc(x.view(x.size(0), -1))

# %%
# --- 3. Data Preparation ---

def get_datasets(task='CNN'):
    # Define a shared seed for reproducibility if needed, 
    # or remove it for different random splits each time.
    random.seed(42) 
    np.random.seed(42)

    if task == 'SVM':
        transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])
        train_set = datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
        test_set = datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
        
        train_idx = [i for i, l in enumerate(train_set.targets) if l in [0, 1]]
        test_idx = [i for i, l in enumerate(test_set.targets) if l in [0, 1]]
        
        airplanes = [i for i in train_idx if train_set.targets[i] == 0][:15*330]
        autos = [i for i in train_idx if train_set.targets[i] == 1][:15*330]
        
        # Create the raw list of 30 Subsets
        all_subsets = [Subset(train_set, airplanes[i*330:(i+1)*330]) for i in range(15)] + \
                       [Subset(train_set, autos[i*330:(i+1)*330]) for i in range(15)]
        
        # RANDOMIZATION: Shuffle the list so 'Airplane devices' are spread 0-29
        random.shuffle(all_subsets)
        device_data = all_subsets
        
        return device_data, Subset(test_set, test_idx), SVMModel(), 0.0001

    else: # CNN Task (MNIST)
        transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))])
        train_set = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
        test_set = datasets.MNIST(root='./data', train=False, download=True, transform=transform)
        
        # Pathological Non-IID: Sort by label to create shards
        indices = np.argsort(train_set.targets.numpy())
        shards = [indices[i*1000 : (i+1)*1000] for i in range(60)]
        
        # RANDOMIZATION: Shuffle the shards so Device 0 doesn't 
        # automatically get the 'lowest' labels (0 and 1)
        random.shuffle(shards)
        
        # Each device gets 2 random shards (each shard is likely 1 digit)
        device_data = [Subset(train_set, np.concatenate((shards[i*2], shards[i*2+1]))) for i in range(30)]
        
        return device_data, test_set, CNNModel(), 0.005
    
def observe_distribution(device_data, task='CNN'):
    # Determine how many classes to show
    num_labels = 10 if task == 'CNN' else 2
    distribution_matrix = np.zeros((30, num_labels))

    for i in range(30):
        subset = device_data[i]
        # Robustly handle different dataset target formats
        targets = subset.dataset.targets
        subset_labels = [int(targets[idx]) for idx in subset.indices]
        
        counts = collections.Counter(subset_labels)
        for label, count in counts.items():
            # For SVM, only record if label is 0 or 1
            if label < num_labels:
                distribution_matrix[i, label] = count

    # Plotting
    plt.figure(figsize=(8, 8)) # Narrower figure for 2 columns
    im = plt.imshow(distribution_matrix, cmap='YlGnBu', aspect='auto')
    
    plt.colorbar(im, label='Number of Samples')
    plt.title(f'Non-IID Heatmap: {task} Task', fontsize=14)
    plt.xlabel('Class Label', fontsize=12)
    plt.ylabel('Device Index', fontsize=12)
    
    # Set x-ticks specifically to the number of labels
    plt.xticks(range(num_labels))
    # If SVM, label them appropriately
    if task == 'SVM':
        plt.gca().set_xticklabels(['0 (Airplane)', '1 (Auto)'])
    
    plt.yticks(range(0, 30, 2))
    plt.tight_layout()
    plt.show()

# %%
def get_optimal_probabilities(n_k_list, grad_norms, T_u_list, rho):
    """
    Implements Theorem 1 - Importance- and channel-aware scheduling policy.
    """
    n_total = sum(n_k_list)
    grad_norms = np.array(grad_norms) + 1e-12 
    T_u_list = np.array(T_u_list)
    num_devices = len(n_k_list)

    floor_value = 0.0001 # Each device gets at least 1% chance
    total_floor = num_devices * floor_value
    remaining_budget = 1.0 - total_floor

    def apply_gaussian_top3(values, reverse=False):
        # 1. Start everyone with the 1% floor
        p = np.full(num_devices, floor_value)
        
        # 2. Identify the Top 3
        sorted_indices = np.argsort(values)
        if not reverse:
            sorted_indices = sorted_indices[::-1]
            
        # 3. Distribute the remaining 40% budget using Gaussian weights
        # Weights: Rank1 (1.0), Rank2 (0.606), Rank3 (0.135) -> Sum = 1.741
        raw_weights = np.array([1.0, 0.606, 0.135])
        normalized_weights = raw_weights / np.sum(raw_weights) # Scale to sum to 1.0
        
        # Add the budgeted share to the floor
        p[sorted_indices[0]] += normalized_weights[0] * remaining_budget
        p[sorted_indices[1]] += normalized_weights[1] * remaining_budget
        p[sorted_indices[2]] += normalized_weights[2] * remaining_budget
        
        return p

    # 1. New Behavior for rho = 0 (Channel-aware: Top 3 Fastest)
    if rho == 0:
        return apply_gaussian_top3(T_u_list, reverse=True)

    # 2. New Behavior for rho = 1 (Importance-aware: Top 3 Most Informative)
    if rho == 1:
        # Importance includes data weight n_k/n
        importance = (np.array(n_k_list) / n_total) * grad_norms
        return apply_gaussian_top3(importance, reverse=False)

    # 3. Proposed Policy (Intermediate rho)
    def compute_p_star(lam):
        denom = (1 - rho) * T_u_list + lam
        p = (np.array(n_k_list) / n_total) * grad_norms * np.sqrt(rho / np.maximum(denom, 1e-15))
        return p

    low = -np.min((1 - rho) * T_u_list) + 1e-12
    high = 1e6 
    
    for _ in range(100):
        mid = (low + high) / 2
        if np.sum(compute_p_star(mid)) > 1: low = mid
        else: high = mid

    lambda_star  = high
    final_p_raw = compute_p_star(lambda_star)
    return final_p_raw / np.sum(final_p_raw)

# %%
def get_multi_device_selection(n_k_list, grad_norms, T_u_list_full_B, rho, M):
    """
    Implements Algorithm 1: Importance- and Channel-Aware Scheduling 
    without replacement for M devices.
    """

    num_devices = len(n_k_list)

    # --- Pure Channel-Aware (Fastest M) ---
    if rho == 0:
        # Get indices of the M smallest latency values
        selected_indices = np.argsort(T_u_list_full_B)[:M].tolist()
        # Create a uniform p_star just for logging purposes
        p_star = np.zeros(num_devices)
        p_star[selected_indices] = 1.0 / M
        return selected_indices, p_star
    
    # --- Pure Importance-Aware ---
    if rho == 1:
        # Importance calculation consistent with Equation 14
        importance = (np.array(n_k_list) / sum(n_k_list)) * np.array(grad_norms)
        # Get indices of the M largest importance values
        selected_indices = np.argsort(importance)[-M:][::-1].tolist()
        # Create a uniform p_star for logging
        p_star = np.zeros(num_devices)
        p_star[selected_indices] = 1.0 / M
        return selected_indices, p_star
    
    # 1. Compute optimal scheduling distribution P* (Equation 25)
    p_star = get_optimal_probabilities(n_k_list, grad_norms, T_u_list_full_B, rho)
    
    selected_indices = []
    current_p = p_star.copy()
    
    for m in range(M):
        # Normalize current distribution to ensure sum = 1
        current_p = current_p / np.sum(current_p)
        
        # 2. Randomly select device based on conditional distribution
        idx = np.random.choice(range(len(p_star)), p=current_p)
        selected_indices.append(idx)
        
        # 3. The probability for this selected device becomes 0 in the next step
        current_p[idx] = 0
        
    return selected_indices, p_star

# %%
# --- 5. Main Training Logic ---

def run_multi_device_fl(task='SVM', training_time=10, rho=5e-6, M=10, r_km= RADIUS_KM * np.sqrt(np.random.rand(30))):
    device_data, test_set, global_model, lr = get_datasets(task)
    test_loader = DataLoader(test_set, batch_size=1000, shuffle=False)
    n_k_list = [len(d) for d in device_data]
    n_total = sum(n_k_list)
    lmbda = 0.01 
    # Force 5 devices to be at the cell edge (450m - 500m) 
    # and 25 devices to be distributed normally.
    r_km = RADIUS_KM * np.sqrt(np.random.rand(30))
    r_km[:5] = 0.45 + (np.random.rand(5) * 0.05)
    
    history = {'acc': [], 'time': []}
    cumulative_time = 0

    print(f"\n--- Multi-Device Simulation: {task} | M={M} | Training Time: {training_time}s ---")

    while cumulative_time < training_time:
        # Communication Model 
        path_loss_db = 128.1 + 37.6 * np.log10(np.maximum(r_km, 0.01))
        
        noise_up_w = 10**(((N0_DBM_HZ + 10 * np.log10(B_HZ)) - 30) / 10)
        p_rx_up_w = 10**(((P_TX_CLIENT_DBM - path_loss_db) - 30) / 10)
        gamma_up = p_rx_up_w / noise_up_w
        
        p_rx_down_w = 10**(((P_TX_SERVER_DBM - path_loss_db) - 30) / 10)
        gamma_down_min = np.min(p_rx_down_w / noise_up_w) 
        
        num_params = sum(p.numel() for p in global_model.parameters())
        payload_bits = num_params * Q_BITS
        T_u_full_B = payload_bits / (B_HZ * np.log2(1 + gamma_up))

        # Importance Evaluation
        grad_norms = []
        client_gradients = []
        for i in range(30):
            # Step 1: Global Model Broadcast
            local_model = type(global_model)()
            local_model.load_state_dict(global_model.state_dict())
            loader = DataLoader(device_data[i], batch_size=len(device_data[i]))
            data, target = next(iter(loader))
            local_model.zero_grad()

            # Step 2: Local Gradient Calculation
            output = local_model(data).squeeze()
            if task == 'SVM':
                target_svm = (target.float() * 2) - 1 
                loss = 0.5 * torch.mean(torch.clamp(1 - target_svm * output, min=0)) + (lmbda / 2.0) * sum(p.pow(2).sum() for p in local_model.parameters())
            else:
                target_oh = torch.nn.functional.one_hot(target, num_classes=10).float()
                loss = 0.5 * torch.nn.functional.mse_loss(output, target_oh, reduction='mean')
            
            # Step 3: Importance Indicator Report
            loss.backward()
            grads = [p.grad.detach().clone() for p in local_model.parameters()]
            grad_norms.append(torch.norm(torch.cat([g.view(-1) for g in grads])).item())
            client_gradients.append(grads)

        # Step 4: Device Selection and Resource Allocation
        selected_indices, p_star = get_multi_device_selection(n_k_list, grad_norms, T_u_full_B, rho, M)
        print(f"Probability Policy: [Max: {100 * np.max(p_star):.2f}% - (Device {np.argmax(p_star)}) | "
        f"Min: {100 * np.min(p_star):.2f}% | Std: {100 * np.std(p_star):.2f}% | Sum: {100 * np.sum(p_star):.2f}% ]"
        f"\nSelected Devices: {selected_indices}" )

        # Step 5: Local Gradient Upload (Simulate Latency with Bandwidth Allocation - Theorem 3)
        # 1. Calculate the rate per unit bandwidth for selected devices
        R_k = np.log2(1 + gamma_up[selected_indices])
        
        # 2. Apply Theorem 3: Optimal Parallel Upload Time
        # This allows multiple devices to share the 'B' bandwidth efficiently
        sum_sqrt_inv_R = np.sum(np.sqrt(1.0 / R_k))
        t_upload_parallel = (payload_bits / B_HZ) * (sum_sqrt_inv_R**2)
        
        # 3. Standard overheads
        t_broadcast = payload_bits / (B_HZ * np.log2(1 + gamma_down_min))
        t_comp_max = (max(n_k_list) * 6000) / (DEVICE_GFLOPS * 1e9)
        
        # Total time for this specific round
        round_time = t_broadcast + t_comp_max + t_upload_parallel
        cumulative_time += round_time

        # Step 6: Global Model Update (Equation 29)
        with torch.no_grad():
            global_grad_sum = [torch.zeros_like(p) for p in global_model.parameters()]
            
            for m, idx in enumerate(selected_indices):
                if rho == 0 or rho == 1:
                    # --- FedAvg Style (Simple Average) ---
                    # We ignore the selection probability scaling entirely.
                    # Each of the M selected devices contributes 1/M to the update.
                    for g_sum, g_local in zip(global_grad_sum, client_gradients[idx]):
                        g_sum += (1.0 / M) * g_local
                else:
                    # --- Proposed Policy Style (Unbiased Estimator) ---
                    # Calculate conditional probability q_Y_m for Theorem 1 correctness
                    sum_prev_p = sum(p_star[selected_indices[j]] for j in range(m))
                    q_Y_m = p_star[idx] / np.maximum(1.0 - sum_prev_p, 1e-10)
                    
                    # Apply importance scale based on Equation 29
                    scale = n_k_list[idx] / (n_total * q_Y_m)
                    
                    for g_sum, g_local in zip(global_grad_sum, client_gradients[idx]):
                        # Clip only the proposed update to handle potential variance
                        update_val = (1.0 / M) * scale * g_local
                        g_sum += torch.clamp(update_val, min=-10.0, max=10.0)
            
            # Update global weights
            for p_global, g_agg in zip(global_model.parameters(), global_grad_sum):
                p_global -= lr * g_agg

        # Evaluation
        global_model.eval()
        correct, total = 0, 0
        with torch.no_grad():
            for data, target in test_loader:
                output = global_model(data)
                pred = torch.sign(output.squeeze()) if task == 'SVM' else output.argmax(1)
                labels = (target.float()*2-1) if task == 'SVM' else target
                correct += (pred == labels).sum().item()
                total += target.size(0)
        
        acc = 100. * correct / total
        history['acc'].append(acc)
        history['time'].append(cumulative_time)
        
        print(f"Time: {cumulative_time:.3f}s / {training_time}s | Acc: {acc:.2f}%")

    return history

# %%
def run_multi_comparison(task='SVM', training_time=10):
    """
    Executes all multi-device scheduling policies for a specific task and plots the results.
    """
    # Define task-specific parameters based on Section VI.C 
    if task == 'SVM':
        M_devices = 10
        rhos = {0: 'Channel-aware', 
                1: 'Importance-aware',
                5e-4: 'Proposed (5e-4)',
                5e-6: 'Proposed (5e-6)'}
        time_scale = 1 # Seconds
        x_label = "Training Time (seconds)"
    else: # CNN
        M_devices = 3
        rhos = {0: 'Channel-aware', 
                1: 'Importance-aware', 
                1e-2: 'Proposed (1e-2)',
                1e-3: 'Proposed (1e-3)'}
        time_scale = 60 # Minutes
        x_label = "Training Time (minutes)"
    
    results = {}
    # Force 5 devices to be at the cell edge (450m - 500m) 
    # and 25 devices to be distributed normally.
    r_km = RADIUS_KM * np.sqrt(np.random.rand(30))
    r_km[:5] = 0.45 + (np.random.rand(5) * 0.05)
    plot_radar_map(r_km)

    print(f"--- Starting {task} Multi-Device Comparison (M={M_devices}) ---")
    for rho, label in rhos.items():
        print(f"Running {label} (rho={rho})...")
        # Ensure fresh model for each policy run
        results[label] = run_multi_device_fl(task=task, training_time=training_time, rho=rho, M=M_devices, r_km=r_km)

    # --- Plotting Results (Replicating Figure 4) ---
    plt.figure(figsize=(10, 6))
    for label, hist in results.items():
        # Convert time to appropriate scale (seconds or minutes)
        plt.plot(np.array(hist['time']) / time_scale, hist['acc'], label=label)
    
    plt.title(f"Multi-Device Performance Comparison: {task} Model (M={M_devices})")
    plt.xlabel(x_label)
    plt.ylabel("Test Accuracy (%)")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()

# To execute the multi-device simulation:
# run_multi_comparison(task='SVM', training_time=10)
# run_multi_comparison(task='CNN', training_time=50)

# %%
# Force 5 devices to be at the cell edge (450m - 500m) 
# and 25 devices to be distributed normally.
r_km = RADIUS_KM * np.sqrt(np.random.rand(30))
r_km[:5] = 0.45 + (np.random.rand(5) * 0.05)
plot_radar_map(r_km)

# %%
def plot_fl_history(history, task_name="CNN", rho=0.01, M=3):
    # Extract data
    times = np.array(history['time'])
    accs = np.array(history['acc'])
    
    # Optional: Convert time to minutes if it's very long
    time_label = "Time (Seconds)"
    if times[-1] > 600:
        times = times / 60
        time_label = "Time (Minutes)"

    plt.figure(figsize=(10, 6))
    
    # Plot the raw accuracy (thin, light color)
    plt.plot(times, accs, alpha=0.3, color='steelblue', label='Raw Accuracy')
    
    # Plot a moving average (thick, bold color) to see the trend
    window_size = 10
    if len(accs) > window_size:
        smoothed_accs = np.convolve(accs, np.ones(window_size)/window_size, mode='valid')
        plt.plot(times[window_size-1:], smoothed_accs, color='navy', linewidth=2, label=f'Trend ({window_size}-round MA)')

    # Labels and Styling
    plt.title(f"Federated Learning Performance: {task_name}\n($\\rho={rho}$, $M={M}$ devices)", fontsize=14)
    plt.xlabel(time_label, fontsize=12)
    plt.ylabel("Test Accuracy (%)", fontsize=12)
    plt.grid(True, which='both', linestyle='--', alpha=0.5)
    plt.legend()
    
    # Highlight the final accuracy
    plt.axhline(y=accs[-1], color='red', linestyle=':', alpha=0.6)
    plt.text(times[0], accs[-1], f'Final: {accs[-1]:.2f}%', color='red', fontweight='bold', va='bottom')

    plt.tight_layout()
    plt.show()

# %%
import re
import matplotlib.pyplot as plt
import numpy as np

def extract_fl_logs_final(file_path, keyword, max_time=12000):
    """
    Ultra-robust extractor:
    1. Identifies the section by looking for the keyword (e.g., 'Channel').
    2. Extracts the first two numbers on any line containing 'Time' and 'Acc'.
    """
    data = {'acc': [], 'time': []}
    is_target_section = False
    
    try:
        with open(file_path, 'r') as f:
            for line in f:
                line_clean = line.strip()
                if not line_clean: continue
                
                # Update section toggle
                if ">>>" in line_clean or "Running" in line_clean:
                    if keyword.lower() in line_clean.lower():
                        is_target_section = True
                    else:
                        is_target_section = False
                
                # Extract data
                if is_target_section and "Time" in line_clean and "Acc" in line_clean:
                    # Find all numbers (integers or decimals) in the line
                    nums = re.findall(r"[-+]?\d*\.\d+|\d+", line_clean)
                    if len(nums) >= 2:
                        t = float(nums[0])
                        a = float(nums[1])
                        if t <= max_time:
                            data['time'].append(t)
                            data['acc'].append(a)
        return data
    except FileNotFoundError:
        print(f"Error: '{file_path}' not found.")
        return data

# --- 1. DATA EXTRACTION ---
log_file = 'output.log'
his1 = extract_fl_logs_final(log_file, "Channel", max_time=12000)
his2 = extract_fl_logs_final(log_file, "Importance", max_time=12000)
# Assuming 'his' (Proposed) is already defined or extracted similarly:
# his = extract_fl_logs_final(log_file, "Proposed", max_time=12000)

print(f"✅ Extraction Results:")
print(f"his1 (Channel): {len(his1['acc'])} rounds")
print(f"his2 (Importance): {len(his2['acc'])} rounds")

# --- 2. PLOTTING ---
if len(his1['acc']) > 0 or len(his2['acc']) > 0:
    plt.figure(figsize=(11, 6))

    def add_to_plot(history, label, color):
        if not history['acc']: return
        
        times = np.array(history['time']) / 60 # Minutes
        accs = np.array(history['acc'])
        
        # Raw data (faded)
        plt.plot(times, accs, alpha=0.15, color=color)
        
        # Trend line (Moving Average)
        window = 15
        if len(accs) > window:
            smoothed = np.convolve(accs, np.ones(window)/window, mode='valid')
            plt.plot(times[window-1:], smoothed, label=label, color=color, linewidth=2.5)
        else:
            plt.plot(times, accs, label=label, color=color, linewidth=2.5)

    add_to_plot(his1, "Channel-aware ($\\rho=0$)", "tab:blue")
    add_to_plot(his2, "Importance-aware ($\\rho=1$)", "tab:orange")
    # add_to_plot(his, "Proposed ($\\rho=0.2$)", "tab:green")

    plt.title("Performance Comparison: CNN Model (M=3)", fontsize=14)
    plt.xlabel("Training Time (Minutes)", fontsize=12)
    plt.ylabel("Test Accuracy (%)", fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.3)
    plt.legend(loc='lower right')
    plt.tight_layout()
    plt.show()
else:
    print("❌ No data found to plot. Please check if 'output.log' contains the keywords.")
# Out:
# Extraction Complete!
# his1 (Channel) rounds: 0
# his2 (Importance) rounds: 0

# %%
import matplotlib.pyplot as plt
import numpy as np

def extract_fl_logs_final(file_path, keyword, max_time=12000):
    """
    Ultra-reliable extractor:
    - Finds the section by matching the keyword (Case-insensitive)
    - Extracts 'Time' and 'Acc' by splitting strings (ignores weird characters)
    """
    data = {'acc': [], 'time': []}
    is_correct_section = False
    
    try:
        with open(file_path, 'r') as f:
            for line in f:
                line = line.strip()
                if not line: continue

                # 1. Detect the Start of a Section
                # Checks if "Running" is in line AND the keyword is in line
                if "Running" in line or ">>>" in line:
                    if keyword.lower() in line.lower():
                        is_correct_section = True
                    else:
                        is_correct_section = False
                
                # 2. Extract Data if we are in the correct section
                if is_correct_section and "Time:" in line and "Acc:" in line:
                    try:
                        # Extract Time: Find number between 'Time:' and 's'
                        time_str = line.split("Time:")[1].split("s")[0].strip()
                        # Extract Acc: Find number between 'Acc:' and '%'
                        acc_str = line.split("Acc:")[1].split("%")[0].strip()
                        
                        t = float(time_str)
                        a = float(acc_str)
                        
                        if t <= max_time:
                            data['time'].append(t)
                            data['acc'].append(a)
                    except (IndexError, ValueError):
                        continue # Skip lines that don't match numerical format
        return data
    except FileNotFoundError:
        print(f"Error: File '{file_path}' not found.")
        return data

# --- 1. SETUP AND EXTRACTION ---
log_file = 'output.log'

# Extraction for all 3 cases
his1 = extract_fl_logs_final(log_file, "Channel", max_time=12000)
his2 = extract_fl_logs_final(log_file, "Importance", max_time=12000)

# %%
his = run_multi_device_fl(task='CNN', training_time=12000, rho= 2e-1, M=3, r_km=r_km)
# Out:
# --- Multi-Device Simulation: CNN | M=3 | Training Time: 12000s ---
# Probability Policy: [Max: 54.42% - (Device 10) | Min: 0.84% | Std: 9.50% | Sum: 100.00% ]
# Selected Devices: [19, 10, 3]
# Time: 8.609s / 12000s | Acc: 10.02%
# Probability Policy: [Max: 54.88% - (Device 10) | Min: 0.82% | Std: 9.59% | Sum: 100.00% ]
# Selected Devices: [10, 14, 4]
# Time: 16.925s / 12000s | Acc: 10.06%
# Probability Policy: [Max: 55.18% - (Device 10) | Min: 0.81% | Std: 9.64% | Sum: 100.00% ]
# Selected Devices: [10, 1, 28]
# Time: 25.922s / 12000s | Acc: 10.10%
# Probability Policy: [Max: 55.58% - (Device 10) | Min: 0.81% | Std: 9.72% | Sum: 100.00% ]
# Selected Devices: [10, 21, 8]
# Time: 33.575s / 12000s | Acc: 10.08%
# Probability Policy: [Max: 55.91% - (Device 10) | Min: 0.81% | Std: 9.78% | Sum: 100.00% ]
# Selected Devices: [10, 18, 5]
# Time: 41.013s / 12000s | Acc: 10.18%
# Probability Policy: [Max: 56.19% - (Device 10) | Min: 0.80% | Std: 9.83% | Sum: 100.00% ]
# Selected Devices: [29, 14, 25]
# Time: 49.342s / 12000s | Acc: 10.20%
# Probability Policy: [Max: 56.72% - (Device 10) | Min: 0.79% | Std: 9.93% | Sum: 100.00% ]
# Selected Devices: [24, 10, 28]
# Time: 57.743s / 12000s | Acc: 10.25%
# Probability Policy: [Max: 57.15% - (Device 10) | Min: 0.77% | Std: 10.01% | Sum: 100.00% ]
# Selected Devices: [6, 10, 1]
# Time: 65.336s / 12000s | Acc: 10.24%
# Probability Policy: [Max: 57.42% - (Device 10) | Min: 0.77% | Std: 10.06% | Sum: 100.00% ]
# Selected Devices: [10, 13, 7]
# Time: 73.584s / 12000s | Acc: 10.28%
# Probability Policy: [Max: 57.63% - (Device 10) | Min: 0.76% | Std: 10.10% | Sum: 100.00% ]
# Selected Devices: [19, 10, 8]
# Time: 81.664s / 12000s | Acc: 10.30%
# Probability Policy: [Max: 58.01% - (Device 10) | Min: 0.74% | Std: 10.16% | Sum: 100.00% ]
# Selected Devices: [10, 4, 26]
# Time: 90.034s / 12000s | Acc: 10.35%
# Probability Policy: [Max: 58.31% - (Device 10) | Min: 0.73% | Std: 10.22% | Sum: 100.00% ]
# Selected Devices: [5, 29, 13]
# Time: 97.271s / 12000s | Acc: 10.53%
# Probability Policy: [Max: 58.85% - (Device 10) | Min: 0.74% | Std: 10.32% | Sum: 100.00% ]
# Selected Devices: [10, 0, 26]
# Time: 105.555s / 12000s | Acc: 10.69%
# Probability Policy: [Max: 59.12% - (Device 10) | Min: 0.74% | Std: 10.37% | Sum: 100.00% ]
# Selected Devices: [10, 23, 24]
# Time: 113.558s / 12000s | Acc: 10.51%
# Probability Policy: [Max: 59.30% - (Device 10) | Min: 0.73% | Std: 10.40% | Sum: 100.00% ]
# Selected Devices: [5, 10, 3]
# Time: 121.784s / 12000s | Acc: 10.85%
# Probability Policy: [Max: 59.51% - (Device 10) | Min: 0.74% | Std: 10.44% | Sum: 100.00% ]
# Selected Devices: [21, 10, 9]
# Time: 129.590s / 12000s | Acc: 10.85%
# Probability Policy: [Max: 59.75% - (Device 10) | Min: 0.73% | Std: 10.49% | Sum: 100.00% ]
# Selected Devices: [5, 10, 11]
# Time: 137.792s / 12000s | Acc: 11.29%
# Probability Policy: [Max: 59.99% - (Device 10) | Min: 0.74% | Std: 10.53% | Sum: 100.00% ]
# Selected Devices: [10, 20, 27]
# Time: 146.325s / 12000s | Acc: 11.42%
# Probability Policy: [Max: 60.26% - (Device 10) | Min: 0.74% | Std: 10.58% | Sum: 100.00% ]
# Selected Devices: [10, 4, 23]
# Time: 155.107s / 12000s | Acc: 11.44%
# Probability Policy: [Max: 60.47% - (Device 10) | Min: 0.74% | Std: 10.62% | Sum: 100.00% ]
# Selected Devices: [13, 10, 24]
# Time: 162.755s / 12000s | Acc: 11.50%
# Probability Policy: [Max: 60.69% - (Device 10) | Min: 0.73% | Std: 10.66% | Sum: 100.00% ]
# Selected Devices: [10, 17, 14]
# Time: 170.429s / 12000s | Acc: 11.48%
# Probability Policy: [Max: 60.77% - (Device 10) | Min: 0.72% | Std: 10.68% | Sum: 100.00% ]
# Selected Devices: [2, 9, 3]
# Time: 182.196s / 12000s | Acc: 11.74%
# Probability Policy: [Max: 61.30% - (Device 10) | Min: 0.72% | Std: 10.77% | Sum: 100.00% ]
# Selected Devices: [10, 9, 17]
# Time: 190.893s / 12000s | Acc: 11.45%
# Probability Policy: [Max: 61.42% - (Device 10) | Min: 0.71% | Std: 10.80% | Sum: 100.00% ]
# Selected Devices: [24, 10, 13]
# Time: 198.541s / 12000s | Acc: 11.14%
# Probability Policy: [Max: 61.51% - (Device 10) | Min: 0.70% | Std: 10.81% | Sum: 100.00% ]
# Selected Devices: [12, 10, 2]
# Time: 207.873s / 12000s | Acc: 11.52%
# Probability Policy: [Max: 61.84% - (Device 10) | Min: 0.71% | Std: 10.87% | Sum: 100.00% ]
# Selected Devices: [10, 5, 29]
# Time: 214.209s / 12000s | Acc: 11.75%
# Probability Policy: [Max: 61.90% - (Device 10) | Min: 0.72% | Std: 10.89% | Sum: 100.00% ]
# Selected Devices: [16, 10, 27]
# Time: 222.181s / 12000s | Acc: 11.93%
# Probability Policy: [Max: 62.03% - (Device 10) | Min: 0.72% | Std: 10.91% | Sum: 100.00% ]
# Selected Devices: [15, 10, 27]
# Time: 229.843s / 12000s | Acc: 12.28%
# Probability Policy: [Max: 62.21% - (Device 10) | Min: 0.72% | Std: 10.94% | Sum: 100.00% ]
# Selected Devices: [10, 25, 28]
# Time: 238.763s / 12000s | Acc: 12.79%
# Probability Policy: [Max: 62.29% - (Device 10) | Min: 0.72% | Std: 10.96% | Sum: 100.00% ]
# Selected Devices: [10, 3, 7]
# Time: 248.371s / 12000s | Acc: 12.68%
# Probability Policy: [Max: 62.29% - (Device 10) | Min: 0.72% | Std: 10.96% | Sum: 100.00% ]
# Selected Devices: [10, 26, 27]
# Time: 256.081s / 12000s | Acc: 12.95%
# Probability Policy: [Max: 62.42% - (Device 10) | Min: 0.72% | Std: 10.98% | Sum: 100.00% ]
# Selected Devices: [0, 10, 14]
# Time: 264.310s / 12000s | Acc: 13.31%
# Probability Policy: [Max: 62.55% - (Device 10) | Min: 0.73% | Std: 11.01% | Sum: 100.00% ]
# Selected Devices: [10, 4, 12]
# Time: 273.875s / 12000s | Acc: 13.53%
# Probability Policy: [Max: 62.66% - (Device 10) | Min: 0.73% | Std: 11.03% | Sum: 100.00% ]
# Selected Devices: [26, 10, 16]
# Time: 281.199s / 12000s | Acc: 14.34%
# Probability Policy: [Max: 62.80% - (Device 10) | Min: 0.73% | Std: 11.05% | Sum: 100.00% ]
# Selected Devices: [10, 12, 29]
# Time: 288.699s / 12000s | Acc: 14.82%
# Probability Policy: [Max: 62.84% - (Device 10) | Min: 0.74% | Std: 11.06% | Sum: 100.00% ]
# Selected Devices: [28, 10, 15]
# Time: 296.483s / 12000s | Acc: 14.84%
# Probability Policy: [Max: 63.01% - (Device 10) | Min: 0.74% | Std: 11.09% | Sum: 100.00% ]
# Selected Devices: [10, 8, 1]
# Time: 305.494s / 12000s | Acc: 15.42%
# Probability Policy: [Max: 63.07% - (Device 10) | Min: 0.75% | Std: 11.10% | Sum: 100.00% ]
# Selected Devices: [10, 16, 2]
# Time: 313.918s / 12000s | Acc: 15.59%
# Probability Policy: [Max: 63.13% - (Device 10) | Min: 0.75% | Std: 11.11% | Sum: 100.00% ]
# Selected Devices: [10, 28, 6]
# Time: 321.178s / 12000s | Acc: 15.67%
# Probability Policy: [Max: 63.19% - (Device 10) | Min: 0.75% | Std: 11.12% | Sum: 100.00% ]
# Selected Devices: [10, 16, 29]
# Time: 327.874s / 12000s | Acc: 16.10%
# Probability Policy: [Max: 63.20% - (Device 10) | Min: 0.75% | Std: 11.12% | Sum: 100.00% ]
# Selected Devices: [10, 21, 24]
# Time: 335.297s / 12000s | Acc: 15.97%
# Probability Policy: [Max: 63.22% - (Device 10) | Min: 0.75% | Std: 11.13% | Sum: 100.00% ]
# Selected Devices: [10, 23, 12]
# Time: 343.871s / 12000s | Acc: 16.39%
# Probability Policy: [Max: 63.29% - (Device 10) | Min: 0.75% | Std: 11.14% | Sum: 100.00% ]
# Selected Devices: [10, 20, 17]
# Time: 352.422s / 12000s | Acc: 16.59%
# Probability Policy: [Max: 63.37% - (Device 10) | Min: 0.75% | Std: 11.16% | Sum: 100.00% ]
# Selected Devices: [6, 18, 10]
# Time: 359.432s / 12000s | Acc: 16.82%
# Probability Policy: [Max: 63.51% - (Device 10) | Min: 0.75% | Std: 11.18% | Sum: 100.00% ]
# Selected Devices: [10, 1, 19]
# Time: 367.851s / 12000s | Acc: 16.98%
# Probability Policy: [Max: 63.53% - (Device 10) | Min: 0.74% | Std: 11.19% | Sum: 100.00% ]
# Selected Devices: [10, 0, 17]
# Time: 376.844s / 12000s | Acc: 17.44%
# Probability Policy: [Max: 63.58% - (Device 10) | Min: 0.74% | Std: 11.20% | Sum: 100.00% ]
# Selected Devices: [10, 21, 5]
# Time: 383.610s / 12000s | Acc: 17.96%
# Probability Policy: [Max: 63.61% - (Device 10) | Min: 0.75% | Std: 11.20% | Sum: 100.00% ]
# Selected Devices: [10, 13, 29]
# Time: 390.100s / 12000s | Acc: 18.28%
# Probability Policy: [Max: 63.64% - (Device 10) | Min: 0.75% | Std: 11.21% | Sum: 100.00% ]
# Selected Devices: [10, 11, 3]
# Time: 399.850s / 12000s | Acc: 18.29%
# Probability Policy: [Max: 63.63% - (Device 10) | Min: 0.75% | Std: 11.20% | Sum: 100.00% ]
# Selected Devices: [25, 21, 10]
# Time: 407.760s / 12000s | Acc: 19.35%
# Probability Policy: [Max: 63.63% - (Device 10) | Min: 0.76% | Std: 11.20% | Sum: 100.00% ]
# Selected Devices: [10, 26, 17]
# Time: 415.486s / 12000s | Acc: 19.63%
# Probability Policy: [Max: 63.68% - (Device 10) | Min: 0.75% | Std: 11.21% | Sum: 100.00% ]
# Selected Devices: [10, 6, 3]
# Time: 423.259s / 12000s | Acc: 19.48%
# Probability Policy: [Max: 63.66% - (Device 10) | Min: 0.76% | Std: 11.21% | Sum: 100.00% ]
# Selected Devices: [22, 23, 10]
# Time: 430.940s / 12000s | Acc: 20.07%
# Probability Policy: [Max: 63.78% - (Device 10) | Min: 0.76% | Std: 11.23% | Sum: 100.00% ]
# Selected Devices: [10, 11, 23]
# Time: 439.692s / 12000s | Acc: 19.98%
# Probability Policy: [Max: 63.80% - (Device 10) | Min: 0.76% | Std: 11.24% | Sum: 100.00% ]
# Selected Devices: [22, 21, 11]
# Time: 449.082s / 12000s | Acc: 20.07%
# Probability Policy: [Max: 63.75% - (Device 10) | Min: 0.75% | Std: 11.23% | Sum: 100.00% ]
# Selected Devices: [10, 3, 6]
# Time: 456.855s / 12000s | Acc: 19.70%
# Probability Policy: [Max: 63.72% - (Device 10) | Min: 0.75% | Std: 11.22% | Sum: 100.00% ]
# Selected Devices: [22, 10, 0]
# Time: 465.382s / 12000s | Acc: 20.51%
# Probability Policy: [Max: 63.74% - (Device 10) | Min: 0.73% | Std: 11.23% | Sum: 100.00% ]
# Selected Devices: [8, 10, 0]
# Time: 474.504s / 12000s | Acc: 20.49%
# Probability Policy: [Max: 63.81% - (Device 10) | Min: 0.72% | Std: 11.24% | Sum: 100.00% ]
# Selected Devices: [10, 18, 22]
# Time: 482.307s / 12000s | Acc: 20.79%
# Probability Policy: [Max: 63.84% - (Device 10) | Min: 0.72% | Std: 11.24% | Sum: 100.00% ]
# Selected Devices: [10, 6, 23]
# Time: 489.201s / 12000s | Acc: 20.94%
# Probability Policy: [Max: 63.89% - (Device 10) | Min: 0.72% | Std: 11.25% | Sum: 100.00% ]
# Selected Devices: [10, 11, 23]
# Time: 497.954s / 12000s | Acc: 20.71%
# Probability Policy: [Max: 63.89% - (Device 10) | Min: 0.72% | Std: 11.25% | Sum: 100.00% ]
# Selected Devices: [10, 26, 20]
# Time: 505.815s / 12000s | Acc: 21.12%
# Probability Policy: [Max: 63.96% - (Device 10) | Min: 0.72% | Std: 11.27% | Sum: 100.00% ]
# Selected Devices: [10, 3, 13]
# Time: 514.218s / 12000s | Acc: 21.07%
# Probability Policy: [Max: 63.94% - (Device 10) | Min: 0.72% | Std: 11.26% | Sum: 100.00% ]
# Selected Devices: [10, 7, 29]
# Time: 521.759s / 12000s | Acc: 21.20%
# Probability Policy: [Max: 63.96% - (Device 10) | Min: 0.73% | Std: 11.27% | Sum: 100.00% ]
# Selected Devices: [10, 27, 19]
# Time: 529.702s / 12000s | Acc: 21.15%
# Probability Policy: [Max: 64.02% - (Device 10) | Min: 0.73% | Std: 11.28% | Sum: 100.00% ]
# Selected Devices: [14, 10, 19]
# Time: 536.947s / 12000s | Acc: 20.84%
# Probability Policy: [Max: 64.03% - (Device 10) | Min: 0.74% | Std: 11.28% | Sum: 100.00% ]
# Selected Devices: [10, 6, 23]
# Time: 543.841s / 12000s | Acc: 21.08%
# Probability Policy: [Max: 64.06% - (Device 10) | Min: 0.74% | Std: 11.29% | Sum: 100.00% ]
# Selected Devices: [10, 1, 21]
# Time: 551.823s / 12000s | Acc: 21.02%
# Probability Policy: [Max: 64.04% - (Device 10) | Min: 0.74% | Std: 11.28% | Sum: 100.00% ]
# Selected Devices: [10, 29, 27]
# Time: 558.885s / 12000s | Acc: 21.46%
# Probability Policy: [Max: 64.08% - (Device 10) | Min: 0.74% | Std: 11.29% | Sum: 100.00% ]
# Selected Devices: [24, 10, 0]
# Time: 567.755s / 12000s | Acc: 21.37%
# Probability Policy: [Max: 64.12% - (Device 10) | Min: 0.74% | Std: 11.30% | Sum: 100.00% ]
# Selected Devices: [25, 10, 29]
# Time: 575.195s / 12000s | Acc: 22.56%
# Probability Policy: [Max: 64.06% - (Device 10) | Min: 0.75% | Std: 11.28% | Sum: 100.00% ]
# Selected Devices: [27, 18, 10]
# Time: 583.425s / 12000s | Acc: 22.78%
# Probability Policy: [Max: 64.22% - (Device 10) | Min: 0.75% | Std: 11.31% | Sum: 100.00% ]
# Selected Devices: [10, 26, 9]
# Time: 591.425s / 12000s | Acc: 22.83%
# Probability Policy: [Max: 64.25% - (Device 10) | Min: 0.75% | Std: 11.32% | Sum: 100.00% ]
# Selected Devices: [10, 18, 29]
# Time: 598.355s / 12000s | Acc: 23.05%
# Probability Policy: [Max: 64.27% - (Device 10) | Min: 0.75% | Std: 11.32% | Sum: 100.00% ]
# Selected Devices: [10, 18, 3]
# Time: 607.264s / 12000s | Acc: 23.11%
# Probability Policy: [Max: 64.25% - (Device 10) | Min: 0.76% | Std: 11.32% | Sum: 100.00% ]
# Selected Devices: [10, 29, 4]
# Time: 614.957s / 12000s | Acc: 23.07%
# Probability Policy: [Max: 64.27% - (Device 10) | Min: 0.76% | Std: 11.32% | Sum: 100.00% ]
# Selected Devices: [10, 27, 22]
# Time: 622.901s / 12000s | Acc: 23.25%
# Probability Policy: [Max: 64.30% - (Device 10) | Min: 0.75% | Std: 11.33% | Sum: 100.00% ]
# Selected Devices: [10, 22, 11]
# Time: 631.488s / 12000s | Acc: 23.21%
# Probability Policy: [Max: 64.28% - (Device 10) | Min: 0.75% | Std: 11.32% | Sum: 100.00% ]
# Selected Devices: [10, 25, 26]
# Time: 639.593s / 12000s | Acc: 23.54%
# Probability Policy: [Max: 64.26% - (Device 10) | Min: 0.75% | Std: 11.32% | Sum: 100.00% ]
# Selected Devices: [20, 24, 10]
# Time: 648.024s / 12000s | Acc: 23.97%
# Probability Policy: [Max: 64.34% - (Device 10) | Min: 0.75% | Std: 11.34% | Sum: 100.00% ]
# Selected Devices: [10, 25, 20]
# Time: 656.976s / 12000s | Acc: 24.38%
# Probability Policy: [Max: 64.32% - (Device 10) | Min: 0.75% | Std: 11.33% | Sum: 100.00% ]
# Selected Devices: [10, 25, 27]
# Time: 665.764s / 12000s | Acc: 24.41%
# Probability Policy: [Max: 64.31% - (Device 10) | Min: 0.75% | Std: 11.33% | Sum: 100.00% ]
# Selected Devices: [10, 13, 3]
# Time: 674.168s / 12000s | Acc: 23.94%
# Probability Policy: [Max: 64.27% - (Device 10) | Min: 0.75% | Std: 11.32% | Sum: 100.00% ]
# Selected Devices: [10, 1, 15]
# Time: 682.297s / 12000s | Acc: 23.96%
# Probability Policy: [Max: 64.25% - (Device 10) | Min: 0.75% | Std: 11.32% | Sum: 100.00% ]
# Selected Devices: [10, 8, 19]
# Time: 690.377s / 12000s | Acc: 23.91%
# Probability Policy: [Max: 64.29% - (Device 10) | Min: 0.75% | Std: 11.33% | Sum: 100.00% ]
# Selected Devices: [3, 5, 16]
# Time: 699.887s / 12000s | Acc: 24.22%
# Probability Policy: [Max: 64.18% - (Device 10) | Min: 0.76% | Std: 11.31% | Sum: 100.00% ]
# Selected Devices: [10, 4, 17]
# Time: 708.971s / 12000s | Acc: 24.27%
# Probability Policy: [Max: 64.23% - (Device 10) | Min: 0.76% | Std: 11.32% | Sum: 100.00% ]
# Selected Devices: [12, 10, 20]
# Time: 717.988s / 12000s | Acc: 25.89%
# Probability Policy: [Max: 64.28% - (Device 10) | Min: 0.74% | Std: 11.33% | Sum: 100.00% ]
# Selected Devices: [6, 5, 10]
# Time: 724.400s / 12000s | Acc: 26.68%
# Probability Policy: [Max: 64.32% - (Device 10) | Min: 0.73% | Std: 11.33% | Sum: 100.00% ]
# Selected Devices: [10, 20, 23]
# Time: 732.659s / 12000s | Acc: 26.80%
# Probability Policy: [Max: 64.36% - (Device 10) | Min: 0.74% | Std: 11.34% | Sum: 100.00% ]
# Selected Devices: [29, 10, 9]
# Time: 739.998s / 12000s | Acc: 27.17%
# Probability Policy: [Max: 64.39% - (Device 10) | Min: 0.73% | Std: 11.35% | Sum: 100.00% ]
# Selected Devices: [14, 10, 15]
# Time: 746.978s / 12000s | Acc: 27.04%
# Probability Policy: [Max: 64.43% - (Device 10) | Min: 0.74% | Std: 11.35% | Sum: 100.00% ]
# Selected Devices: [6, 2, 27]
# Time: 756.201s / 12000s | Acc: 27.13%
# Probability Policy: [Max: 64.49% - (Device 10) | Min: 0.73% | Std: 11.36% | Sum: 100.00% ]
# Selected Devices: [17, 10, 13]
# Time: 763.963s / 12000s | Acc: 27.60%
# Probability Policy: [Max: 64.53% - (Device 10) | Min: 0.73% | Std: 11.37% | Sum: 100.00% ]
# Selected Devices: [10, 5, 8]
# Time: 771.673s / 12000s | Acc: 27.64%
# Probability Policy: [Max: 64.55% - (Device 10) | Min: 0.73% | Std: 11.38% | Sum: 100.00% ]
# Selected Devices: [10, 22, 20]
# Time: 779.771s / 12000s | Acc: 27.69%
# Probability Policy: [Max: 64.56% - (Device 10) | Min: 0.73% | Std: 11.38% | Sum: 100.00% ]
# Selected Devices: [10, 29, 21]
# Time: 786.056s / 12000s | Acc: 27.84%
# Probability Policy: [Max: 64.56% - (Device 10) | Min: 0.73% | Std: 11.38% | Sum: 100.00% ]
# Selected Devices: [10, 19, 13]
# Time: 793.387s / 12000s | Acc: 27.96%
# Probability Policy: [Max: 64.59% - (Device 10) | Min: 0.73% | Std: 11.38% | Sum: 100.00% ]
# Selected Devices: [10, 12, 23]
# Time: 801.960s / 12000s | Acc: 28.32%
# Probability Policy: [Max: 64.63% - (Device 10) | Min: 0.73% | Std: 11.39% | Sum: 100.00% ]
# Selected Devices: [1, 10, 2]
# Time: 811.304s / 12000s | Acc: 28.26%
# Probability Policy: [Max: 64.54% - (Device 10) | Min: 0.73% | Std: 11.37% | Sum: 100.00% ]
# Selected Devices: [4, 19, 10]
# Time: 819.918s / 12000s | Acc: 27.73%
# Probability Policy: [Max: 64.60% - (Device 10) | Min: 0.73% | Std: 11.39% | Sum: 100.00% ]
# Selected Devices: [10, 3, 16]
# Time: 828.558s / 12000s | Acc: 27.59%
# Probability Policy: [Max: 64.58% - (Device 10) | Min: 0.74% | Std: 11.38% | Sum: 100.00% ]
# Selected Devices: [10, 5, 15]
# Time: 835.459s / 12000s | Acc: 27.68%
# Probability Policy: [Max: 64.59% - (Device 10) | Min: 0.74% | Std: 11.38% | Sum: 100.00% ]
# Selected Devices: [10, 20, 21]
# Time: 843.128s / 12000s | Acc: 27.93%
# Probability Policy: [Max: 64.60% - (Device 10) | Min: 0.74% | Std: 11.38% | Sum: 100.00% ]
# Selected Devices: [4, 10, 20]
# Time: 852.359s / 12000s | Acc: 27.65%
# Probability Policy: [Max: 64.60% - (Device 10) | Min: 0.74% | Std: 11.38% | Sum: 100.00% ]
# Selected Devices: [10, 27, 20]
# Time: 860.892s / 12000s | Acc: 27.94%
# Probability Policy: [Max: 64.60% - (Device 10) | Min: 0.74% | Std: 11.38% | Sum: 100.00% ]
# Selected Devices: [10, 2, 21]
# Time: 868.849s / 12000s | Acc: 27.75%
# Probability Policy: [Max: 64.59% - (Device 10) | Min: 0.74% | Std: 11.38% | Sum: 100.00% ]
# Selected Devices: [3, 10, 29]
# Time: 876.538s / 12000s | Acc: 27.25%
# Probability Policy: [Max: 64.48% - (Device 10) | Min: 0.75% | Std: 11.36% | Sum: 100.00% ]
# Selected Devices: [10, 13, 21]
# Time: 883.464s / 12000s | Acc: 27.39%
# Probability Policy: [Max: 64.50% - (Device 10) | Min: 0.75% | Std: 11.37% | Sum: 100.00% ]
# Selected Devices: [10, 17, 29]
# Time: 890.543s / 12000s | Acc: 27.68%
# Probability Policy: [Max: 64.52% - (Device 10) | Min: 0.75% | Std: 11.37% | Sum: 100.00% ]
# Selected Devices: [10, 29, 26]
# Time: 897.001s / 12000s | Acc: 27.75%
# Probability Policy: [Max: 64.52% - (Device 10) | Min: 0.75% | Std: 11.37% | Sum: 100.00% ]
# Selected Devices: [10, 2, 4]
# Time: 906.550s / 12000s | Acc: 27.90%
# Probability Policy: [Max: 64.51% - (Device 10) | Min: 0.75% | Std: 11.37% | Sum: 100.00% ]
# Selected Devices: [2, 8, 10]
# Time: 915.535s / 12000s | Acc: 27.40%
# Probability Policy: [Max: 64.46% - (Device 10) | Min: 0.74% | Std: 11.36% | Sum: 100.00% ]
# Selected Devices: [6, 10, 27]
# Time: 922.678s / 12000s | Acc: 27.40%
# Probability Policy: [Max: 64.47% - (Device 10) | Min: 0.74% | Std: 11.36% | Sum: 100.00% ]
# Selected Devices: [2, 15, 10]
# Time: 930.783s / 12000s | Acc: 26.37%
# Probability Policy: [Max: 64.37% - (Device 10) | Min: 0.74% | Std: 11.34% | Sum: 100.00% ]
# Selected Devices: [10, 22, 19]
# Time: 938.307s / 12000s | Acc: 26.72%
# Probability Policy: [Max: 64.42% - (Device 10) | Min: 0.74% | Std: 11.35% | Sum: 100.00% ]
# Selected Devices: [21, 10, 25]
# Time: 946.216s / 12000s | Acc: 27.23%
# Probability Policy: [Max: 64.41% - (Device 10) | Min: 0.74% | Std: 11.35% | Sum: 100.00% ]
# Selected Devices: [10, 6, 24]
# Time: 953.266s / 12000s | Acc: 27.44%
# Probability Policy: [Max: 64.45% - (Device 10) | Min: 0.75% | Std: 11.36% | Sum: 100.00% ]
# Selected Devices: [15, 29, 10]
# Time: 959.681s / 12000s | Acc: 27.87%
# Probability Policy: [Max: 64.47% - (Device 10) | Min: 0.74% | Std: 11.36% | Sum: 100.00% ]
# Selected Devices: [10, 24, 11]
# Time: 968.611s / 12000s | Acc: 27.68%
# Probability Policy: [Max: 64.45% - (Device 10) | Min: 0.74% | Std: 11.36% | Sum: 100.00% ]
# Selected Devices: [25, 19, 10]
# Time: 976.955s / 12000s | Acc: 27.66%
# Probability Policy: [Max: 64.43% - (Device 10) | Min: 0.75% | Std: 11.35% | Sum: 100.00% ]
# Selected Devices: [10, 23, 3]
# Time: 985.732s / 12000s | Acc: 27.74%
# Probability Policy: [Max: 64.42% - (Device 10) | Min: 0.76% | Std: 11.35% | Sum: 100.00% ]
# Selected Devices: [22, 10, 26]
# Time: 993.031s / 12000s | Acc: 28.83%
# Probability Policy: [Max: 64.50% - (Device 10) | Min: 0.75% | Std: 11.37% | Sum: 100.00% ]
# Selected Devices: [10, 27, 13]
# Time: 1000.776s / 12000s | Acc: 28.94%
# Probability Policy: [Max: 64.51% - (Device 10) | Min: 0.75% | Std: 11.37% | Sum: 100.00% ]
# Selected Devices: [1, 23, 8]
# Time: 1011.285s / 12000s | Acc: 29.35%
# Probability Policy: [Max: 64.49% - (Device 10) | Min: 0.76% | Std: 11.36% | Sum: 100.00% ]
# Selected Devices: [10, 29, 27]
# Time: 1018.347s / 12000s | Acc: 29.59%
# Probability Policy: [Max: 64.49% - (Device 10) | Min: 0.76% | Std: 11.36% | Sum: 100.00% ]
# Selected Devices: [10, 20, 14]
# Time: 1026.156s / 12000s | Acc: 29.77%
# Probability Policy: [Max: 64.52% - (Device 10) | Min: 0.76% | Std: 11.37% | Sum: 100.00% ]
# Selected Devices: [10, 11, 21]
# Time: 1034.299s / 12000s | Acc: 29.45%
# Probability Policy: [Max: 64.47% - (Device 10) | Min: 0.76% | Std: 11.36% | Sum: 100.00% ]
# Selected Devices: [10, 24, 25]
# Time: 1042.983s / 12000s | Acc: 29.27%
# Probability Policy: [Max: 64.46% - (Device 10) | Min: 0.77% | Std: 11.36% | Sum: 100.00% ]
# Selected Devices: [7, 10, 2]
# Time: 1052.362s / 12000s | Acc: 29.40%
# Probability Policy: [Max: 64.54% - (Device 10) | Min: 0.75% | Std: 11.37% | Sum: 100.00% ]
# Selected Devices: [10, 14, 27]
# Time: 1060.019s / 12000s | Acc: 29.42%
# Probability Policy: [Max: 64.55% - (Device 10) | Min: 0.74% | Std: 11.38% | Sum: 100.00% ]
# Selected Devices: [10, 4, 5]
# Time: 1068.250s / 12000s | Acc: 29.35%
# Probability Policy: [Max: 64.56% - (Device 10) | Min: 0.75% | Std: 11.38% | Sum: 100.00% ]
# Selected Devices: [11, 10, 3]
# Time: 1078.000s / 12000s | Acc: 28.32%
# Probability Policy: [Max: 64.35% - (Device 10) | Min: 0.76% | Std: 11.34% | Sum: 100.00% ]
# Selected Devices: [7, 10, 3]
# Time: 1087.608s / 12000s | Acc: 28.14%
# Probability Policy: [Max: 64.40% - (Device 10) | Min: 0.75% | Std: 11.35% | Sum: 100.00% ]
# Selected Devices: [16, 10, 3]
# Time: 1096.248s / 12000s | Acc: 28.13%
# Probability Policy: [Max: 64.44% - (Device 10) | Min: 0.76% | Std: 11.36% | Sum: 100.00% ]
# Selected Devices: [7, 29, 10]
# Time: 1103.789s / 12000s | Acc: 29.06%
# Probability Policy: [Max: 64.54% - (Device 10) | Min: 0.74% | Std: 11.37% | Sum: 100.00% ]
# Selected Devices: [10, 25, 29]
# Time: 1111.228s / 12000s | Acc: 28.81%
# Probability Policy: [Max: 64.51% - (Device 10) | Min: 0.74% | Std: 11.37% | Sum: 100.00% ]
# Selected Devices: [29, 10, 12]
# Time: 1118.728s / 12000s | Acc: 29.80%
# Probability Policy: [Max: 64.55% - (Device 10) | Min: 0.74% | Std: 11.38% | Sum: 100.00% ]
# Selected Devices: [6, 13, 10]
# Time: 1125.294s / 12000s | Acc: 30.54%
# Probability Policy: [Max: 64.67% - (Device 10) | Min: 0.74% | Std: 11.40% | Sum: 100.00% ]
# Selected Devices: [10, 28, 4]
# Time: 1134.493s / 12000s | Acc: 30.44%
# Probability Policy: [Max: 64.69% - (Device 10) | Min: 0.74% | Std: 11.40% | Sum: 100.00% ]
# Selected Devices: [10, 0, 15]
# Time: 1142.728s / 12000s | Acc: 30.93%
# Probability Policy: [Max: 64.71% - (Device 10) | Min: 0.75% | Std: 11.40% | Sum: 100.00% ]
# Selected Devices: [5, 10, 4]
# Time: 1150.958s / 12000s | Acc: 31.50%
# Probability Policy: [Max: 64.73% - (Device 10) | Min: 0.74% | Std: 11.41% | Sum: 100.00% ]
# Selected Devices: [10, 23, 18]
# Time: 1158.918s / 12000s | Acc: 31.16%
# Probability Policy: [Max: 64.76% - (Device 10) | Min: 0.74% | Std: 11.42% | Sum: 100.00% ]
# Selected Devices: [27, 10, 8]
# Time: 1167.435s / 12000s | Acc: 31.84%
# Probability Policy: [Max: 64.78% - (Device 10) | Min: 0.74% | Std: 11.42% | Sum: 100.00% ]
# Selected Devices: [20, 10, 29]
# Time: 1174.642s / 12000s | Acc: 32.55%
# Probability Policy: [Max: 64.81% - (Device 10) | Min: 0.75% | Std: 11.42% | Sum: 100.00% ]
# Selected Devices: [1, 28, 5]
# Time: 1184.528s / 12000s | Acc: 33.73%
# Probability Policy: [Max: 64.82% - (Device 10) | Min: 0.75% | Std: 11.43% | Sum: 100.00% ]
# Selected Devices: [22, 10, 29]
# Time: 1191.198s / 12000s | Acc: 34.64%
# Probability Policy: [Max: 64.88% - (Device 10) | Min: 0.74% | Std: 11.44% | Sum: 100.00% ]
# Selected Devices: [6, 10, 29]
# Time: 1197.143s / 12000s | Acc: 34.66%
# Probability Policy: [Max: 64.90% - (Device 10) | Min: 0.74% | Std: 11.44% | Sum: 100.00% ]
# Selected Devices: [10, 20, 22]
# Time: 1205.241s / 12000s | Acc: 35.09%
# Probability Policy: [Max: 64.92% - (Device 10) | Min: 0.74% | Std: 11.44% | Sum: 100.00% ]
# Selected Devices: [10, 20, 18]
# Time: 1213.628s / 12000s | Acc: 35.07%
# Probability Policy: [Max: 64.93% - (Device 10) | Min: 0.74% | Std: 11.45% | Sum: 100.00% ]
# Selected Devices: [22, 4, 10]
# Time: 1222.244s / 12000s | Acc: 34.98%
# Probability Policy: [Max: 64.95% - (Device 10) | Min: 0.73% | Std: 11.45% | Sum: 100.00% ]
# Selected Devices: [27, 21, 10]
# Time: 1229.763s / 12000s | Acc: 35.87%
# Probability Policy: [Max: 64.93% - (Device 10) | Min: 0.73% | Std: 11.44% | Sum: 100.00% ]
# Selected Devices: [10, 8, 6]
# Time: 1237.035s / 12000s | Acc: 36.06%
# Probability Policy: [Max: 64.94% - (Device 10) | Min: 0.73% | Std: 11.45% | Sum: 100.00% ]
# Selected Devices: [10, 12, 19]
# Time: 1245.443s / 12000s | Acc: 36.10%
# Probability Policy: [Max: 64.96% - (Device 10) | Min: 0.73% | Std: 11.45% | Sum: 100.00% ]
# Selected Devices: [6, 29, 27]
# Time: 1252.846s / 12000s | Acc: 36.25%
# Probability Policy: [Max: 64.94% - (Device 10) | Min: 0.73% | Std: 11.45% | Sum: 100.00% ]
# Selected Devices: [10, 17, 9]
# Time: 1261.542s / 12000s | Acc: 36.46%
# Probability Policy: [Max: 64.99% - (Device 10) | Min: 0.74% | Std: 11.46% | Sum: 100.00% ]
# Selected Devices: [15, 10, 5]
# Time: 1268.444s / 12000s | Acc: 36.42%
# Probability Policy: [Max: 64.99% - (Device 10) | Min: 0.73% | Std: 11.46% | Sum: 100.00% ]
# Selected Devices: [23, 15, 27]
# Time: 1277.483s / 12000s | Acc: 36.03%
# Probability Policy: [Max: 64.94% - (Device 10) | Min: 0.74% | Std: 11.45% | Sum: 100.00% ]
# Selected Devices: [10, 19, 13]
# Time: 1284.813s / 12000s | Acc: 36.31%
# Probability Policy: [Max: 64.97% - (Device 10) | Min: 0.75% | Std: 11.45% | Sum: 100.00% ]
# Selected Devices: [25, 19, 4]
# Time: 1295.659s / 12000s | Acc: 35.07%
# Probability Policy: [Max: 64.93% - (Device 10) | Min: 0.76% | Std: 11.45% | Sum: 100.00% ]
# Selected Devices: [3, 10, 25]
# Time: 1305.151s / 12000s | Acc: 34.80%
# Probability Policy: [Max: 64.85% - (Device 10) | Min: 0.77% | Std: 11.43% | Sum: 100.00% ]
# Selected Devices: [29, 10, 18]
# Time: 1312.081s / 12000s | Acc: 35.16%
# Probability Policy: [Max: 64.87% - (Device 10) | Min: 0.76% | Std: 11.43% | Sum: 100.00% ]
# Selected Devices: [10, 29, 24]
# Time: 1319.051s / 12000s | Acc: 35.39%
# Probability Policy: [Max: 64.91% - (Device 10) | Min: 0.76% | Std: 11.44% | Sum: 100.00% ]
# Selected Devices: [17, 10, 13]
# Time: 1326.814s / 12000s | Acc: 35.39%
# Probability Policy: [Max: 64.97% - (Device 10) | Min: 0.74% | Std: 11.45% | Sum: 100.00% ]
# Selected Devices: [10, 2, 27]
# Time: 1335.653s / 12000s | Acc: 35.36%
# Probability Policy: [Max: 64.93% - (Device 10) | Min: 0.74% | Std: 11.45% | Sum: 100.00% ]
# Selected Devices: [15, 29, 28]
# Time: 1343.709s / 12000s | Acc: 37.19%
# Probability Policy: [Max: 65.03% - (Device 10) | Min: 0.74% | Std: 11.46% | Sum: 100.00% ]
# Selected Devices: [10, 24, 29]
# Time: 1350.679s / 12000s | Acc: 37.31%
# Probability Policy: [Max: 65.06% - (Device 10) | Min: 0.74% | Std: 11.47% | Sum: 100.00% ]
# Selected Devices: [18, 10, 14]
# Time: 1358.198s / 12000s | Acc: 36.49%
# Probability Policy: [Max: 65.08% - (Device 10) | Min: 0.74% | Std: 11.47% | Sum: 100.00% ]
# Selected Devices: [10, 29, 18]
# Time: 1365.128s / 12000s | Acc: 36.27%
# Probability Policy: [Max: 65.08% - (Device 10) | Min: 0.74% | Std: 11.47% | Sum: 100.00% ]
# Selected Devices: [10, 21, 19]
# Time: 1372.240s / 12000s | Acc: 36.36%
# Probability Policy: [Max: 65.09% - (Device 10) | Min: 0.73% | Std: 11.47% | Sum: 100.00% ]
# Selected Devices: [10, 4, 21]
# Time: 1380.411s / 12000s | Acc: 36.52%
# Probability Policy: [Max: 65.08% - (Device 10) | Min: 0.74% | Std: 11.47% | Sum: 100.00% ]
# Selected Devices: [10, 24, 16]
# Time: 1388.283s / 12000s | Acc: 36.58%
# Probability Policy: [Max: 65.11% - (Device 10) | Min: 0.74% | Std: 11.48% | Sum: 100.00% ]
# Selected Devices: [18, 10, 17]
# Time: 1396.531s / 12000s | Acc: 35.85%
# Probability Policy: [Max: 65.09% - (Device 10) | Min: 0.73% | Std: 11.48% | Sum: 100.00% ]
# Selected Devices: [21, 10, 4]
# Time: 1404.702s / 12000s | Acc: 36.08%
# Probability Policy: [Max: 65.09% - (Device 10) | Min: 0.74% | Std: 11.47% | Sum: 100.00% ]
# Selected Devices: [3, 10, 20]
# Time: 1413.928s / 12000s | Acc: 35.83%
# Probability Policy: [Max: 65.02% - (Device 10) | Min: 0.75% | Std: 11.46% | Sum: 100.00% ]
# Selected Devices: [10, 6, 4]
# Time: 1421.705s / 12000s | Acc: 35.39%
# Probability Policy: [Max: 64.99% - (Device 10) | Min: 0.75% | Std: 11.46% | Sum: 100.00% ]
# Selected Devices: [1, 10, 19]
# Time: 1430.124s / 12000s | Acc: 34.80%
# Probability Policy: [Max: 64.92% - (Device 10) | Min: 0.74% | Std: 11.44% | Sum: 100.00% ]
# Selected Devices: [10, 14, 28]
# Time: 1437.903s / 12000s | Acc: 35.27%
# Probability Policy: [Max: 64.96% - (Device 10) | Min: 0.74% | Std: 11.45% | Sum: 100.00% ]
# Selected Devices: [10, 16, 24]
# Time: 1445.776s / 12000s | Acc: 35.47%
# Probability Policy: [Max: 65.01% - (Device 10) | Min: 0.74% | Std: 11.46% | Sum: 100.00% ]
# Selected Devices: [10, 20, 27]
# Time: 1454.310s / 12000s | Acc: 35.80%
# Probability Policy: [Max: 65.00% - (Device 10) | Min: 0.74% | Std: 11.46% | Sum: 100.00% ]
# Selected Devices: [27, 10, 29]
# Time: 1461.372s / 12000s | Acc: 36.16%
# Probability Policy: [Max: 64.97% - (Device 10) | Min: 0.73% | Std: 11.45% | Sum: 100.00% ]
# Selected Devices: [10, 7, 15]
# Time: 1469.534s / 12000s | Acc: 36.18%
# Probability Policy: [Max: 65.00% - (Device 10) | Min: 0.73% | Std: 11.46% | Sum: 100.00% ]
# Selected Devices: [29, 10, 9]
# Time: 1476.874s / 12000s | Acc: 36.99%
# Probability Policy: [Max: 65.06% - (Device 10) | Min: 0.72% | Std: 11.47% | Sum: 100.00% ]
# Selected Devices: [10, 7, 3]
# Time: 1486.482s / 12000s | Acc: 36.57%
# Probability Policy: [Max: 65.05% - (Device 10) | Min: 0.72% | Std: 11.47% | Sum: 100.00% ]
# Selected Devices: [10, 4, 5]
# Time: 1494.712s / 12000s | Acc: 36.84%
# Probability Policy: [Max: 65.06% - (Device 10) | Min: 0.72% | Std: 11.47% | Sum: 100.00% ]
# Selected Devices: [10, 20, 6]
# Time: 1502.000s / 12000s | Acc: 36.80%
# Probability Policy: [Max: 65.04% - (Device 10) | Min: 0.72% | Std: 11.47% | Sum: 100.00% ]
# Selected Devices: [10, 27, 14]
# Time: 1509.658s / 12000s | Acc: 36.76%
# Probability Policy: [Max: 65.04% - (Device 10) | Min: 0.72% | Std: 11.47% | Sum: 100.00% ]
# Selected Devices: [10, 5, 6]
# Time: 1516.069s / 12000s | Acc: 37.04%
# Probability Policy: [Max: 65.05% - (Device 10) | Min: 0.72% | Std: 11.47% | Sum: 100.00% ]
# Selected Devices: [4, 10, 9]
# Time: 1525.451s / 12000s | Acc: 36.43%
# Probability Policy: [Max: 65.05% - (Device 10) | Min: 0.73% | Std: 11.47% | Sum: 100.00% ]
# Selected Devices: [10, 3, 5]
# Time: 1533.678s / 12000s | Acc: 36.62%
# Probability Policy: [Max: 65.04% - (Device 10) | Min: 0.73% | Std: 11.47% | Sum: 100.00% ]
# Selected Devices: [10, 6, 13]
# Time: 1540.244s / 12000s | Acc: 36.73%
# Probability Policy: [Max: 65.05% - (Device 10) | Min: 0.73% | Std: 11.47% | Sum: 100.00% ]
# Selected Devices: [10, 22, 1]
# Time: 1548.665s / 12000s | Acc: 36.95%
# Probability Policy: [Max: 65.06% - (Device 10) | Min: 0.73% | Std: 11.47% | Sum: 100.00% ]
# Selected Devices: [14, 10, 3]
# Time: 1556.977s / 12000s | Acc: 36.97%
# Probability Policy: [Max: 65.08% - (Device 10) | Min: 0.72% | Std: 11.47% | Sum: 100.00% ]
# Selected Devices: [20, 24, 5]
# Time: 1566.267s / 12000s | Acc: 37.19%
# Probability Policy: [Max: 65.12% - (Device 10) | Min: 0.71% | Std: 11.48% | Sum: 100.00% ]
# Selected Devices: [10, 25, 23]
# Time: 1574.776s / 12000s | Acc: 37.34%
# Probability Policy: [Max: 65.11% - (Device 10) | Min: 0.71% | Std: 11.48% | Sum: 100.00% ]
# Selected Devices: [10, 6, 13]
# Time: 1581.343s / 12000s | Acc: 37.44%
# Probability Policy: [Max: 65.12% - (Device 10) | Min: 0.71% | Std: 11.48% | Sum: 100.00% ]
# Selected Devices: [10, 20, 12]
# Time: 1590.360s / 12000s | Acc: 37.73%
# Probability Policy: [Max: 65.14% - (Device 10) | Min: 0.71% | Std: 11.48% | Sum: 100.00% ]
# Selected Devices: [10, 23, 1]
# Time: 1598.945s / 12000s | Acc: 37.88%
# Probability Policy: [Max: 65.13% - (Device 10) | Min: 0.71% | Std: 11.48% | Sum: 100.00% ]
# Selected Devices: [10, 22, 28]
# Time: 1607.014s / 12000s | Acc: 38.36%
# Probability Policy: [Max: 65.17% - (Device 10) | Min: 0.72% | Std: 11.49% | Sum: 100.00% ]
# Selected Devices: [10, 17, 3]
# Time: 1616.093s / 12000s | Acc: 38.26%
# Probability Policy: [Max: 65.15% - (Device 10) | Min: 0.71% | Std: 11.49% | Sum: 100.00% ]
# Selected Devices: [10, 17, 6]
# Time: 1623.252s / 12000s | Acc: 37.87%
# Probability Policy: [Max: 65.15% - (Device 10) | Min: 0.70% | Std: 11.49% | Sum: 100.00% ]
# Selected Devices: [10, 13, 0]
# Time: 1631.573s / 12000s | Acc: 38.30%
# Probability Policy: [Max: 65.19% - (Device 10) | Min: 0.71% | Std: 11.49% | Sum: 100.00% ]
# Selected Devices: [10, 6, 12]
# Time: 1639.155s / 12000s | Acc: 38.51%
# Probability Policy: [Max: 65.21% - (Device 10) | Min: 0.71% | Std: 11.50% | Sum: 100.00% ]
# Selected Devices: [10, 27, 18]
# Time: 1647.385s / 12000s | Acc: 38.32%
# Probability Policy: [Max: 65.19% - (Device 10) | Min: 0.71% | Std: 11.49% | Sum: 100.00% ]
# Selected Devices: [10, 24, 15]
# Time: 1654.951s / 12000s | Acc: 38.13%
# Probability Policy: [Max: 65.20% - (Device 10) | Min: 0.71% | Std: 11.50% | Sum: 100.00% ]
# Selected Devices: [7, 10, 19]
# Time: 1663.403s / 12000s | Acc: 37.70%
# Probability Policy: [Max: 65.23% - (Device 10) | Min: 0.69% | Std: 11.50% | Sum: 100.00% ]
# Selected Devices: [10, 14, 4]
# Time: 1671.718s / 12000s | Acc: 37.48%
# Probability Policy: [Max: 65.23% - (Device 10) | Min: 0.69% | Std: 11.50% | Sum: 100.00% ]
# Selected Devices: [10, 12, 21]
# Time: 1679.689s / 12000s | Acc: 38.35%
# Probability Policy: [Max: 65.26% - (Device 10) | Min: 0.69% | Std: 11.51% | Sum: 100.00% ]
# Selected Devices: [10, 12, 29]
# Time: 1687.189s / 12000s | Acc: 39.01%
# Probability Policy: [Max: 65.30% - (Device 10) | Min: 0.70% | Std: 11.51% | Sum: 100.00% ]
# Selected Devices: [10, 6, 3]
# Time: 1694.962s / 12000s | Acc: 38.98%
# Probability Policy: [Max: 65.28% - (Device 10) | Min: 0.70% | Std: 11.51% | Sum: 100.00% ]
# Selected Devices: [10, 7, 5]
# Time: 1703.034s / 12000s | Acc: 38.83%
# Probability Policy: [Max: 65.29% - (Device 10) | Min: 0.69% | Std: 11.51% | Sum: 100.00% ]
# Selected Devices: [10, 8, 5]
# Time: 1710.744s / 12000s | Acc: 39.47%
# Probability Policy: [Max: 65.33% - (Device 10) | Min: 0.70% | Std: 11.52% | Sum: 100.00% ]
# Selected Devices: [22, 6, 10]
# Time: 1717.493s / 12000s | Acc: 39.76%
# Probability Policy: [Max: 65.36% - (Device 10) | Min: 0.70% | Std: 11.52% | Sum: 100.00% ]
# Selected Devices: [10, 29, 3]
# Time: 1725.182s / 12000s | Acc: 39.95%
# Probability Policy: [Max: 65.35% - (Device 10) | Min: 0.71% | Std: 11.52% | Sum: 100.00% ]
# Selected Devices: [10, 29, 25]
# Time: 1732.621s / 12000s | Acc: 39.94%
# Probability Policy: [Max: 65.34% - (Device 10) | Min: 0.71% | Std: 11.52% | Sum: 100.00% ]
# Selected Devices: [15, 10, 5]
# Time: 1739.523s / 12000s | Acc: 40.54%
# Probability Policy: [Max: 65.35% - (Device 10) | Min: 0.71% | Std: 11.52% | Sum: 100.00% ]
# Selected Devices: [10, 29, 16]
# Time: 1746.219s / 12000s | Acc: 40.69%
# Probability Policy: [Max: 65.36% - (Device 10) | Min: 0.71% | Std: 11.52% | Sum: 100.00% ]
# Selected Devices: [10, 8, 24]
# Time: 1754.633s / 12000s | Acc: 41.12%
# Probability Policy: [Max: 65.38% - (Device 10) | Min: 0.71% | Std: 11.53% | Sum: 100.00% ]
# Selected Devices: [10, 9, 14]
# Time: 1762.580s / 12000s | Acc: 41.36%
# Probability Policy: [Max: 65.41% - (Device 10) | Min: 0.70% | Std: 11.53% | Sum: 100.00% ]
# Selected Devices: [10, 7, 3]
# Time: 1772.188s / 12000s | Acc: 41.16%
# Probability Policy: [Max: 65.39% - (Device 10) | Min: 0.70% | Std: 11.53% | Sum: 100.00% ]
# Selected Devices: [10, 8, 19]
# Time: 1780.268s / 12000s | Acc: 41.28%
# Probability Policy: [Max: 65.40% - (Device 10) | Min: 0.70% | Std: 11.53% | Sum: 100.00% ]
# Selected Devices: [10, 15, 18]
# Time: 1787.791s / 12000s | Acc: 41.06%
# Probability Policy: [Max: 65.40% - (Device 10) | Min: 0.70% | Std: 11.53% | Sum: 100.00% ]
# Selected Devices: [5, 10, 4]
# Time: 1796.021s / 12000s | Acc: 41.25%
# Probability Policy: [Max: 65.41% - (Device 10) | Min: 0.70% | Std: 11.53% | Sum: 100.00% ]
# Selected Devices: [6, 29, 10]
# Time: 1801.966s / 12000s | Acc: 40.89%
# Probability Policy: [Max: 65.41% - (Device 10) | Min: 0.71% | Std: 11.53% | Sum: 100.00% ]
# Selected Devices: [14, 10, 22]
# Time: 1809.214s / 12000s | Acc: 40.62%
# Probability Policy: [Max: 65.41% - (Device 10) | Min: 0.70% | Std: 11.53% | Sum: 100.00% ]
# Selected Devices: [10, 19, 14]
# Time: 1816.459s / 12000s | Acc: 40.14%
# Probability Policy: [Max: 65.39% - (Device 10) | Min: 0.69% | Std: 11.53% | Sum: 100.00% ]
# Selected Devices: [10, 11, 29]
# Time: 1824.125s / 12000s | Acc: 40.55%
# Probability Policy: [Max: 65.39% - (Device 10) | Min: 0.70% | Std: 11.53% | Sum: 100.00% ]
# Selected Devices: [16, 28, 10]
# Time: 1832.221s / 12000s | Acc: 41.93%
# Probability Policy: [Max: 65.47% - (Device 10) | Min: 0.71% | Std: 11.54% | Sum: 100.00% ]
# Selected Devices: [10, 29, 5]
# Time: 1838.557s / 12000s | Acc: 41.86%
# Probability Policy: [Max: 65.47% - (Device 10) | Min: 0.71% | Std: 11.55% | Sum: 100.00% ]
# Selected Devices: [6, 10, 19]
# Time: 1845.304s / 12000s | Acc: 41.39%
# Probability Policy: [Max: 65.45% - (Device 10) | Min: 0.71% | Std: 11.54% | Sum: 100.00% ]
# Selected Devices: [17, 10, 25]
# Time: 1854.111s / 12000s | Acc: 40.51%
# Probability Policy: [Max: 65.43% - (Device 10) | Min: 0.68% | Std: 11.54% | Sum: 100.00% ]
# Selected Devices: [10, 5, 6]
# Time: 1860.523s / 12000s | Acc: 40.64%
# Probability Policy: [Max: 65.43% - (Device 10) | Min: 0.68% | Std: 11.54% | Sum: 100.00% ]
# Selected Devices: [15, 10, 17]
# Time: 1868.202s / 12000s | Acc: 40.79%
# Probability Policy: [Max: 65.42% - (Device 10) | Min: 0.68% | Std: 11.54% | Sum: 100.00% ]
# Selected Devices: [10, 27, 12]
# Time: 1877.056s / 12000s | Acc: 41.47%
# Probability Policy: [Max: 65.44% - (Device 10) | Min: 0.68% | Std: 11.54% | Sum: 100.00% ]
# Selected Devices: [15, 10, 12]
# Time: 1885.174s / 12000s | Acc: 41.79%
# Probability Policy: [Max: 65.43% - (Device 10) | Min: 0.69% | Std: 11.54% | Sum: 100.00% ]
# Selected Devices: [10, 9, 23]
# Time: 1893.576s / 12000s | Acc: 42.33%
# Probability Policy: [Max: 65.47% - (Device 10) | Min: 0.69% | Std: 11.55% | Sum: 100.00% ]
# Selected Devices: [10, 6, 28]
# Time: 1900.836s / 12000s | Acc: 42.72%
# Probability Policy: [Max: 65.49% - (Device 10) | Min: 0.69% | Std: 11.55% | Sum: 100.00% ]
# Selected Devices: [10, 17, 28]
# Time: 1909.357s / 12000s | Acc: 42.82%
# Probability Policy: [Max: 65.50% - (Device 10) | Min: 0.68% | Std: 11.55% | Sum: 100.00% ]
# Selected Devices: [10, 4, 29]
# Time: 1917.049s / 12000s | Acc: 42.89%
# Probability Policy: [Max: 65.50% - (Device 10) | Min: 0.69% | Std: 11.55% | Sum: 100.00% ]
# Selected Devices: [10, 11, 4]
# Time: 1926.804s / 12000s | Acc: 43.34%
# Probability Policy: [Max: 65.50% - (Device 10) | Min: 0.69% | Std: 11.55% | Sum: 100.00% ]
# Selected Devices: [13, 10, 18]
# Time: 1934.410s / 12000s | Acc: 43.72%
# Probability Policy: [Max: 65.53% - (Device 10) | Min: 0.70% | Std: 11.56% | Sum: 100.00% ]
# Selected Devices: [22, 12, 10]
# Time: 1942.820s / 12000s | Acc: 44.01%
# Probability Policy: [Max: 65.54% - (Device 10) | Min: 0.71% | Std: 11.56% | Sum: 100.00% ]
# Selected Devices: [10, 7, 23]
# Time: 1951.438s / 12000s | Acc: 44.05%
# Probability Policy: [Max: 65.55% - (Device 10) | Min: 0.72% | Std: 11.56% | Sum: 100.00% ]
# Selected Devices: [3, 10, 24]
# Time: 1960.393s / 12000s | Acc: 44.54%
# Probability Policy: [Max: 65.55% - (Device 10) | Min: 0.72% | Std: 11.56% | Sum: 100.00% ]
# Selected Devices: [21, 10, 26]
# Time: 1967.286s / 12000s | Acc: 45.49%
# Probability Policy: [Max: 65.58% - (Device 10) | Min: 0.72% | Std: 11.57% | Sum: 100.00% ]
# Selected Devices: [9, 18, 10]
# Time: 1975.816s / 12000s | Acc: 45.37%
# Probability Policy: [Max: 65.60% - (Device 10) | Min: 0.71% | Std: 11.57% | Sum: 100.00% ]
# Selected Devices: [10, 25, 5]
# Time: 1983.784s / 12000s | Acc: 45.48%
# Probability Policy: [Max: 65.60% - (Device 10) | Min: 0.71% | Std: 11.57% | Sum: 100.00% ]
# Selected Devices: [10, 22, 23]
# Time: 1991.464s / 12000s | Acc: 45.45%
# Probability Policy: [Max: 65.61% - (Device 10) | Min: 0.71% | Std: 11.57% | Sum: 100.00% ]
# Selected Devices: [10, 22, 16]
# Time: 1999.017s / 12000s | Acc: 45.32%
# Probability Policy: [Max: 65.61% - (Device 10) | Min: 0.72% | Std: 11.57% | Sum: 100.00% ]
# Selected Devices: [10, 11, 5]
# Time: 2007.219s / 12000s | Acc: 45.44%
# Probability Policy: [Max: 65.61% - (Device 10) | Min: 0.72% | Std: 11.57% | Sum: 100.00% ]
# Selected Devices: [23, 10, 13]
# Time: 2014.704s / 12000s | Acc: 45.90%
# Probability Policy: [Max: 65.62% - (Device 10) | Min: 0.73% | Std: 11.57% | Sum: 100.00% ]
# Selected Devices: [10, 29, 5]
# Time: 2021.040s / 12000s | Acc: 45.68%
# Probability Policy: [Max: 65.63% - (Device 10) | Min: 0.73% | Std: 11.57% | Sum: 100.00% ]
# Selected Devices: [10, 16, 20]
# Time: 2029.166s / 12000s | Acc: 45.63%
# Probability Policy: [Max: 65.64% - (Device 10) | Min: 0.73% | Std: 11.58% | Sum: 100.00% ]
# Selected Devices: [2, 20, 25]
# Time: 2040.450s / 12000s | Acc: 47.29%
# Probability Policy: [Max: 65.64% - (Device 10) | Min: 0.73% | Std: 11.58% | Sum: 100.00% ]
# Selected Devices: [10, 22, 28]
# Time: 2048.519s / 12000s | Acc: 47.31%
# Probability Policy: [Max: 65.66% - (Device 10) | Min: 0.73% | Std: 11.58% | Sum: 100.00% ]
# Selected Devices: [10, 5, 19]
# Time: 2055.685s / 12000s | Acc: 47.13%
# Probability Policy: [Max: 65.66% - (Device 10) | Min: 0.73% | Std: 11.58% | Sum: 100.00% ]
# Selected Devices: [10, 14, 23]
# Time: 2063.084s / 12000s | Acc: 47.38%
# Probability Policy: [Max: 65.67% - (Device 10) | Min: 0.73% | Std: 11.58% | Sum: 100.00% ]
# Selected Devices: [25, 23, 10]
# Time: 2071.594s / 12000s | Acc: 47.19%
# Probability Policy: [Max: 65.63% - (Device 10) | Min: 0.73% | Std: 11.57% | Sum: 100.00% ]
# Selected Devices: [10, 29, 24]
# Time: 2078.564s / 12000s | Acc: 47.14%
# Probability Policy: [Max: 65.64% - (Device 10) | Min: 0.73% | Std: 11.58% | Sum: 100.00% ]
# Selected Devices: [10, 28, 26]
# Time: 2086.396s / 12000s | Acc: 47.13%
# Probability Policy: [Max: 65.64% - (Device 10) | Min: 0.73% | Std: 11.58% | Sum: 100.00% ]
# Selected Devices: [10, 19, 13]
# Time: 2093.727s / 12000s | Acc: 47.17%
# Probability Policy: [Max: 65.65% - (Device 10) | Min: 0.72% | Std: 11.58% | Sum: 100.00% ]
# Selected Devices: [5, 10, 25]
# Time: 2101.694s / 12000s | Acc: 46.80%
# Probability Policy: [Max: 65.63% - (Device 10) | Min: 0.72% | Std: 11.57% | Sum: 100.00% ]
# Selected Devices: [0, 10, 14]
# Time: 2109.924s / 12000s | Acc: 46.79%
# Probability Policy: [Max: 65.66% - (Device 10) | Min: 0.73% | Std: 11.58% | Sum: 100.00% ]
# Selected Devices: [10, 28, 11]
# Time: 2119.092s / 12000s | Acc: 47.67%
# Probability Policy: [Max: 65.66% - (Device 10) | Min: 0.73% | Std: 11.58% | Sum: 100.00% ]
# Selected Devices: [10, 23, 14]
# Time: 2126.491s / 12000s | Acc: 47.38%
# Probability Policy: [Max: 65.67% - (Device 10) | Min: 0.73% | Std: 11.58% | Sum: 100.00% ]
# Selected Devices: [10, 14, 4]
# Time: 2134.807s / 12000s | Acc: 47.67%
# Probability Policy: [Max: 65.67% - (Device 10) | Min: 0.73% | Std: 11.58% | Sum: 100.00% ]
# Selected Devices: [10, 16, 13]
# Time: 2142.166s / 12000s | Acc: 47.47%
# Probability Policy: [Max: 65.68% - (Device 10) | Min: 0.73% | Std: 11.58% | Sum: 100.00% ]
# Selected Devices: [23, 10, 18]
# Time: 2150.126s / 12000s | Acc: 46.71%
# Probability Policy: [Max: 65.67% - (Device 10) | Min: 0.74% | Std: 11.58% | Sum: 100.00% ]
# Selected Devices: [10, 0, 21]
# Time: 2158.211s / 12000s | Acc: 47.01%
# Probability Policy: [Max: 65.67% - (Device 10) | Min: 0.74% | Std: 11.58% | Sum: 100.00% ]
# Selected Devices: [10, 29, 4]
# Time: 2165.904s / 12000s | Acc: 46.71%
# Probability Policy: [Max: 65.66% - (Device 10) | Min: 0.73% | Std: 11.58% | Sum: 100.00% ]
# Selected Devices: [10, 3, 29]
# Time: 2173.593s / 12000s | Acc: 46.98%
# Probability Policy: [Max: 65.64% - (Device 10) | Min: 0.73% | Std: 11.58% | Sum: 100.00% ]
# Selected Devices: [10, 19, 2]
# Time: 2181.987s / 12000s | Acc: 47.44%
# Probability Policy: [Max: 65.65% - (Device 10) | Min: 0.73% | Std: 11.58% | Sum: 100.00% ]
# Selected Devices: [10, 6, 28]
# Time: 2189.247s / 12000s | Acc: 47.33%
# Probability Policy: [Max: 65.66% - (Device 10) | Min: 0.74% | Std: 11.58% | Sum: 100.00% ]
# Selected Devices: [10, 6, 1]
# Time: 2196.840s / 12000s | Acc: 47.29%
# Probability Policy: [Max: 65.64% - (Device 10) | Min: 0.74% | Std: 11.58% | Sum: 100.00% ]
# Selected Devices: [10, 18, 2]
# Time: 2205.529s / 12000s | Acc: 47.33%
# Probability Policy: [Max: 65.64% - (Device 10) | Min: 0.74% | Std: 11.58% | Sum: 100.00% ]
# Selected Devices: [11, 10, 17]
# Time: 2214.583s / 12000s | Acc: 48.48%
# Probability Policy: [Max: 65.59% - (Device 10) | Min: 0.74% | Std: 11.57% | Sum: 100.00% ]
# Selected Devices: [10, 13, 18]
# Time: 2222.189s / 12000s | Acc: 48.16%
# Probability Policy: [Max: 65.60% - (Device 10) | Min: 0.74% | Std: 11.57% | Sum: 100.00% ]
# Selected Devices: [10, 6, 27]
# Time: 2229.332s / 12000s | Acc: 48.25%
# Probability Policy: [Max: 65.60% - (Device 10) | Min: 0.75% | Std: 11.57% | Sum: 100.00% ]
# Selected Devices: [26, 10, 7]
# Time: 2237.544s / 12000s | Acc: 48.64%
# Probability Policy: [Max: 65.62% - (Device 10) | Min: 0.74% | Std: 11.57% | Sum: 100.00% ]
# Selected Devices: [10, 14, 0]
# Time: 2245.773s / 12000s | Acc: 48.98%
# Probability Policy: [Max: 65.64% - (Device 10) | Min: 0.74% | Std: 11.58% | Sum: 100.00% ]
# Selected Devices: [10, 22, 20]
# Time: 2253.871s / 12000s | Acc: 49.14%
# Probability Policy: [Max: 65.66% - (Device 10) | Min: 0.74% | Std: 11.58% | Sum: 100.00% ]
# Selected Devices: [3, 10, 7]
# Time: 2263.479s / 12000s | Acc: 49.66%
# Probability Policy: [Max: 65.61% - (Device 10) | Min: 0.74% | Std: 11.57% | Sum: 100.00% ]
# Selected Devices: [10, 0, 4]
# Time: 2273.170s / 12000s | Acc: 49.66%
# Probability Policy: [Max: 65.60% - (Device 10) | Min: 0.74% | Std: 11.57% | Sum: 100.00% ]
# Selected Devices: [14, 10, 21]
# Time: 2280.014s / 12000s | Acc: 50.11%
# Probability Policy: [Max: 65.63% - (Device 10) | Min: 0.74% | Std: 11.57% | Sum: 100.00% ]
# Selected Devices: [10, 3, 8]
# Time: 2289.223s / 12000s | Acc: 50.14%
# Probability Policy: [Max: 65.60% - (Device 10) | Min: 0.74% | Std: 11.57% | Sum: 100.00% ]
# Selected Devices: [10, 27, 24]
# Time: 2297.496s / 12000s | Acc: 50.81%
# Probability Policy: [Max: 65.62% - (Device 10) | Min: 0.74% | Std: 11.57% | Sum: 100.00% ]
# Selected Devices: [10, 21, 6]
# Time: 2303.857s / 12000s | Acc: 50.59%
# Probability Policy: [Max: 65.61% - (Device 10) | Min: 0.74% | Std: 11.57% | Sum: 100.00% ]
# Selected Devices: [10, 27, 0]
# Time: 2312.832s / 12000s | Acc: 50.84%
# Probability Policy: [Max: 65.62% - (Device 10) | Min: 0.74% | Std: 11.57% | Sum: 100.00% ]
# Selected Devices: [7, 10, 1]
# Time: 2322.238s / 12000s | Acc: 50.85%
# Probability Policy: [Max: 65.64% - (Device 10) | Min: 0.72% | Std: 11.58% | Sum: 100.00% ]
# Selected Devices: [10, 19, 13]
# Time: 2329.568s / 12000s | Acc: 50.86%
# Probability Policy: [Max: 65.65% - (Device 10) | Min: 0.72% | Std: 11.58% | Sum: 100.00% ]
# Selected Devices: [21, 14, 10]
# Time: 2336.412s / 12000s | Acc: 50.99%
# Probability Policy: [Max: 65.64% - (Device 10) | Min: 0.72% | Std: 11.58% | Sum: 100.00% ]
# Selected Devices: [10, 13, 19]
# Time: 2343.743s / 12000s | Acc: 50.90%
# Probability Policy: [Max: 65.65% - (Device 10) | Min: 0.71% | Std: 11.58% | Sum: 100.00% ]
# Selected Devices: [10, 20, 13]
# Time: 2351.640s / 12000s | Acc: 51.41%
# Probability Policy: [Max: 65.67% - (Device 10) | Min: 0.71% | Std: 11.58% | Sum: 100.00% ]
# Selected Devices: [10, 14, 8]
# Time: 2359.432s / 12000s | Acc: 51.48%
# Probability Policy: [Max: 65.67% - (Device 10) | Min: 0.71% | Std: 11.58% | Sum: 100.00% ]
# Selected Devices: [26, 10, 4]
# Time: 2367.802s / 12000s | Acc: 51.67%
# Probability Policy: [Max: 65.67% - (Device 10) | Min: 0.71% | Std: 11.58% | Sum: 100.00% ]
# Selected Devices: [20, 10, 27]
# Time: 2376.336s / 12000s | Acc: 52.14%
# Probability Policy: [Max: 65.68% - (Device 10) | Min: 0.71% | Std: 11.58% | Sum: 100.00% ]
# Selected Devices: [14, 10, 0]
# Time: 2384.565s / 12000s | Acc: 52.50%
# Probability Policy: [Max: 65.71% - (Device 10) | Min: 0.70% | Std: 11.59% | Sum: 100.00% ]
# Selected Devices: [10, 17, 21]
# Time: 2392.101s / 12000s | Acc: 52.40%
# Probability Policy: [Max: 65.70% - (Device 10) | Min: 0.69% | Std: 11.59% | Sum: 100.00% ]
# Selected Devices: [10, 5, 26]
# Time: 2399.048s / 12000s | Acc: 52.33%
# Probability Policy: [Max: 65.71% - (Device 10) | Min: 0.69% | Std: 11.59% | Sum: 100.00% ]
# Selected Devices: [29, 10, 5]
# ...
# Probability Policy: [Max: 65.16% - (Device 10) | Min: 0.74% | Std: 11.49% | Sum: 100.00% ]
# Selected Devices: [10, 3, 27]
# Time: 11227.892s / 12000s | Acc: 80.44%
# Probability Policy: [Max: 65.10% - (Device 10) | Min: 0.75% | Std: 11.48% | Sum: 100.00% ]
# Selected Devices: [10, 13, 21]
# Time: 11234.818s / 12000s | Acc: 80.27%
# Probability Policy: [Max: 65.11% - (Device 10) | Min: 0.75% | Std: 11.48% | Sum: 100.00% ]
# Selected Devices: [10, 20, 2]
# Time: 11243.820s / 12000s | Acc: 80.27%
# Probability Policy: [Max: 65.05% - (Device 10) | Min: 0.75% | Std: 11.47% | Sum: 100.00% ]
# Selected Devices: [15, 25, 10]
# Time: 11251.877s / 12000s | Acc: 79.67%
# Probability Policy: [Max: 64.96% - (Device 10) | Min: 0.77% | Std: 11.45% | Sum: 100.00% ]
# Selected Devices: [27, 10, 14]
# Time: 11259.534s / 12000s | Acc: 79.85%
# Probability Policy: [Max: 64.86% - (Device 10) | Min: 0.76% | Std: 11.43% | Sum: 100.00% ]
# Selected Devices: [10, 18, 13]
# Time: 11267.140s / 12000s | Acc: 79.94%
# Probability Policy: [Max: 64.91% - (Device 10) | Min: 0.76% | Std: 11.44% | Sum: 100.00% ]
# Selected Devices: [10, 4, 13]
# Time: 11275.548s / 12000s | Acc: 79.97%
# Probability Policy: [Max: 64.92% - (Device 10) | Min: 0.77% | Std: 11.44% | Sum: 100.00% ]
# Selected Devices: [10, 22, 6]
# Time: 11282.296s / 12000s | Acc: 80.02%
# Probability Policy: [Max: 64.97% - (Device 10) | Min: 0.77% | Std: 11.45% | Sum: 100.00% ]
# Selected Devices: [5, 10, 19]
# Time: 11289.463s / 12000s | Acc: 79.84%
# Probability Policy: [Max: 65.06% - (Device 10) | Min: 0.77% | Std: 11.47% | Sum: 100.00% ]
# Selected Devices: [19, 10, 9]
# Time: 11297.700s / 12000s | Acc: 80.85%
# Probability Policy: [Max: 65.11% - (Device 10) | Min: 0.73% | Std: 11.48% | Sum: 100.00% ]
# Selected Devices: [14, 10, 2]
# Time: 11305.800s / 12000s | Acc: 81.14%
# Probability Policy: [Max: 65.10% - (Device 10) | Min: 0.72% | Std: 11.48% | Sum: 100.00% ]
# Selected Devices: [10, 27, 12]
# Time: 11314.654s / 12000s | Acc: 80.93%
# Probability Policy: [Max: 65.09% - (Device 10) | Min: 0.72% | Std: 11.48% | Sum: 100.00% ]
# Selected Devices: [10, 5, 6]
# Time: 11321.065s / 12000s | Acc: 80.90%
# Probability Policy: [Max: 65.12% - (Device 10) | Min: 0.73% | Std: 11.48% | Sum: 100.00% ]
# Selected Devices: [10, 19, 3]
# Time: 11329.675s / 12000s | Acc: 81.20%
# Probability Policy: [Max: 65.09% - (Device 10) | Min: 0.72% | Std: 11.47% | Sum: 100.00% ]
# Selected Devices: [25, 10, 18]
# Time: 11338.314s / 12000s | Acc: 80.68%
# Probability Policy: [Max: 65.00% - (Device 10) | Min: 0.74% | Std: 11.46% | Sum: 100.00% ]
# Selected Devices: [16, 6, 10]
# Time: 11345.088s / 12000s | Acc: 80.87%
# Probability Policy: [Max: 65.10% - (Device 10) | Min: 0.75% | Std: 11.48% | Sum: 100.00% ]
# Selected Devices: [10, 25, 23]
# Time: 11353.597s / 12000s | Acc: 80.57%
# Probability Policy: [Max: 65.05% - (Device 10) | Min: 0.76% | Std: 11.47% | Sum: 100.00% ]
# Selected Devices: [10, 29, 4]
# Time: 11361.290s / 12000s | Acc: 80.58%
# Probability Policy: [Max: 65.03% - (Device 10) | Min: 0.77% | Std: 11.46% | Sum: 100.00% ]
# Selected Devices: [20, 28, 10]
# Time: 11369.953s / 12000s | Acc: 80.25%
# Probability Policy: [Max: 65.10% - (Device 10) | Min: 0.76% | Std: 11.48% | Sum: 100.00% ]
# Selected Devices: [10, 1, 14]
# Time: 11378.077s / 12000s | Acc: 80.17%
# Probability Policy: [Max: 65.10% - (Device 10) | Min: 0.75% | Std: 11.48% | Sum: 100.00% ]
# Selected Devices: [10, 18, 29]
# Time: 11385.008s / 12000s | Acc: 80.12%
# Probability Policy: [Max: 65.09% - (Device 10) | Min: 0.76% | Std: 11.48% | Sum: 100.00% ]
# Selected Devices: [10, 15, 25]
# Time: 11393.064s / 12000s | Acc: 79.97%
# Probability Policy: [Max: 65.07% - (Device 10) | Min: 0.76% | Std: 11.47% | Sum: 100.00% ]
# Selected Devices: [26, 2, 29]
# Time: 11401.497s / 12000s | Acc: 79.21%
# Probability Policy: [Max: 64.87% - (Device 10) | Min: 0.78% | Std: 11.43% | Sum: 100.00% ]
# Selected Devices: [7, 15, 10]
# Time: 11409.659s / 12000s | Acc: 80.25%
# Probability Policy: [Max: 64.98% - (Device 10) | Min: 0.74% | Std: 11.45% | Sum: 100.00% ]
# Selected Devices: [10, 14, 20]
# Time: 11417.468s / 12000s | Acc: 80.20%
# Probability Policy: [Max: 64.95% - (Device 10) | Min: 0.74% | Std: 11.45% | Sum: 100.00% ]
# Selected Devices: [10, 2, 19]
# Time: 11425.861s / 12000s | Acc: 80.38%
# Probability Policy: [Max: 64.90% - (Device 10) | Min: 0.73% | Std: 11.44% | Sum: 100.00% ]
# Selected Devices: [22, 10, 6]
# Time: 11432.610s / 12000s | Acc: 80.16%
# Probability Policy: [Max: 64.98% - (Device 10) | Min: 0.75% | Std: 11.46% | Sum: 100.00% ]
# Selected Devices: [10, 1, 25]
# Time: 11441.901s / 12000s | Acc: 80.03%
# Probability Policy: [Max: 64.98% - (Device 10) | Min: 0.75% | Std: 11.45% | Sum: 100.00% ]
# Selected Devices: [15, 10, 11]
# Time: 11450.194s / 12000s | Acc: 79.70%
# Probability Policy: [Max: 64.88% - (Device 10) | Min: 0.77% | Std: 11.44% | Sum: 100.00% ]
# Selected Devices: [14, 10, 25]
# Time: 11458.245s / 12000s | Acc: 80.04%
# Probability Policy: [Max: 64.89% - (Device 10) | Min: 0.75% | Std: 11.44% | Sum: 100.00% ]
# Selected Devices: [10, 24, 18]
# Time: 11466.374s / 12000s | Acc: 80.34%
# Probability Policy: [Max: 64.93% - (Device 10) | Min: 0.74% | Std: 11.45% | Sum: 100.00% ]
# Selected Devices: [10, 29, 16]
# Time: 11473.070s / 12000s | Acc: 80.17%
# Probability Policy: [Max: 64.97% - (Device 10) | Min: 0.74% | Std: 11.45% | Sum: 100.00% ]
# Selected Devices: [10, 6, 20]
# Time: 11480.358s / 12000s | Acc: 80.25%
# Probability Policy: [Max: 64.95% - (Device 10) | Min: 0.74% | Std: 11.45% | Sum: 100.00% ]
# Selected Devices: [10, 6, 2]
# Time: 11487.927s / 12000s | Acc: 80.11%
# Probability Policy: [Max: 64.90% - (Device 10) | Min: 0.75% | Std: 11.44% | Sum: 100.00% ]
# Selected Devices: [10, 23, 16]
# Time: 11495.634s / 12000s | Acc: 80.08%
# Probability Policy: [Max: 64.94% - (Device 10) | Min: 0.76% | Std: 11.45% | Sum: 100.00% ]
# Selected Devices: [10, 21, 3]
# Time: 11503.801s / 12000s | Acc: 80.23%
# Probability Policy: [Max: 64.95% - (Device 10) | Min: 0.76% | Std: 11.45% | Sum: 100.00% ]
# Selected Devices: [10, 5, 6]
# Time: 11510.213s / 12000s | Acc: 80.06%
# Probability Policy: [Max: 64.98% - (Device 10) | Min: 0.76% | Std: 11.45% | Sum: 100.00% ]
# Selected Devices: [10, 13, 1]
# Time: 11518.428s / 12000s | Acc: 80.06%
# Probability Policy: [Max: 65.00% - (Device 10) | Min: 0.76% | Std: 11.46% | Sum: 100.00% ]
# Selected Devices: [10, 16, 14]
# Time: 11525.702s / 12000s | Acc: 80.08%
# Probability Policy: [Max: 65.02% - (Device 10) | Min: 0.76% | Std: 11.46% | Sum: 100.00% ]
# Selected Devices: [10, 26, 4]
# Time: 11534.072s / 12000s | Acc: 79.92%
# Probability Policy: [Max: 64.98% - (Device 10) | Min: 0.77% | Std: 11.45% | Sum: 100.00% ]
# Selected Devices: [10, 2, 3]
# Time: 11543.618s / 12000s | Acc: 79.94%
# Probability Policy: [Max: 64.91% - (Device 10) | Min: 0.77% | Std: 11.44% | Sum: 100.00% ]
# Selected Devices: [10, 18, 27]
# Time: 11551.847s / 12000s | Acc: 80.14%
# Probability Policy: [Max: 64.86% - (Device 10) | Min: 0.78% | Std: 11.43% | Sum: 100.00% ]
# Selected Devices: [10, 29, 1]
# Time: 11559.357s / 12000s | Acc: 80.08%
# Probability Policy: [Max: 64.86% - (Device 10) | Min: 0.78% | Std: 11.43% | Sum: 100.00% ]
# Selected Devices: [8, 4, 10]
# Time: 11568.571s / 12000s | Acc: 79.81%
# Probability Policy: [Max: 64.77% - (Device 10) | Min: 0.76% | Std: 11.42% | Sum: 100.00% ]
# Selected Devices: [10, 20, 1]
# Time: 11577.599s / 12000s | Acc: 79.82%
# Probability Policy: [Max: 64.75% - (Device 10) | Min: 0.77% | Std: 11.41% | Sum: 100.00% ]
# Selected Devices: [26, 16, 10]
# Time: 11584.924s / 12000s | Acc: 78.98%
# Probability Policy: [Max: 64.76% - (Device 10) | Min: 0.79% | Std: 11.41% | Sum: 100.00% ]
# Selected Devices: [6, 10, 4]
# Time: 11592.701s / 12000s | Acc: 79.23%
# Probability Policy: [Max: 64.72% - (Device 10) | Min: 0.76% | Std: 11.41% | Sum: 100.00% ]
# Selected Devices: [10, 16, 6]
# Time: 11599.474s / 12000s | Acc: 79.20%
# Probability Policy: [Max: 64.75% - (Device 10) | Min: 0.77% | Std: 11.41% | Sum: 100.00% ]
# Selected Devices: [10, 29, 20]
# Time: 11606.681s / 12000s | Acc: 79.16%
# Probability Policy: [Max: 64.76% - (Device 10) | Min: 0.77% | Std: 11.41% | Sum: 100.00% ]
# Selected Devices: [26, 10, 12]
# Time: 11614.849s / 12000s | Acc: 78.81%
# Probability Policy: [Max: 64.67% - (Device 10) | Min: 0.78% | Std: 11.40% | Sum: 100.00% ]
# Selected Devices: [10, 3, 0]
# Time: 11624.536s / 12000s | Acc: 78.84%
# Probability Policy: [Max: 64.68% - (Device 10) | Min: 0.78% | Std: 11.40% | Sum: 100.00% ]
# Selected Devices: [10, 20, 13]
# Time: 11632.433s / 12000s | Acc: 78.77%
# Probability Policy: [Max: 64.70% - (Device 10) | Min: 0.78% | Std: 11.40% | Sum: 100.00% ]
# Selected Devices: [10, 14, 0]
# Time: 11640.662s / 12000s | Acc: 78.83%
# Probability Policy: [Max: 64.75% - (Device 10) | Min: 0.76% | Std: 11.41% | Sum: 100.00% ]
# Selected Devices: [10, 6, 3]
# Time: 11648.435s / 12000s | Acc: 79.05%
# Probability Policy: [Max: 64.74% - (Device 10) | Min: 0.77% | Std: 11.41% | Sum: 100.00% ]
# Selected Devices: [27, 10, 21]
# Time: 11655.954s / 12000s | Acc: 78.86%
# Probability Policy: [Max: 64.55% - (Device 10) | Min: 0.76% | Std: 11.38% | Sum: 100.00% ]
# Selected Devices: [10, 13, 6]
# Time: 11662.521s / 12000s | Acc: 78.92%
# Probability Policy: [Max: 64.61% - (Device 10) | Min: 0.76% | Std: 11.39% | Sum: 100.00% ]
# Selected Devices: [8, 10, 24]
# Time: 11670.935s / 12000s | Acc: 79.06%
# Probability Policy: [Max: 64.73% - (Device 10) | Min: 0.75% | Std: 11.41% | Sum: 100.00% ]
# Selected Devices: [10, 17, 14]
# Time: 11678.609s / 12000s | Acc: 79.36%
# Probability Policy: [Max: 64.82% - (Device 10) | Min: 0.76% | Std: 11.43% | Sum: 100.00% ]
# Selected Devices: [24, 6, 10]
# Time: 11685.659s / 12000s | Acc: 80.01%
# Probability Policy: [Max: 64.94% - (Device 10) | Min: 0.77% | Std: 11.45% | Sum: 100.00% ]
# Selected Devices: [10, 24, 29]
# Time: 11692.629s / 12000s | Acc: 80.13%
# Probability Policy: [Max: 64.98% - (Device 10) | Min: 0.75% | Std: 11.45% | Sum: 100.00% ]
# Selected Devices: [10, 27, 24]
# Time: 11700.903s / 12000s | Acc: 80.08%
# Probability Policy: [Max: 64.93% - (Device 10) | Min: 0.74% | Std: 11.45% | Sum: 100.00% ]
# Selected Devices: [10, 13, 14]
# Time: 11707.961s / 12000s | Acc: 80.03%
# Probability Policy: [Max: 64.97% - (Device 10) | Min: 0.74% | Std: 11.45% | Sum: 100.00% ]
# Selected Devices: [29, 10, 23]
# Time: 11714.777s / 12000s | Acc: 80.01%
# Probability Policy: [Max: 65.05% - (Device 10) | Min: 0.74% | Std: 11.47% | Sum: 100.00% ]
# Selected Devices: [10, 22, 13]
# Time: 11722.109s / 12000s | Acc: 79.84%
# Probability Policy: [Max: 65.10% - (Device 10) | Min: 0.74% | Std: 11.48% | Sum: 100.00% ]
# Selected Devices: [10, 25, 24]
# Time: 11730.794s / 12000s | Acc: 80.02%
# Probability Policy: [Max: 65.11% - (Device 10) | Min: 0.73% | Std: 11.48% | Sum: 100.00% ]
# Selected Devices: [19, 5, 10]
# Time: 11737.960s / 12000s | Acc: 80.50%
# Probability Policy: [Max: 65.20% - (Device 10) | Min: 0.72% | Std: 11.50% | Sum: 100.00% ]
# Selected Devices: [10, 13, 18]
# Time: 11745.566s / 12000s | Acc: 80.19%
# Probability Policy: [Max: 65.19% - (Device 10) | Min: 0.72% | Std: 11.49% | Sum: 100.00% ]
# Selected Devices: [10, 16, 29]
# Time: 11752.262s / 12000s | Acc: 80.12%
# Probability Policy: [Max: 65.23% - (Device 10) | Min: 0.73% | Std: 11.50% | Sum: 100.00% ]
# Selected Devices: [10, 21, 12]
# Time: 11760.233s / 12000s | Acc: 80.13%
# Probability Policy: [Max: 65.25% - (Device 10) | Min: 0.74% | Std: 11.50% | Sum: 100.00% ]
# Selected Devices: [10, 5, 29]
# Time: 11766.569s / 12000s | Acc: 79.76%
# Probability Policy: [Max: 65.26% - (Device 10) | Min: 0.74% | Std: 11.51% | Sum: 100.00% ]
# Selected Devices: [20, 22, 29]
# Time: 11774.945s / 12000s | Acc: 78.88%
# Probability Policy: [Max: 65.13% - (Device 10) | Min: 0.75% | Std: 11.48% | Sum: 100.00% ]
# Selected Devices: [10, 11, 21]
# Time: 11783.088s / 12000s | Acc: 79.00%
# Probability Policy: [Max: 65.16% - (Device 10) | Min: 0.75% | Std: 11.49% | Sum: 100.00% ]
# Selected Devices: [10, 14, 11]
# Time: 11791.375s / 12000s | Acc: 79.27%
# Probability Policy: [Max: 65.18% - (Device 10) | Min: 0.74% | Std: 11.49% | Sum: 100.00% ]
# Selected Devices: [10, 18, 5]
# Time: 11798.813s / 12000s | Acc: 79.13%
# Probability Policy: [Max: 65.18% - (Device 10) | Min: 0.74% | Std: 11.49% | Sum: 100.00% ]
# Selected Devices: [10, 17, 18]
# Time: 11807.061s / 12000s | Acc: 79.58%
# Probability Policy: [Max: 65.19% - (Device 10) | Min: 0.75% | Std: 11.49% | Sum: 100.00% ]
# Selected Devices: [10, 22, 0]
# Time: 11815.588s / 12000s | Acc: 79.04%
# Probability Policy: [Max: 65.18% - (Device 10) | Min: 0.73% | Std: 11.49% | Sum: 100.00% ]
# Selected Devices: [10, 24, 17]
# Time: 11823.879s / 12000s | Acc: 79.53%
# Probability Policy: [Max: 65.20% - (Device 10) | Min: 0.74% | Std: 11.49% | Sum: 100.00% ]
# Selected Devices: [10, 21, 17]
# Time: 11831.415s / 12000s | Acc: 79.76%
# Probability Policy: [Max: 65.21% - (Device 10) | Min: 0.73% | Std: 11.50% | Sum: 100.00% ]
# Selected Devices: [13, 10, 19]
# Time: 11838.746s / 12000s | Acc: 79.70%
# Probability Policy: [Max: 65.23% - (Device 10) | Min: 0.72% | Std: 11.50% | Sum: 100.00% ]
# Selected Devices: [10, 4, 8]
# Time: 11847.959s / 12000s | Acc: 79.72%
# Probability Policy: [Max: 65.26% - (Device 10) | Min: 0.72% | Std: 11.51% | Sum: 100.00% ]
# Selected Devices: [10, 19, 15]
# Time: 11855.209s / 12000s | Acc: 79.94%
# Probability Policy: [Max: 65.26% - (Device 10) | Min: 0.72% | Std: 11.51% | Sum: 100.00% ]
# Selected Devices: [10, 0, 16]
# Time: 11863.765s / 12000s | Acc: 79.63%
# Probability Policy: [Max: 65.25% - (Device 10) | Min: 0.74% | Std: 11.51% | Sum: 100.00% ]
# Selected Devices: [10, 22, 0]
# Time: 11872.293s / 12000s | Acc: 79.26%
# Probability Policy: [Max: 65.23% - (Device 10) | Min: 0.71% | Std: 11.50% | Sum: 100.00% ]
# Selected Devices: [10, 29, 5]
# Time: 11878.629s / 12000s | Acc: 79.03%
# Probability Policy: [Max: 65.22% - (Device 10) | Min: 0.71% | Std: 11.50% | Sum: 100.00% ]
# Selected Devices: [10, 3, 20]
# Time: 11887.856s / 12000s | Acc: 79.21%
# Probability Policy: [Max: 65.22% - (Device 10) | Min: 0.71% | Std: 11.50% | Sum: 100.00% ]
# Selected Devices: [10, 13, 17]
# Time: 11895.618s / 12000s | Acc: 79.24%
# Probability Policy: [Max: 65.23% - (Device 10) | Min: 0.72% | Std: 11.50% | Sum: 100.00% ]
# Selected Devices: [21, 10, 0]
# Time: 11903.703s / 12000s | Acc: 79.15%
# Probability Policy: [Max: 65.23% - (Device 10) | Min: 0.71% | Std: 11.50% | Sum: 100.00% ]
# Selected Devices: [19, 10, 27]
# Time: 11911.645s / 12000s | Acc: 80.13%
# Probability Policy: [Max: 65.27% - (Device 10) | Min: 0.73% | Std: 11.51% | Sum: 100.00% ]
# Selected Devices: [10, 24, 14]
# Time: 11919.206s / 12000s | Acc: 80.25%
# Probability Policy: [Max: 65.26% - (Device 10) | Min: 0.71% | Std: 11.51% | Sum: 100.00% ]
# Selected Devices: [10, 27, 17]
# Time: 11927.599s / 12000s | Acc: 80.54%
# Probability Policy: [Max: 65.23% - (Device 10) | Min: 0.70% | Std: 11.50% | Sum: 100.00% ]
# Selected Devices: [10, 7, 6]
# Time: 11935.223s / 12000s | Acc: 80.79%
# Probability Policy: [Max: 65.22% - (Device 10) | Min: 0.68% | Std: 11.50% | Sum: 100.00% ]
# Selected Devices: [10, 9, 18]
# Time: 11943.754s / 12000s | Acc: 80.77%
# Probability Policy: [Max: 65.21% - (Device 10) | Min: 0.67% | Std: 11.50% | Sum: 100.00% ]
# Selected Devices: [10, 14, 20]
# Time: 11951.562s / 12000s | Acc: 80.82%
# Probability Policy: [Max: 65.18% - (Device 10) | Min: 0.67% | Std: 11.49% | Sum: 100.00% ]
# Selected Devices: [6, 9, 10]
# Time: 11958.983s / 12000s | Acc: 81.02%
# Probability Policy: [Max: 65.10% - (Device 10) | Min: 0.64% | Std: 11.48% | Sum: 100.00% ]
# Selected Devices: [10, 6, 9]
# Time: 11966.405s / 12000s | Acc: 81.03%
# Probability Policy: [Max: 65.06% - (Device 10) | Min: 0.63% | Std: 11.47% | Sum: 100.00% ]
# Selected Devices: [10, 25, 0]
# Time: 11975.809s / 12000s | Acc: 81.09%
# Probability Policy: [Max: 65.13% - (Device 10) | Min: 0.64% | Std: 11.48% | Sum: 100.00% ]
# Selected Devices: [10, 21, 25]
# Time: 11983.718s / 12000s | Acc: 81.15%
# Probability Policy: [Max: 65.17% - (Device 10) | Min: 0.65% | Std: 11.49% | Sum: 100.00% ]
# Selected Devices: [25, 2, 10]
# Time: 11992.983s / 12000s | Acc: 81.27%
# Probability Policy: [Max: 65.13% - (Device 10) | Min: 0.67% | Std: 11.48% | Sum: 100.00% ]
# Selected Devices: [21, 10, 16]
# Time: 12000.122s / 12000s | Acc: 80.97%

# %%
# Execute the plot
plot_fl_history(his, task_name="CNN", rho=2e-1, M=3)

# %%
# --- Execution ---
log_file = 'output.log'

# Extracting for rho=0 (Channel-aware) and rho=1 (Importance-aware)
his1 = extract_fl_logs(log_file, "Channel-aware", max_time=12000)
his2 = extract_fl_logs(log_file, "Importance-aware", max_time=12000)

print(f"Extraction Complete!")
print(f"his1 (Channel-aware) rounds: {len(his1['acc'])}")
print(f"his2 (Importance-aware) rounds: {len(his2['acc'])}")
# Out:
# Extraction Complete!
# his1 (Channel-aware) rounds: 0
# his2 (Importance-aware) rounds: 0

# %%
import matplotlib.pyplot as plt
import numpy as np

# 1. Create a single figure and axis
plt.figure(figsize=(10, 6))

# 2. Define a helper to handle potential empty data and smoothing
def add_to_plot(history, label, color):
    if not history or 'acc' not in history or len(history['acc']) == 0:
        print(f"Warning: {label} has no data!")
        return
    
    # Convert time to minutes for a cleaner x-axis
    times = np.array(history['time']) / 60 
    accs = np.array(history['acc'])
    
    # Plot the raw data (faded/thin) to show the 'spikes'
    plt.plot(times, accs, alpha=0.2, color=color)
    
    # Plot a Moving Average (thick) to see the actual learning trend
    window = 10
    if len(accs) > window:
        smoothed = np.convolve(accs, np.ones(window)/window, mode='valid')
        plt.plot(times[window-1:], smoothed, label=label, color=color, linewidth=2)
    else:
        plt.plot(times, accs, label=label, color=color, linewidth=2)

# 3. Add all three lines to the SAME plot
add_to_plot(his1, "Channel-aware (rho=0)", "tab:blue")
add_to_plot(his2, "Importance-aware (rho=1)", "tab:orange")
add_to_plot(his,  "Proposed (rho=0.2)", "tab:green")

# 4. Final Styling
plt.title("Performance Comparison: CNN Task (M=3)", fontsize=14)
plt.xlabel("Training Time (Minutes)", fontsize=12)
plt.ylabel("Test Accuracy (%)", fontsize=12)
plt.legend(loc='lower right')
plt.grid(True, linestyle='--', alpha=0.5)

# 5. Show only ONCE at the very end
plt.tight_layout()
plt.show()
